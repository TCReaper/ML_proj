# %% [markdown]
# ## Part 1: Estimate Emission Parameters

# %% [markdown]
# ##### Function to process the file

# %%
def process_file(filepath):
    # we make use of the default library "collections" to make processing the tags and word-tag pairs easier
    import collections #used for counting
    tag_count = collections.defaultdict(int)  # counting for tags
    word_tag_count = collections.defaultdict(int)  # counting for word-tag pairs
    vocabulary = set()  # stores unique words
    sentences = []
    current_sentence = []

    with open(filepath, 'r', encoding='utf-8') as file:
        # reading file line-by-line
        for line in file:
            stripped_line = line.strip() #removes the /n and then splits it to separete the word and its label
            if stripped_line:  # check if there even is a word or tag in the line
                word, tag = stripped_line.split()  # Split line into word and tag
                word_tag_count[(word, tag)] += 1
                tag_count[tag] += 1
                vocabulary.add(word) #doesnt add duplicates
                current_sentence.append(word)
            else:
                if current_sentence:
                    sentences.append(current_sentence)
                    current_sentence = []
        if current_sentence:
            sentences.append(current_sentence)

    return tag_count, word_tag_count, vocabulary, sentences


#tag count : dictionary with the count of each tag e.g ('B-NP') : 45
#word_tag_count : dictionary with the count of each word-tag pair e.g ('Municipal','B-NP') : 1

tag_count, word_tag_count, vocabulary, sentences = process_file('EN/train')

# %% [markdown]
# ##### Part 1a, 5 points

# %%
def estimate_all_emission_probabilities(tag_count, word_tag_count):
  
    emission_probabilities = {}
    # iterate through all the word tag pairs to get all the emission probabilities
    # store the results in the dictionary emission_probabilities
    for (word, tag), count in word_tag_count.items():
        emission_probabilities[(word, tag)] = count / tag_count[tag] 
        #setting a soft defauly emission probability of (no.of times word-tag appears)/(number of occurence of the tag in question in document)
        
    return emission_probabilities

# %%
def estimate_one_emission_probabilities(x, y, tag_count, word_tag_count):
    
    # get the total times y->x occurs
    word_tag_freq = word_tag_count.get((x, y), 0)
    # total times y appears
    tag_total_freq = tag_count.get(y, 1)
    
    return word_tag_freq / tag_total_freq

# %%
emission_probabilities = estimate_all_emission_probabilities(tag_count, word_tag_count)

# %%
emission_probabilities
# Out:
# {('Municipal', 'B-NP'): 2.1139414438220062e-05,
#  ('bonds', 'I-NP'): 0.0018134857394075947,
#  ('are', 'B-VP'): 0.03707354471277586,
#  ('generally', 'B-ADVP'): 0.0033660589060308557,
#  ('a', 'B-ADJP'): 0.0017133066818960593,
#  ('bit', 'I-ADJP'): 0.003484320557491289,
#  ('safer', 'I-ADJP'): 0.0017421602787456446,
#  ('than', 'B-PP'): 0.006961440147930603,
#  ('corporate', 'B-NP'): 0.0005919036042701618,
#  ('in', 'B-PP'): 0.15565345080763582,
#  ('a', 'B-NP'): 0.0758693584187718,
#  ('recession', 'I-NP'): 0.000641131322012786,
#  (',', 'O'): 0.36465315013404825,
#  ('but', 'O'): 0.012231903485254691,
#  ('not', 'B-ADJP'): 0.0034266133637921186,
#  ('as', 'I-ADJP'): 0.012195121951219513,
#  ('safe', 'I-ADJP'): 0.003484320557491289,
#  ('as', 'B-PP'): 0.019796595420677653,
#  ('bonds', 'B-NP'): 0.0004439277032026213,
#  ('issued', 'B-VP'): 0.0007666611905153059,
#  ('by', 'B-PP'): 0.047207266003154405,
#  ('Per', 'B-NP'): 4.2278828876440124e-05,
#  ('capita', 'I-NP'): 5.495411331538166e-05,
#  ('income', 'I-NP'): 0.0019966661171255335,
#  ('widely', 'I-NP'): 7.327215108717554e-05,
#  ('used', 'I-NP'): 5.495411331538166e-05,
#  ('measure', 'I-NP'): 0.000476268982066641,
#  ('nation', 'I-NP'): 0.0008426297375025187,
#  ('economic', 'I-NP'): 0.0006960854353281677,
#  ('health', 'I-NP'): 0.00031140664212049606,
#  ('record', 'I-NP'): 0.000476268982066641,
#  ('1988', 'B-NP'): 0.0008244371630905824,
#  ('rising', 'B-VP'): 0.00038333059525765293,
#  ('1.7', 'B-NP'): 6.341824331466019e-05,
#  ('inflation', 'B-NP'): 0.0006341824331466019,
#  ('adjustment', 'I-NP'): 7.327215108717554e-05,
#  ('13,120', 'I-NP'): 1.8318037771793885e-05,
#  ('Within', 'B-PP'): 0.0005982487627127862,
#  ('appropriations', 'I-NP'): 5.495411331538166e-05,
#  ('67', 'I-NP'): 7.327215108717554e-05,
#  ('largest', 'I-NP'): 0.000787675624187137,
#  ('domestic', 'I-NP'): 0.0001282262644025572,
#  ('spending', 'I-NP'): 0.00036636075543587773,
#  ('bills', 'I-NP'): 0.0003480427176640838,
#  ('covers', 'B-VP'): 0.0003285690816494168,
#  ('disparate', 'I-NP'): 1.8318037771793885e-05,
#  ('collection', 'I-NP'): 3.663607554358777e-05,
#  ('accounts', 'B-NP'): 4.2278828876440124e-05,
#  ('science', 'B-NP'): 2.1139414438220062e-05,
#  ('housing', 'B-NP'): 0.00019025472994398056,
#  ('veterans', 'B-NP'): 2.1139414438220062e-05,
#  ('environment', 'I-NP'): 0.00016486233994614496,
#  ('Plaster', 'B-NP'): 2.1139414438220062e-05,
#  ('fell', 'B-VP'): 0.0060237664969059745,
#  ('windows', 'B-NP'): 6.341824331466019e-05,
#  ...}

# %% [markdown]
# ##### Part 1b, 10 points

# %%
def estimate_emission_probability_with_unknown(tag, word, tag_count, word_tag_count, vocabulary, k=0.1):
    
    # total times y appears + k
    tag_total_freq = tag_count.get(tag, 0) + k
    
    # Check if the word was seen in the training set; if not, use the special UNK token
    # e(x|y) = k/(count(y)+k) if word token is UNK
    if word not in vocabulary:
        word = '#UNK#'
        word_tag_freq = k
        return word_tag_freq / tag_total_freq
    
    # get the total times y->x occurs
    word_tag_freq = word_tag_count.get((word, tag), 0)
  
    return word_tag_freq / tag_total_freq

# %%
def estimate_all_emission_probabilities_with_unknown(tag_count, word_tag_count, k =0.1):
  
    emission_probabilities = {}
    # iterate through all the word tag pairs to get all the emission probabilities
    # store the results in the dictionary emission_probabilities
    for (word, tag), count in word_tag_count.items():
        
        emission_probabilities[(word, tag)] = count / (tag_count[tag]+k)
        
    for tag, count in tag_count.items():
        emission_probabilities[("#UNK#", tag)] = count / (tag_count[tag]+k)
    return emission_probabilities

# %%
emission_probabilities = estimate_all_emission_probabilities_with_unknown(tag_count, word_tag_count)

# %%
# emission_probabilities

# %%
print(emission_probabilities)

#              'I-VP': 10159,
#              'I-ADVP': 363,
#              'B-PRT': 468,
#              'I-PP': 223,
#              'B-CONJP': 49,
#              'I-CONJP': 64,
#              'B-INTJ': 26,
#              'I-INTJ': 7,
#              'I-SBAR': 48,
#              'B-UCP': 1,
#              'I-UCP': 4,
#              'B-LST': 11})

# %%
max(tag_count)
# Out:
# 'O'

# %% [markdown]
# #### Part 1c, 10 points

# %%
def predict_one_tag(word, emission_probabilities, vocabulary,tag_count):
    # use UNK token if the word is not in the vocabulary
    best_tag = None

    if word not in vocabulary:
        word = '#UNK#'
        best_tag = max(tag_count)
#         return '#UNK#'

    # initialise the variables to keep track of the best tag and its highest probability
    max_probability = -1  # Start with a very low probability

    # iterate over all possible tags for the word in the emission probabilities
    for (current_word, tag), probability in emission_probabilities.items():
        if current_word == word and probability > max_probability:
            max_probability = probability
            best_tag = tag

    return word, best_tag

# %%
def predict_all_tags(filepath, emission_probabilities, vocabulary, tag_count):
    predictions = []
    current_sentence = []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            word = line.strip()
            if word:  # Ensure the line is not empty
                word, best_tag = predict_one_tag(word, emission_probabilities, vocabulary, tag_count)
                current_sentence.append((word, best_tag))
            else:
                if current_sentence:
                    predictions.append(current_sentence)
                    current_sentence = []
        if current_sentence:
                    predictions.append(current_sentence)
#                     current_sentence = []

    return predictions

# %%
predictions = predict_all_tags("EN/dev.in", emission_probabilities, vocabulary, tag_count)

# %%
def write_predictions_to_file(predictions, output_filepath):
    # open the output file for writing
    with open(output_filepath, 'w', encoding='utf-8') as file:
        for sentence in predictions:
            for word, tag in sentence:
                # write each word and its predicted tag to the file, with a spacing to separate.
                file.write(f"{word} {tag}\n")
            file.write("\n")

# %%
write_predictions_to_file(predictions, "EN/dev_try.out")

# %%
predictions
# Out:
# [[('HBO', 'B-NP'),
#   ('has', 'B-VP'),
#   ('close', 'B-ADJP'),
#   ('to', 'B-PP'),
#   ('24', 'I-NP'),
#   ('million', 'I-NP'),
#   ('subscribers', 'I-NP'),
#   ('to', 'B-PP'),
#   ('its', 'B-NP'),
#   ('HBO', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   ('networks', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('Showtime', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('its', 'B-NP'),
#   ('sister', 'I-NP'),
#   ('service', 'I-NP'),
#   (',', 'O'),
#   ('The', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Channel', 'I-NP'),
#   (',', 'O'),
#   ('have', 'I-VP'),
#   ('only', 'I-CONJP'),
#   ('about', 'B-PP'),
#   ('10', 'I-ADVP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Paul', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Associates', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('Calif.', 'B-NP'),
#   (',', 'O'),
#   ('research', 'I-NP'),
#   ('firm', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('after', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('stock', 'I-NP'),
#   ('market', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('roller-coaster', 'I-NP'),
#   ('ride', 'I-VP'),
#   ('.', 'O')],
#  [('This', 'B-NP'),
#   ('may', 'B-VP'),
#   ('seem', 'B-VP'),
#   ('to', 'B-PP'),
#   ('be', 'I-VP'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   ('futile', 'I-NP'),
#   ('effort', 'I-NP'),
#   ('in', 'B-PP'),
#   ('Africa', 'I-NP'),
#   ('.', 'O')],
#  [('American', 'B-NP'),
#   ('Express', 'I-NP'),
#   ('Bank', 'I-NP'),
#   ('earnings', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('50', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('21.3', 'I-NP'),
#   ('million', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('42.5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('despite', 'B-PP'),
#   ('a', 'B-LST'),
#   ('29', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('revenue', 'I-NP'),
#   ('gain', 'I-NP'),
#   ('.', 'O')],
#  [('Californians', 'B-NP'),
#   (',', 'O'),
#   ('meanwhile', 'B-ADVP'),
#   (',', 'O'),
#   ('tried', 'B-VP'),
#   ('to', 'B-PP'),
#   ('cope', 'I-VP'),
#   ('with', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('services', 'I-NP'),
#   (',', 'O'),
#   ('blocked', 'I-VP'),
#   ('roadways', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('water', 'I-NP'),
#   ('shortages', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('aftermath', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('tremor', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('left', 'I-VP'),
#   ('scores', 'I-NP'),
#   ('dead', 'B-ADJP'),
#   ('and', 'I-UCP'),
#   ('injured', 'I-VP'),
#   ('.', 'O')],
#  [('This', 'B-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('number', 'I-NP'),
#   ('of', 'I-PP'),
#   ('retail', 'B-NP'),
#   ('leveraged', 'I-ADJP'),
#   ('#UNK#', 'I-NP'),
#   ('have', 'I-VP'),
#   ('failed', 'B-VP'),
#   (',', 'O'),
#   ('causing', 'I-VP'),
#   ('jitters', 'B-NP'),
#   ('among', 'I-PP'),
#   ('suppliers', 'I-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('Mr.', 'B-NP'),
#   ('Merksamer', 'I-NP'),
#   ('apparently', 'B-ADVP'),
#   ('wanted', 'B-VP'),
#   ('assurances', 'B-NP'),
#   ('that', 'B-SBAR'),
#   ('he', 'B-NP'),
#   ('wo', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('have', 'I-VP'),
#   ('delivery', 'I-NP'),
#   ('problems', 'I-NP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Juliano', 'I-NP'),
#   ('thinks', 'B-VP'),
#   ('so', 'B-ADJP'),
#   ('.', 'O')],
#  [('Assistant', 'O'),
#   ('U.S.', 'I-NP'),
#   ('Attorney', 'I-NP'),
#   ('Terry', 'B-NP'),
#   ('Hart', 'I-NP'),
#   ('of', 'I-PP'),
#   ('Dallas', 'B-NP'),
#   ('says', 'B-VP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('will', 'B-VP'),
#   ('oppose', 'B-VP'),
#   ('any', 'B-NP'),
#   ('efforts', 'I-NP'),
#   ('to', 'B-PP'),
#   ('bring', 'I-VP'),
#   ('in', 'B-PP'),
#   ('a', 'B-LST'),
#   ('new', 'I-NP'),
#   ('defense', 'I-NP'),
#   ('team', 'I-NP'),
#   ('because', 'B-SBAR'),
#   ('it', 'B-NP'),
#   ('would', 'B-VP'),
#   ('delay', 'I-VP'),
#   ('a', 'B-LST'),
#   ('retrial', 'B-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('Co.', 'I-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('will', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('all', 'I-ADVP'),
#   ('#UNK#', 'I-NP'),
#   ('shares', 'I-NP'),
#   ('of', 'I-PP'),
#   ('its', 'B-NP'),
#   ('privately', 'B-ADVP'),
#   ('held', 'I-VP'),
#   ('6.5', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('convertible', 'B-ADJP'),
#   ('Series', 'I-NP'),
#   ('C', 'I-NP'),
#   ('preferred', 'I-NP'),
#   ('stock', 'I-NP'),
#   ('Nov.', 'B-NP'),
#   ('8', 'B-NP'),
#   ('.', 'O')],
#  [('On', 'B-PP'),
#   ('a', 'B-LST'),
#   ('$', 'B-NP'),
#   ('10,000', 'I-NP'),
#   ('investment', 'I-NP'),
#   (',', 'O'),
#   ('that', 'B-SBAR'),
#   ("'s", 'B-NP'),
#   ('a', 'B-LST'),
#   ('difference', 'I-NP'),
#   ('of', 'I-PP'),
#   ('only', 'I-CONJP'),
#   ('$', 'B-NP'),
#   ('50', 'I-NP'),
#   ('a', 'B-LST'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Neither', 'B-NP'),
#   ('the', 'B-NP'),
#   ('Amoco', 'B-NP'),
#   ('agreement', 'I-NP'),
#   ('nor', 'O'),
#   ('the', 'B-NP'),
#   ('wells', 'I-NP'),
#   ('existed', 'B-VP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('suit', 'I-NP'),
#   ('alleged', 'B-VP'),
#   ('.', 'O')],
#  [('But', 'O'),
#   ('for', 'B-PP'),
#   ('individuals', 'B-NP'),
#   ('who', 'B-NP'),
#   ('buy', 'I-VP'),
#   ('much', 'I-ADVP'),
#   ('smaller', 'B-ADJP'),
#   ('amounts', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('care', 'I-NP'),
#   ('less', 'B-ADJP'),
#   ('about', 'B-PP'),
#   ('relative', 'B-ADJP'),
#   ('performance', 'I-NP'),
#   ('than', 'I-CONJP'),
#   ('in', 'B-PP'),
#   ('preserving', 'B-VP'),
#   ('what', 'B-NP'),
#   ('they', 'B-NP'),
#   ('have', 'I-VP'),
#   (',', 'O'),
#   ('that', 'B-SBAR'),
#   ('margin', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('authorities', 'I-NP'),
#   ('have', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   ('foreign', 'B-NP'),
#   ('reporters', 'B-NP'),
#   ('to', 'B-PP'),
#   ('her', 'B-NP'),
#   ('office', 'I-NP'),
#   ('to', 'B-PP'),
#   ('see', 'I-VP'),
#   ('an', 'B-NP'),
#   ('example', 'B-NP'),
#   ('of', 'I-PP'),
#   ('``', 'O'),
#   ('the', 'B-NP'),
#   ('new', 'I-NP'),
#   ('way', 'I-NP'),
#   ('of', 'I-PP'),
#   ('thinking', 'I-VP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('That', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('because', 'B-SBAR'),
#   ('computers', 'I-NP'),
#   ('do', 'B-VP'),
#   ('most', 'B-ADJP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('work', 'I-VP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('low', 'I-ADJP'),
#   ('trading', 'I-NP'),
#   ('activity', 'I-NP'),
#   ('keeps', 'B-VP'),
#   ('a', 'B-LST'),
#   ('lid', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('commission', 'I-NP'),
#   ('costs', 'I-NP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Pinola', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('president', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('chief', 'B-NP'),
#   ('operating', 'I-VP'),
#   ('officer', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('Mutual', 'I-NP'),
#   ('Life', 'I-NP'),
#   ('Insurance', 'I-NP'),
#   ('Co', 'I-NP'),
#   ('.', 'O')],
#  [('John', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('analyst', 'I-NP'),
#   ('with', 'B-PP'),
#   ('Raymond', 'B-NP'),
#   ('James', 'B-NP'),
#   ('&', 'I-NP'),
#   ('Associates', 'I-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('results', 'I-NP'),
#   ('were', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('surprising', 'I-ADJP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('attributed', 'B-VP'),
#   ('the', 'B-NP'),
#   ('buy-back', 'I-NP'),
#   ('to', 'B-PP'),
#   ('management', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('confidence', 'B-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Mirage', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('ability', 'I-NP'),
#   ('to', 'B-PP'),
#   ('generate', 'I-VP'),
#   ('strong', 'I-ADJP'),
#   ('cash', 'B-NP'),
#   ('flow', 'I-NP'),
#   ('in', 'B-PP'),
#   ('1990', 'B-NP'),
#   ('.', 'O')],
#  [('Raymond', 'B-NP'),
#   ('James', 'B-NP'),
#   ('&', 'I-NP'),
#   ('Associates', 'I-NP'),
#   ('in', 'B-PP'),
#   ('St.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('Fla.', 'B-NP'),
#   (',', 'O'),
#   ('lowered', 'B-VP'),
#   ('its', 'B-NP'),
#   ('third-quarter', 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('estimate', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   (',', 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Dow', 'I-NP'),
#   ('Jones', 'I-NP'),
#   ('Professional', 'I-NP'),
#   ('Investor', 'I-NP'),
#   ('Report', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('also', 'I-CONJP'),
#   ('operates', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('entertainment', 'I-NP'),
#   ('properties', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('small', 'I-ADJP'),
#   ('#UNK#', 'I-NP'),
#   ('systems', 'I-NP'),
#   ('.', 'O')],
#  [('Digital', 'B-NP'),
#   (',', 'O'),
#   ('based', 'B-VP'),
#   ('in', 'B-PP'),
#   ('Maynard', 'I-NP'),
#   (',', 'O'),
#   ('Mass.', 'B-NP'),
#   (',', 'O'),
#   ('hopes', 'B-VP'),
#   ('to', 'B-PP'),
#   ('stage', 'I-NP'),
#   ('a', 'B-LST'),
#   ('repeat', 'I-VP'),
#   ('performance', 'I-NP'),
#   ('in', 'B-PP'),
#   ('mainframes', 'I-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('it', 'B-NP'),
#   ('has', 'B-VP'),
#   ('spent', 'B-VP'),
#   ('almost', 'B-ADJP'),
#   ('$', 'B-NP'),
#   ('1', 'B-LST'),
#   ('billion', 'I-NP'),
#   ('developing', 'I-VP'),
#   ('the', 'B-NP'),
#   ('new', 'I-NP'),
#   ('technology', 'I-NP'),
#   ('.', 'O')],
#  [('He', 'B-NP'),
#   ('also', 'I-CONJP'),
#   ('says', 'B-VP'),
#   ('CompuServe', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('continue', 'I-VP'),
#   ('to', 'B-PP'),
#   ('grow', 'I-VP'),
#   ('``', 'O'),
#   ('20', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('30', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('a', 'B-LST'),
#   ('year', 'I-NP'),
#   ("''", 'O'),
#   ('in', 'B-PP'),
#   ('spite', 'B-NP'),
#   ('of', 'I-PP'),
#   ('tough', 'I-ADJP'),
#   ('competition', 'I-NP'),
#   ('from', 'B-PP'),
#   ('giants', 'I-NP'),
#   ('like', 'B-PP'),
#   ('Sears', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('IBM', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Treasury', 'I-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'B-PP'),
#   ('raise', 'I-VP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('new', 'I-NP'),
#   ('cash', 'B-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('sale', 'I-NP'),
#   ('Monday', 'B-NP'),
#   ('of', 'I-PP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('15.6', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('short-term', 'I-NP'),
#   ('bills', 'I-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('bills', 'I-NP'),
#   ('.', 'O')],
#  [('Stocks', 'B-NP'),
#   ('retreated', 'B-VP'),
#   ('to', 'B-PP'),
#   ('session', 'I-NP'),
#   ('lows', 'B-NP'),
#   ('just', 'I-CONJP'),
#   ('after', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('opening', 'I-VP'),
#   ('amid', 'B-PP'),
#   ('worries', 'B-NP'),
#   ('about', 'B-PP'),
#   ('the', 'B-NP'),
#   ('market', 'I-NP'),
#   ('impact', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('quake', 'I-NP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('quickly', 'I-ADVP'),
#   ('snapped', 'B-VP'),
#   ('back', 'B-PRT'),
#   ('to', 'B-PP'),
#   ('higher', 'I-ADJP'),
#   ('levels', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('help', 'I-VP'),
#   ('of', 'I-PP'),
#   ('futures-related', 'B-NP'),
#   ('program', 'I-NP'),
#   ('buying', 'I-VP'),
#   ('.', 'O')],
#  [('There', 'B-NP'),
#   ('is', 'I-INTJ'),
#   ('no', 'I-INTJ'),
#   ('small', 'I-ADJP'),
#   ('irony', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('fact', 'I-ADVP'),
#   ('that', 'B-SBAR'),
#   ('some', 'B-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('advertising', 'I-NP'),
#   ('comes', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('--', 'O'),
#   ('you', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('it', 'B-NP'),
#   ('--', 'O'),
#   ('outsiders', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Federal', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Commission', 'I-NP'),
#   ('clears', 'B-VP'),
#   ('corporate', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('to', 'B-PP'),
#   ('an', 'B-NP'),
#   ('employee', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('chosen', 'I-VP'),
#   ('charity', 'I-NP'),
#   ('in', 'B-PP'),
#   ('exchange', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('worker', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('gift', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ('political', 'I-NP'),
#   ('action', 'I-NP'),
#   ('committee', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('method', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('the', 'B-NP'),
#   ('20', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('tax', 'I-NP'),
#   (',', 'O'),
#   ('paid', 'I-VP'),
#   ('if', 'I-SBAR'),
#   ('it', 'B-NP'),
#   ('exceeds', 'B-VP'),
#   ('tax', 'I-NP'),
#   ('figured', 'B-VP'),
#   ('the', 'B-NP'),
#   ('regular', 'I-NP'),
#   ('way', 'I-NP'),
#   (',', 'O'),
#   ('is', 'I-INTJ'),
#   ('due', 'B-ADJP'),
#   ('for', 'B-PP'),
#   ('a', 'B-LST'),
#   ('change', 'I-VP'),
#   ('in', 'B-PP'),
#   ('1990', 'B-NP'),
#   (',', 'O'),
#   ('#UNK#', 'I-NP'),
#   ('to', 'B-PP'),
#   ('1986', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('tax', 'I-NP'),
#   ('act', 'I-VP'),
#   ('.', 'O')],
#  [('I', 'B-NP'),
#   ('expected', 'I-VP'),
#   ('him', 'B-NP'),
#   ('to', 'B-PP'),
#   ('say', 'B-INTJ'),
#   (',', 'O'),
#   ('``', 'O'),
#   ('I', 'B-NP'),
#   ('told', 'I-VP'),
#   ('you', 'B-NP'),
#   ('so', 'B-ADJP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('but', 'B-CONJP'),
#   ('he', 'B-NP'),
#   ('already', 'B-ADVP'),
#   ('was', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('Although', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('East', 'B-NP'),
#   ('German', 'I-NP'),
#   ('news', 'I-NP'),
#   ('agency', 'I-NP'),
#   ('ADN', 'I-NP'),
#   ('claimed', 'B-VP'),
#   ('Mr.', 'B-NP'),
#   ('Honecker', 'I-NP'),
#   ('had', 'B-VP'),
#   ('asked', 'B-VP'),
#   ('to', 'B-PP'),
#   ('be', 'I-VP'),
#   ('relieved', 'B-ADJP'),
#   ('of', 'I-PP'),
#   ('his', 'B-NP'),
#   ('duties', 'I-NP'),
#   ('for', 'B-PP'),
#   ('``', 'O'),
#   ('health', 'I-NP'),
#   ('reasons', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('West', 'I-NP'),
#   ('German', 'I-NP'),
#   ('government', 'I-NP'),
#   ('sources', 'I-NP'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Politburo', 'I-NP'),
#   ('had', 'B-VP'),
#   ('asked', 'B-VP'),
#   ('for', 'B-PP'),
#   ('his', 'B-NP'),
#   ('resignation', 'I-NP'),
#   ('at', 'B-PP'),
#   ('a', 'B-LST'),
#   ('separate', 'I-NP'),
#   ('meeting', 'I-NP'),
#   ('late', 'I-ADVP'),
#   ('Tuesday', 'B-NP'),
#   ('.', 'O')],
#  [('During', 'B-PP'),
#   ('the', 'B-NP'),
#   ('quarter', 'I-NP'),
#   (',', 'O'),
#   ('Pfizer', 'B-NP'),
#   ('received', 'I-VP'),
#   ('federal', 'I-NP'),
#   ('approval', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('calcium', 'I-NP'),
#   ('channel', 'B-VP'),
#   ('blocker', 'I-NP'),
#   ('approved', 'I-VP'),
#   ('for', 'B-PP'),
#   ('both', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('used', 'I-VP'),
#   ('to', 'B-PP'),
#   ('open', 'B-ADJP'),
#   ('obstructed', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   ('arteries', 'I-NP'),
#   ('.', 'O')],
#  [('We', 'B-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('want', 'I-VP'),
#   ('to', 'B-PP'),
#   ('be', 'I-VP'),
#   ('party', 'I-NP'),
#   ('to', 'B-PP'),
#   ('a', 'B-LST'),
#   ('second', 'I-NP'),
#   ('rejection', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('he', 'B-NP'),
#   ('said', 'B-VP'),
#   (',', 'O'),
#   ('adding', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('coming', 'I-VP'),
#   ('up', 'B-PRT'),
#   ('with', 'B-PP'),
#   ('a', 'B-LST'),
#   ('revised', 'I-NP'),
#   ('offer', 'I-VP'),
#   ('could', 'B-VP'),
#   ('easily', 'I-ADVP'),
#   ('take', 'I-VP'),
#   ('several', 'B-NP'),
#   ('weeks', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('authorities', 'I-NP'),
#   ('say', 'B-INTJ'),
#   ('that', 'B-SBAR'),
#   ('at', 'B-PP'),
#   ('any', 'B-NP'),
#   ('given', 'I-VP'),
#   ('time', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('host', 'I-NP'),
#   ('of', 'I-PP'),
#   ('fraudulent', 'B-NP'),
#   ('telemarketing', 'B-NP'),
#   ('operations', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('many', 'B-NP'),
#   ('legitimate', 'B-NP'),
#   ('businesses', 'I-NP'),
#   ('here', 'B-ADVP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('percentage', 'I-ADVP'),
#   ('rates', 'I-NP'),
#   ('are', 'B-VP'),
#   ('calculated', 'B-VP'),
#   ('on', 'B-PRT'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('yield', 'I-VP'),
#   ('is', 'I-INTJ'),
#   ('based', 'B-VP'),
#   ('on', 'B-PRT'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Neither', 'B-NP'),
#   ('was', 'B-VP'),
#   ('among', 'I-PP'),
#   ('the', 'B-NP'),
#   ('46', 'B-NP'),
#   ('traders', 'B-NP'),
#   ('indicted', 'I-VP'),
#   ('last', 'I-ADVP'),
#   ('August', 'B-NP'),
#   ('in', 'B-PP'),
#   ('a', 'B-LST'),
#   ('federal', 'I-NP'),
#   ('investigation', 'I-NP'),
#   ('of', 'I-PP'),
#   ('traders', 'B-NP'),
#   ('at', 'B-PP'),
#   ('both', 'B-NP'),
#   ('the', 'B-NP'),
#   ('Merc', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('the', 'B-NP'),
#   ('Chicago', 'B-NP'),
#   ('Board', 'I-NP'),
#   ('of', 'I-PP'),
#   ('Trade', 'B-NP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('spokesman', 'I-NP'),
#   ('for', 'B-PP'),
#   ('Dean', 'B-NP'),
#   ('Witter', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('unit', 'I-NP'),
#   ('of', 'I-PP'),
#   ('Sears', 'B-NP'),
#   (',', 'O'),
#   ('Roebuck', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Co.', 'I-NP'),
#   (',', 'O'),
#   ('declined', 'B-VP'),
#   ('to', 'B-PP'),
#   ('comment', 'I-VP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('By', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('a', 'B-LST'),
#   ('place', 'I-VP'),
#   ('now', 'B-ADVP'),
#   (',', 'O'),
#   ('we', 'B-NP'),
#   ('make', 'I-VP'),
#   ('ourselves', 'B-NP'),
#   ('a', 'B-LST'),
#   ('power', 'I-NP'),
#   ('any', 'B-NP'),
#   ('new', 'I-NP'),
#   ('government', 'I-NP'),
#   ('will', 'B-VP'),
#   ('have', 'I-VP'),
#   ('to', 'B-PP'),
#   ('take', 'I-VP'),
#   ('into', 'B-PP'),
#   ('account', 'B-VP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('Also', 'B-ADVP'),
#   (',', 'O'),
#   ('profit', 'I-NP'),
#   ('rose', 'B-VP'),
#   ('19', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('third', 'I-NP'),
#   ('quarter', 'I-NP'),
#   ('.', 'O')],
#  [('Two', 'B-NP'),
#   ('election', 'I-NP'),
#   ('commission', 'I-NP'),
#   ('members', 'I-NP'),
#   ('opposed', 'B-VP'),
#   ('the', 'B-NP'),
#   ('matching', 'B-VP'),
#   ('plans', 'B-VP'),
#   ('.', 'O')],
#  [('An', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('move', 'I-VP'),
#   ('by', 'B-PP'),
#   ('personal', 'I-NP'),
#   ('computer', 'I-NP'),
#   ('manufacturers', 'B-NP'),
#   ("'", 'B-NP'),
#   ('to', 'B-PP'),
#   ('include', 'I-VP'),
#   ('advanced', 'B-VP'),
#   ('graphics', 'B-NP'),
#   ('capabilities', 'I-NP'),
#   ('as', 'B-CONJP'),
#   ('standard', 'I-NP'),
#   ('equipment', 'I-NP'),
#   ('further', 'I-ADVP'),
#   ('#UNK#', 'I-NP'),
#   ('reseller', 'B-NP'),
#   ('purchases', 'I-NP'),
#   ('of', 'I-PP'),
#   ('Western', 'B-NP'),
#   ('Digital', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('equipment', 'I-NP'),
#   ('.', 'O')],
#  [('When', 'B-ADVP'),
#   ('the', 'B-NP'),
#   ('IAFP', 'I-NP'),
#   ('recently', 'I-ADVP'),
#   ('assembled', 'I-VP'),
#   ('other', 'B-NP'),
#   ('industry', 'I-NP'),
#   ('groups', 'I-NP'),
#   ('to', 'B-PP'),
#   ('discuss', 'I-VP'),
#   ('common', 'I-ADJP'),
#   ('standards', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('might', 'B-VP'),
#   ('be', 'I-VP'),
#   ('applied', 'B-VP'),
#   ('to', 'B-PP'),
#   ('planners', 'I-NP'),
#   (',', 'O'),
#   ('Mr.', 'B-NP'),
#   ('Gargan', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('group', 'I-NP'),
#   ('was', 'B-VP'),
#   ('excluded', 'I-VP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('chairman', 'B-NP'),
#   ('of', 'I-PP'),
#   ('his', 'B-NP'),
#   ('own', 'I-NP'),
#   ('consulting', 'I-NP'),
#   ('company', 'I-NP'),
#   ('in', 'B-PP'),
#   ('Englewood', 'B-NP'),
#   (',', 'O'),
#   ('N.J', 'B-NP'),
#   ('.', 'O')],
#  [('CALL', 'B-NP'),
#   ('MONEY', 'I-NP'),
#   (':', 'O'),
#   ('9', 'I-NP'),
#   ('3\\/4', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('10', 'I-ADVP'),
#   ('%', 'I-ADJP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('forces', 'I-NP'),
#   ('at', 'B-PP'),
#   ('work', 'I-VP'),
#   ('included', 'B-VP'),
#   ('computer-guided', 'B-NP'),
#   ('trading', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-CONJP'),
#   ('well', 'I-CONJP'),
#   ('as', 'B-CONJP'),
#   ('#UNK#', 'I-NP'),
#   ('market', 'I-NP'),
#   ('makers', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('institutional', 'I-NP'),
#   ('investors', 'B-NP'),
#   ('who', 'B-NP'),
#   ('had', 'B-VP'),
#   ('bought', 'B-VP'),
#   ('stock', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('cheap', 'I-ADJP'),
#   ('during', 'B-PP'),
#   ('the', 'B-NP'),
#   ('recent', 'I-ADJP'),
#   ('correction', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('thing', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('so', 'B-ADJP'),
#   ('#UNK#', 'I-NP'),
#   ('right', 'I-ADJP'),
#   ('now', 'B-ADVP'),
#   ('that', 'B-SBAR'),
#   ('there', 'B-ADVP'),
#   ("'s", 'B-NP'),
#   ('really', 'B-ADVP'),
#   ('no', 'I-INTJ'),
#   ('way', 'I-NP'),
#   ('to', 'B-PP'),
#   ('say', 'B-INTJ'),
#   ('what', 'B-NP'),
#   ('will', 'B-VP'),
#   ('happen', 'I-VP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Justice', 'I-NP'),
#   ('Department', 'I-NP'),
#   ('attorney', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('III', 'I-NP'),
#   (',', 'O'),
#   ('who', 'B-NP'),
#   ('represents', 'B-VP'),
#   ('the', 'B-NP'),
#   ('IRS', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('case', 'I-NP'),
#   ('.', 'O')],
#  [('That', 'B-NP'),
#   ('rose', 'B-VP'),
#   ('to', 'B-PP'),
#   ('nearly', 'B-ADJP'),
#   ('18', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('during', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('has', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('changed', 'I-ADJP'),
#   ('much', 'I-ADVP'),
#   ('since', 'B-SBAR'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Maynard', 'I-NP'),
#   ('initially', 'B-ADVP'),
#   ('won', 'B-VP'),
#   ('approval', 'I-NP'),
#   ('for', 'B-PP'),
#   ('his', 'B-NP'),
#   ('machine', 'I-NP'),
#   ('to', 'B-PP'),
#   ('be', 'I-VP'),
#   ('used', 'I-VP'),
#   ('at', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('facilities', 'I-NP'),
#   ('regulated', 'I-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('USDA', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('Food', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Service', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('gained', 'B-VP'),
#   ('100', 'I-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('trade', 'I-NP'),
#   ('figures', 'I-NP'),
#   ('range', 'I-ADJP'),
#   ('widely', 'I-ADVP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('few', 'I-NP'),
#   ('economists', 'I-NP'),
#   ('expect', 'B-VP'),
#   ('the', 'B-NP'),
#   ('data', 'I-NP'),
#   ('to', 'B-PP'),
#   ('show', 'I-VP'),
#   ('a', 'B-LST'),
#   ('very', 'B-ADJP'),
#   ('marked', 'B-VP'),
#   ('improvement', 'I-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#', 'B-ADJP'),
#   ('2', 'B-LST'),
#   ('billion', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('-RRB-', 'O'),
#   ('deficit', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('current', 'I-ADJP'),
#   ('account', 'B-VP'),
#   ('reported', 'B-VP'),
#   ('for', 'B-PP'),
#   ('August', 'B-NP'),
#   ('.', 'O')],
#  [('Fox', 'B-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'B-PP'),
#   ('offer', 'I-VP'),
#   ('its', 'B-NP'),
#   ('stations', 'I-NP'),
#   ('movies', 'I-NP'),
#   (',', 'O'),
#   ('theatrical', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   ('ventures', 'I-NP'),
#   (',', 'O'),
#   ('probably', 'B-ADVP'),
#   ('on', 'B-PRT'),
#   ('Wednesdays', 'B-NP'),
#   (',', 'O'),
#   ('sometime', 'B-NP'),
#   ('next', 'B-ADVP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('sentiment', 'I-NP'),
#   ('among', 'I-PP'),
#   ('bankers', 'I-NP'),
#   ('comes', 'B-VP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Independent', 'B-NP'),
#   ('Bankers', 'B-NP'),
#   ('Association', 'I-NP'),
#   ('of', 'I-PP'),
#   ('Texas', 'B-ADJP'),
#   (',', 'O'),
#   ('although', 'B-SBAR'),
#   ('it', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('hard', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('tell', 'I-VP'),
#   ('from', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('$', 'B-NP'),
#   ('5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('``', 'O'),
#   ('The', 'B-NP'),
#   ('I', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('of', 'I-PP'),
#   ('Texas', 'B-ADJP'),
#   ("''", 'O'),
#   ('TV', 'I-NP'),
#   ('campaign', 'I-NP'),
#   ('.', 'O')],
#  [('So-called', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('provisions', 'I-NP'),
#   ('also', 'I-CONJP'),
#   ('merit', 'B-NP'),
#   ('a', 'B-LST'),
#   ('close', 'B-ADJP'),
#   ('inspection', 'I-NP'),
#   ('.', 'O')],
#  [('It', 'B-NP'),
#   ('would', 'B-VP'),
#   ('go', 'I-VP'),
#   ('along', 'B-PRT'),
#   ('doing', 'I-VP'),
#   ('nothing', 'B-NP'),
#   ('but', 'B-CONJP'),
#   ('#UNK#', 'I-NP'),
#   ('the', 'B-NP'),
#   ('heavy', 'B-NP'),
#   ('water', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('then', 'B-ADVP'),
#   ('at', 'B-PP'),
#   ('totally', 'B-ADJP'),
#   ('unpredictable', 'I-NP'),
#   ('times', 'I-ADVP'),
#   (',', 'O'),
#   ('it', 'B-NP'),
#   ('would', 'B-VP'),
#   ('begin', 'I-ADVP'),
#   ('producing', 'I-VP'),
#   ('excess', 'I-NP'),
#   ('heat', 'I-NP'),
#   ('for', 'B-PP'),
#   ('as', 'B-CONJP'),
#   ('long', 'I-ADVP'),
#   ('as', 'B-CONJP'),
#   ('10', 'I-ADVP'),
#   ('or', 'I-PP'),
#   ('11', 'B-NP'),
#   ('hours', 'I-NP'),
#   ('before', 'I-SBAR'),
#   ('#UNK#', 'I-NP'),
#   ('down', 'B-PRT'),
#   ('.', 'O')],
#  [('These', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('other', 'B-NP'),
#   ('modern', 'I-NP'),
#   ('trading', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('``', 'O'),
#   ('tend', 'B-VP'),
#   ('to', 'B-PP'),
#   ('promote', 'B-VP'),
#   ('dramatic', 'I-ADJP'),
#   ('shifts', 'B-VP'),
#   ('in', 'B-PP'),
#   ('assets', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('George', 'B-NP'),
#   ('Douglas', 'B-NP'),
#   (',', 'O'),
#   ('first', 'B-ADVP'),
#   ('vice', 'I-ADVP'),
#   ('president', 'I-NP'),
#   ('at', 'B-PP'),
#   ('Drexel', 'B-NP'),
#   ('Burnham', 'I-NP'),
#   ('Lambert', 'I-NP'),
#   ('Inc', 'I-NP'),
#   ('.', 'O')],
#  [('Executives', 'B-NP'),
#   ('at', 'B-PP'),
#   ('Olivetti', 'B-NP'),
#   (',', 'O'),
#   ('whose', 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('have', 'I-VP'),
#   ('been', 'I-VP'),
#   ('steadily', 'B-ADVP'),
#   ('sliding', 'B-VP'),
#   ('over', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('past', 'I-NP'),
#   ('couple', 'I-NP'),
#   ('of', 'I-PP'),
#   ('years', 'I-NP'),
#   (',', 'O'),
#   ('have', 'I-VP'),
#   ('acknowledged', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('past', 'I-NP'),
#   ('they', 'B-NP'),
#   ('have', 'I-VP'),
#   ('lagged', 'B-VP'),
#   ('at', 'B-PP'),
#   ('getting', 'I-VP'),
#   ('new', 'I-NP'),
#   ('technology', 'I-NP'),
#   ('to', 'B-PP'),
#   ('market', 'I-NP'),
#   ('.', 'O')],
#  [('Tom', 'B-NP'),
#   ('Schumacher', 'I-NP'),
#   (',', 'O'),
#   ('executive', 'I-NP'),
#   ('vice', 'I-ADVP'),
#   ('president', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('general', 'B-ADJP'),
#   ('manager', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('California', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('his', 'B-NP'),
#   ('organization', 'I-NP'),
#   ('urged', 'B-VP'),
#   ('trucking', 'B-NP'),
#   ('firms', 'I-NP'),
#   ('to', 'B-PP'),
#   ('halt', 'I-VP'),
#   ('all', 'I-ADVP'),
#   ('deliveries', 'I-NP'),
#   ('into', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Bay', 'I-NP'),
#   ('area', 'I-NP'),
#   ('yesterday', 'B-NP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('for', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('supplies', 'B-VP'),
#   ('.', 'O')],
#  [('Real-estate', 'B-NP'),
#   ('interests', 'I-NP'),
#   (',', 'O'),
#   ('for', 'B-PP'),
#   ('example', 'B-NP'),
#   (',', 'O'),
#   ('are', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('an', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('President', 'B-NP'),
#   ('Bush', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('capital-gains', 'I-NP'),
#   ('proposal', 'I-NP'),
#   (':', 'O'),
#   ('It', 'B-NP'),
#   ('does', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('include', 'I-VP'),
#   ('real-estate', 'I-NP'),
#   ('gains', 'I-NP'),
#   ('.', 'O')],
#  [('We', 'B-NP'),
#   ('expect', 'B-VP'),
#   ('a', 'B-LST'),
#   ('choppy', 'I-ADJP'),
#   ('and', 'I-UCP'),
#   ('sloppy', 'B-ADJP'),
#   ('market', 'I-NP'),
#   ('for', 'B-PP'),
#   ('a', 'B-LST'),
#   ('short', 'I-ADJP'),
#   ('period', 'I-NP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('we', 'B-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('think', 'B-VP'),
#   ('it', 'B-NP'),
#   ('will', 'B-VP'),
#   ('be', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('Sheldon', 'I-NP'),
#   ('B.', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('chairman', 'B-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Co.', 'I-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('John', 'B-NP'),
#   ('L.', 'I-NP'),
#   ('Murray', 'B-NP'),
#   (',', 'O'),
#   ('chairman', 'B-NP'),
#   ('of', 'I-PP'),
#   ('Universal', 'I-NP'),
#   ('Foods', 'I-NP'),
#   ('Corp.', 'I-NP'),
#   (',', 'O'),
#   ('were', 'B-VP'),
#   ('elected', 'I-VP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('board', 'I-NP'),
#   ('of', 'I-PP'),
#   ('this', 'B-NP'),
#   ('engine', 'I-NP'),
#   ('maker', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'), (':', 'O')],
#  [('And', 'O'),
#   ('the', 'B-NP'),
#   ('respondents', 'I-NP'),
#   ("'", 'B-NP'),
#   ('commitment', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('stock', 'I-NP'),
#   ('market', 'I-NP'),
#   ('remains', 'B-VP'),
#   ('somewhat', 'B-ADJP'),
#   ('#UNK#', 'I-NP'),
#   ('than', 'I-CONJP'),
#   ('usual', 'B-ADJP'),
#   ('.', 'O')],
#  [('Now', 'B-INTJ'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   ('new', 'I-NP'),
#   ('approach', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('available', 'B-ADJP'),
#   ('to', 'B-PP'),
#   ('building', 'I-NP'),
#   ('your', 'B-NP'),
#   ('financial', 'I-ADJP'),
#   ('portfolio', 'I-NP'),
#   ('without', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('risk', 'I-NP'),
#   (',', 'O'),
#   ('without', 'B-PP'),
#   ('extensive', 'I-NP'),
#   ('planning', 'I-VP'),
#   ('and', 'I-UCP'),
#   ('without', 'B-PP'),
#   ('hurting', 'B-VP'),
#   ('your', 'B-NP'),
#   ('life', 'I-NP'),
#   ('style', 'I-NP'),
#   ('one', 'B-NP'),
#   ('bit', 'I-ADJP'),
#   ('!', 'O')],
#  [('``', 'O'),
#   ('Losses', 'B-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('earthquake', 'I-NP'),
#   ('are', 'B-VP'),
#   ('expected', 'I-VP'),
#   ('to', 'B-PP'),
#   ('be', 'I-VP'),
#   ('of', 'I-PP'),
#   ('similar', 'B-ADJP'),
#   ('magnitude', 'I-NP'),
#   ('to', 'B-PP'),
#   ('those', 'B-NP'),
#   ('of', 'I-PP'),
#   ('Hurricane', 'B-NP'),
#   ('Hugo', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Moody', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('.', 'O')],
#  [('Frank', 'B-NP'),
#   ('Carlucci', 'I-NP'),
#   ('III', 'I-NP'),
#   ('was', 'B-VP'),
#   ('named', 'I-VP'),
#   ('to', 'B-PP'),
#   ('this', 'B-NP'),
#   ('telecommunications', 'I-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('board', 'I-NP'),
#   (',', 'O'),
#   ('filling', 'I-VP'),
#   ('the', 'B-NP'),
#   ('vacancy', 'I-NP'),
#   ('created', 'B-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('death', 'I-NP'),
#   ('of', 'I-PP'),
#   ('William', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('last', 'I-ADVP'),
#   ('May', 'B-NP'),
#   ('.', 'O')],
#  [('Most', 'B-NP'),
#   ('banking', 'I-NP'),
#   ('issues', 'I-NP'),
#   ('retreated', 'B-VP'),
#   ('after', 'B-SBAR'),
#   ('a', 'B-LST'),
#   ('sector', 'I-NP'),
#   ('downgrade', 'I-NP'),
#   ('by', 'B-PP'),
#   ('Warburg', 'I-NP'),
#   ('Securities', 'I-NP'),
#   (',', 'O'),
#   ('although', 'B-SBAR'),
#   ('National', 'I-NP'),
#   ('Westminister', 'I-NP'),
#   ('showed', 'B-VP'),
#   ('strength', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('positive', 'B-ADJP'),
#   ('comments', 'I-NP'),
#   ('from', 'B-PP'),
#   ('brokerage', 'I-NP'),
#   ('firms', 'I-NP'),
#   ('about', 'B-PP'),
#   ('its', 'B-NP'),
#   ('long-term', 'I-ADJP'),
#   ('prospects', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('approvals', 'I-NP'),
#   (':', 'O'),
#   ('Bell', 'I-NP'),
#   ('Atlantic', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('New', 'B-NP'),
#   ('Jersey', 'I-NP'),
#   ('Bell', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('General', 'B-NP'),
#   ('Dynamics', 'I-NP'),
#   ('.', 'O')],
#  [('How', 'B-ADVP'),
#   ('should', 'B-VP'),
#   ('a', 'B-LST'),
#   ('reasonable', 'B-ADJP'),
#   ('member', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('Federal', 'I-NP'),
#   ('Reserve', 'I-NP'),
#   ('Board', 'I-NP'),
#   ('interpret', 'I-VP'),
#   ('a', 'B-LST'),
#   ('congressional', 'B-NP'),
#   ('decision', 'I-NP'),
#   ('to', 'B-PP'),
#   ('put', 'I-VP'),
#   ('the', 'B-NP'),
#   ('secretary', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('board', 'I-NP'),
#   ('?', 'O')],
#  [('Assistant', 'O'),
#   ('U.S.', 'I-NP'),
#   ('Attorney', 'I-NP'),
#   ('Randy', 'B-NP'),
#   ('Mastro', 'I-NP'),
#   (',', 'O'),
#   ('who', 'B-NP'),
#   ('headed', 'I-VP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('case', 'I-NP'),
#   ('against', 'B-PP'),
#   ('the', 'B-NP'),
#   ('International', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('will', 'B-VP'),
#   ('join', 'I-VP'),
#   ('Gibson', 'B-NP'),
#   (',', 'O'),
#   ('Dunn', 'I-NP'),
#   ('&', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('its', 'B-NP'),
#   ('New', 'B-NP'),
#   ('York', 'I-NP'),
#   ('office', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('Sell', 'B-NP'),
#   ('stocks', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('are', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('doing', 'I-VP'),
#   ('well', 'I-CONJP'),
#   ('now', 'B-ADVP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('that', 'B-SBAR'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('have', 'I-VP'),
#   ('good', 'I-ADJP'),
#   ('earnings', 'I-NP'),
#   ('prospects', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Alfred', 'B-NP'),
#   ('Goldman', 'B-NP'),
#   (',', 'O'),
#   ('technical', 'B-ADJP'),
#   ('analyst', 'I-NP'),
#   ('at', 'B-PP'),
#   ('St.', 'B-NP'),
#   ('Louis-based', 'I-NP'),
#   ('A.G.', 'B-NP'),
#   ('Edwards', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Sons', 'O'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('attorney', 'I-NP'),
#   ('in', 'B-PP'),
#   ('Washington', 'B-NP'),
#   ('for', 'B-PP'),
#   ('Mr.', 'B-NP'),
#   ('Keating', 'I-NP'),
#   (',', 'O'),
#   ('declined', 'B-VP'),
#   ('to', 'B-PP'),
#   ('comment', 'I-VP'),
#   ('on', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('hearings', 'I-NP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('to', 'B-PP'),
#   ('say', 'B-INTJ'),
#   (',', 'O'),
#   ('``', 'O'),
#   ('We', 'B-NP'),
#   ('will', 'B-VP'),
#   ('be', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('several', 'B-NP'),
#   ('forums', 'I-NP'),
#   ('to', 'B-PP'),
#   ('each', 'B-NP'),
#   ('of', 'I-PP'),
#   ('these', 'B-NP'),
#   ('allegations', 'I-NP'),
#   ('at', 'B-PP'),
#   ('the', 'B-NP'),
#   ('appropriate', 'B-NP'),
#   ('time', 'I-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('The', 'B-NP'),
#   ('directors', 'I-NP'),
#   ("'", 'B-NP'),
#   ('action', 'I-NP'),
#   (',', 'O'),
#   ('taken', 'I-VP'),
#   ('Oct.', 'B-NP'),
#   ('10', 'I-ADVP'),
#   ('but', 'B-CONJP'),
#   ('announced', 'B-VP'),
#   ('Friday', 'B-NP'),
#   (',', 'O'),
#   ('had', 'B-VP'),
#   ('little', 'I-ADJP'),
#   ('or', 'I-PP'),
#   ('no', 'I-INTJ'),
#   ('effect', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('stock', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('at', 'B-PP'),
#   ('$', 'B-NP'),
#   ('4.75', 'I-NP'),
#   ('in', 'B-PP'),
#   ('light', 'B-ADJP'),
#   ('over-the-counter', 'I-NP'),
#   ('trading', 'I-NP'),
#   ('.', 'O')],
#  [('Few', 'B-NP'),
#   ('specialists', 'B-NP'),
#   ('said', 'B-VP'),
#   ('they', 'B-NP'),
#   ('expect', 'B-VP'),
#   ('the', 'B-NP'),
#   ('quake', 'I-NP'),
#   ('to', 'B-PP'),
#   ('have', 'I-VP'),
#   ('much', 'I-ADVP'),
#   ('of', 'I-PP'),
#   ('an', 'B-NP'),
#   ('effect', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('most', 'B-ADJP'),
#   ('California', 'B-NP'),
#   ('property', 'I-NP'),
#   ('values', 'I-NP'),
#   ('.', 'O')],
#  [('Food', 'I-NP'),
#   ('prices', 'I-NP'),
#   ('rose', 'B-VP'),
#   ('0.2', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('second', 'I-NP'),
#   ('month', 'I-NP'),
#   ('in', 'B-PP'),
#   ('a', 'B-LST'),
#   ('row', 'I-NP'),
#   (',', 'O'),
#   ('far', 'I-ADVP'),
#   ('slower', 'I-ADJP'),
#   ('than', 'I-CONJP'),
#   ('the', 'B-NP'),
#   ('monthly', 'B-ADVP'),
#   ('rises', 'B-VP'),
#   ('earlier', 'B-ADVP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('There', 'B-NP'),
#   ('was', 'B-VP'),
#   ('no', 'I-INTJ'),
#   ('cost', 'I-VP'),
#   ('estimate', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('second', 'I-NP'),
#   ('phase', 'I-VP'),
#   ('.', 'O')],
#  [('Some', 'B-NP'),
#   ('couples', 'I-NP'),
#   ('continue', 'I-VP'),
#   ('to', 'B-PP'),
#   ('try', 'I-VP'),
#   ('.', 'O')],
#  [('Stocks', 'B-NP'),
#   ('of', 'I-PP'),
#   ('major', 'I-NP'),
#   ('toy', 'I-NP'),
#   ('makers', 'I-NP'),
#   ('rallied', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('wake', 'I-NP'),
#   ('of', 'I-PP'),
#   ('strong', 'I-ADJP'),
#   ('third-quarter', 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('reports', 'I-NP'),
#   ('.', 'O')],
#  [('Bay', 'I-NP'),
#   ('Financial', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('may', 'B-VP'),
#   ('be', 'I-VP'),
#   ('forced', 'I-VP'),
#   ('to', 'B-PP'),
#   ('file', 'I-VP'),
#   ('under', 'B-PP'),
#   ('Chapter', 'B-NP'),
#   ('11', 'B-NP'),
#   ('if', 'I-SBAR'),
#   ('it', 'B-NP'),
#   ('ca', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('reach', 'I-VP'),
#   ('an', 'B-NP'),
#   ('agreement', 'I-NP'),
#   ('with', 'B-PP'),
#   ('its', 'B-NP'),
#   ('lenders', 'B-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('its', 'B-NP'),
#   ('debt', 'I-NP'),
#   ('burden', 'I-NP'),
#   (',', 'O'),
#   ('plunged', 'B-VP'),
#   ('1', 'B-LST'),
#   ('3\\/8', 'I-NP'),
#   ('to', 'B-PP'),
#   ('2', 'B-LST'),
#   ('1\\/8', 'I-NP'),
#   ('.', 'O')],
#  [('His', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('was', 'B-VP'),
#   ('rejected', 'B-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('programs', 'I-NP'),
#   ('have', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Rep.', 'B-NP'),
#   ('Henry', 'I-NP'),
#   ('Hyde', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('conservative', 'I-ADJP'),
#   ('Republican', 'I-NP'),
#   ('from', 'B-PP'),
#   ('Illinois', 'I-NP'),
#   ('.', 'O')],
#  [('You', 'B-NP'),
#   ("'ll", 'B-VP'),
#   ('see', 'I-VP'),
#   ('carriers', 'I-NP'),
#   ('try', 'I-VP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('some', 'B-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('price', 'I-NP'),
#   ('cutting', 'I-VP'),
#   ('that', 'B-SBAR'),
#   ('occurred', 'B-VP'),
#   ('previously', 'B-ADVP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('And', 'O'),
#   ('they', 'B-NP'),
#   ('have', 'I-VP'),
#   ('bought', 'B-VP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('500', 'I-NP'),
#   ('million', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('plans', 'B-VP'),
#   (',', 'O'),
#   ('offered', 'I-VP'),
#   ('in', 'B-PP'),
#   ('Michigan', 'B-NP'),
#   (',', 'O'),
#   ('Florida', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('Wyoming', 'B-NP'),
#   ('.', 'O')],
#  [('Meanwhile', 'B-ADVP'),
#   (',', 'O'),
#   ('Eurocom', 'B-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('had', 'B-VP'),
#   ('held', 'I-VP'),
#   ('20', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('of', 'I-PP'),
#   ('WCRS', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('ad', 'I-NP'),
#   ('unit', 'I-NP'),
#   (',', 'O'),
#   ('will', 'B-VP'),
#   ('pay', 'I-VP'),
#   ('#', 'B-ADJP'),
#   ('43.5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   ('-RRB-', 'O'),
#   ('to', 'B-PP'),
#   ('raise', 'I-VP'),
#   ('its', 'B-NP'),
#   ('stake', 'I-NP'),
#   ('to', 'B-PP'),
#   ('60', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Treasury', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('benchmark', 'I-NP'),
#   ('30-year', 'B-NP'),
#   ('bond', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('more', 'B-ADJP'),
#   ('than', 'I-CONJP'),
#   ('1\\/2', 'I-ADJP'),
#   ('point', 'I-ADVP'),
#   (',', 'O'),
#   ('or', 'I-PP'),
#   ('over', 'B-PRT'),
#   ('$', 'B-NP'),
#   ('5', 'I-NP'),
#   ('for', 'B-PP'),
#   ('each', 'B-NP'),
#   ('$', 'B-NP'),
#   ('1,000', 'I-ADJP'),
#   ('face', 'B-VP'),
#   ('amount', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('yield', 'I-VP'),
#   ('moved', 'I-VP'),
#   ('above', 'I-PP'),
#   ('8', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('first', 'B-ADVP'),
#   ('time', 'I-NP'),
#   ('since', 'B-SBAR'),
#   ('Thursday', 'B-NP'),
#   ('.', 'O')],
#  [('Yet', 'B-ADVP'),
#   ('her', 'B-NP'),
#   ('intensity', 'I-NP'),
#   ('stops', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('starts', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('music', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('results', 'I-NP'),
#   ('compare', 'I-VP'),
#   ('with', 'B-PP'),
#   ('a', 'B-LST'),
#   ('year-earlier', 'I-NP'),
#   ('net', 'B-NP'),
#   ('loss', 'I-NP'),
#   ('of', 'I-PP'),
#   ('$', 'B-NP'),
#   ('1.5', 'I-NP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('or', 'I-PP'),
#   ('seven', 'B-NP'),
#   ('cents', 'I-NP'),
#   ('a', 'B-LST'),
#   ('share', 'I-NP'),
#   (',', 'O'),
#   ('based', 'B-VP'),
#   ('on', 'B-PRT'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   ('common', 'I-ADJP'),
#   ('and', 'I-UCP'),
#   ('dilutive', 'I-NP'),
#   ('equivalents', 'I-NP'),
#   ('outstanding', 'B-ADJP'),
#   ('.', 'O')],
#  [('Revenue', 'B-NP'),
#   ('dropped', 'B-VP'),
#   ('1.6', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.21', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.23', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('.', 'O')],
#  [('Charleston', 'B-NP'),
#   ('is', 'I-INTJ'),
#   ('historic', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-CONJP'),
#   ('your', 'B-NP'),
#   ('reporter', 'I-NP'),
#   ('said', 'B-VP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('not', 'B-CONJP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-CONJP'),
#   ('he', 'B-NP'),
#   ('suggested', 'B-VP'),
#   ('.', 'O')],
#  [('This', 'B-NP'),
#   ('magazine', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('book', 'I-NP'),
#   ('publisher', 'I-NP'),
#   ('said', 'B-VP'),
#   ('three', 'B-NP'),
#   ('men', 'I-NP'),
#   ('were', 'B-VP'),
#   ('elected', 'I-VP'),
#   ('directors', 'I-NP'),
#   (',', 'O'),
#   ('increasing', 'B-VP'),
#   ('the', 'B-NP'),
#   ('board', 'I-NP'),
#   ('to', 'B-PP'),
#   ('10', 'I-ADVP'),
#   ('.', 'O')],
#  [('Among', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Guinness', 'I-NP'),
#   ('disk', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('wonders', 'B-NP'),
#   (':', 'O'),
#   ('the', 'B-NP'),
#   ('world', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('recorded', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('company', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('is', 'I-INTJ'),
#   ('retaining', 'B-NP'),
#   ('most', 'B-ADJP'),
#   ('of', 'I-PP'),
#   ('its', 'B-NP'),
#   ('wine', 'B-UCP'),
#   ('and', 'I-UCP'),
#   ('all', 'I-ADVP'),
#   ('of', 'I-PP'),
#   ('its', 'B-NP'),
#   ('soft-drink', 'I-UCP'),
#   ('interests', 'I-NP'),
#   (',', 'O'),
#   ('did', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('break', 'I-VP'),
#   ('out', 'B-PRT'),
#   ('results', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('businesses', 'I-NP'),
#   ('it', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'B-PP'),
#   ('sell', 'I-VP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('press', 'I-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('doing', 'I-VP'),
#   ('an', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('job', 'I-NP'),
#   ('.', 'O')],
#  [('Two', 'B-NP'),
#   ('rules', 'I-NP'),
#   ('in', 'B-PP'),
#   ('pending', 'B-ADJP'),
#   ('congressional', 'B-NP'),
#   ('legislation', 'I-NP'),
#   ('threaten', 'I-VP'),
#   ('to', 'B-PP'),
#   ('hinder', 'I-VP'),
#   ('leveraged', 'I-ADJP'),
#   ('buy-outs', 'B-NP'),
#   ('by', 'B-PP'),
#   ('raising', 'B-VP'),
#   ('the', 'B-NP'),
#   ('price', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('such', 'B-PP'),
#   ('deals', 'I-NP'),
#   ('by', 'B-PP'),
#   ('as', 'B-CONJP'),
#   ('much', 'I-ADVP'),
#   ('as', 'B-CONJP'),
#   ('10', 'I-ADVP'),
#   ('%', 'I-ADJP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('We', 'B-NP'),
#   ('hope', 'B-VP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('employers', 'I-NP'),
#   ("''", 'O'),
#   ('to', 'B-PP'),
#   ('recognize', 'I-VP'),
#   ('the', 'B-NP'),
#   ('problems', 'I-NP'),
#   ('so', 'B-ADJP'),
#   ('they', 'B-NP'),
#   ('can', 'B-VP'),
#   ('do', 'B-VP'),
#   ('something', 'B-NP'),
#   ('about', 'B-PP'),
#   ('them', 'B-NP'),
#   (',', 'O'),
#   ('Dr.', 'B-NP'),
#   ('Warshaw', 'I-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('year', 'I-NP'),
#   ('earlier', 'B-ADVP'),
#   ('sales', 'I-NP'),
#   ('totaled', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('francs', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('We', 'B-NP'),
#   ("'re", 'B-VP'),
#   ('encouraging', 'B-VP'),
#   ('a', 'B-LST'),
#   ('graceful', 'I-NP'),
#   ('transition', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Mary', 'I-NP'),
#   ('Kay', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('organization', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('president', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Taxpayers', 'I-NP'),
#   ('Union', 'I-NP'),
#   ('would', 'B-VP'),
#   ('like', 'B-PP'),
#   ('Congress', 'B-NP'),
#   ('to', 'B-PP'),
#   ('add', 'I-VP'),
#   ('800,000', 'I-NP'),
#   ('acres', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('system', 'I-NP'),
#   ('by', 'B-PP'),
#   ('enacting', 'B-VP'),
#   ('``', 'O'),
#   ('The', 'B-NP'),
#   ('Coastal', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Act', 'I-NP'),
#   ('of', 'I-PP'),
#   ('1989', 'I-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('Digital', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('failure', 'I-NP'),
#   ('to', 'B-PP'),
#   ('deliver', 'I-VP'),
#   ('a', 'B-LST'),
#   ('true', 'I-ADJP'),
#   ('mainframe-class', 'I-NP'),
#   ('machine', 'I-NP'),
#   ('before', 'I-SBAR'),
#   ('now', 'B-ADVP'),
#   ('may', 'B-VP'),
#   ('have', 'I-VP'),
#   ('cost', 'I-VP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ('as', 'B-CONJP'),
#   ('much', 'I-ADVP'),
#   ('as', 'B-CONJP'),
#   ('$', 'B-NP'),
#   ('1', 'B-LST'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('revenue', 'I-NP'),
#   ('in', 'B-PP'),
#   ('fiscal', 'B-NP'),
#   ('1989', 'I-NP'),
#   (',', 'O'),
#   ('Mr.', 'B-NP'),
#   ('Willman', 'I-NP'),
#   ('says', 'B-VP'),
#   ('.', 'O')],
#  [('It', 'B-NP'), ('is', 'I-INTJ'), ("n't", 'I-VP'), ('.', 'O')],
#  [('Detroit', 'B-NP'),
#   ('Edison', 'B-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('plan', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('generated', 'B-VP'),
#   ('$', 'B-NP'),
#   ('54,000', 'B-NP'),
#   ('in', 'B-PP'),
#   ('matching', 'B-VP'),
#   ('funds', 'I-NP'),
#   ('this', 'B-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-PRT'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('1988', 'B-NP'),
#   ('.', 'O')],
#  [('Along', 'B-PP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('car', 'I-NP'),
#   (',', 'O'),
#   ('Wacoal', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'B-PP'),
#   ('launch', 'I-VP'),
#   ('a', 'B-LST'),
#   ('series', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('men', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('underwear', 'I-NP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('columnist', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Atlanta', 'B-NP'),
#   ('Journal', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('Constitution', 'I-NP'),
#   ('wrote', 'B-VP'),
#   (':', 'O'),
#   ('``', 'O'),
#   ('Who', 'B-NP'),
#   ('did', 'B-VP'),
#   ('the', 'B-NP'),
#   ('research', 'I-NP'),
#   ('for', 'B-PP'),
#   ('this', 'B-NP'),
#   ('report', 'I-VP'),
#   ('?', 'O')],
#  [('Computer', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Corp.', 'I-NP'),
#   (',', 'O'),
#   ('El', 'B-NP'),
#   ('Segundo', 'I-NP'),
#   (',', 'O'),
#   ('Calif.', 'B-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Aeronautics', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('Space', 'I-NP'),
#   ('Administration', 'I-NP'),
#   ('will', 'B-VP'),
#   ('negotiate', 'I-VP'),
#   ('details', 'B-NP'),
#   ('of', 'I-PP'),
#   ('a', 'B-LST'),
#   ('contract', 'I-NP'),
#   ('valued', 'B-VP'),
#   ('at', 'B-PP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('170', 'I-NP'),
#   ('million', 'I-NP'),
#   ('to', 'B-PP'),
#   ('provide', 'I-VP'),
#   ('software', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Ames', 'B-NP'),
#   ('Research', 'I-NP'),
#   ('Center', 'I-NP'),
#   ('.', 'O')],
#  [('He', 'B-NP'),
#   ('was', 'B-VP'),
#   ('a', 'B-LST'),
#   ('``', 'O'),
#   ('socialist', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ("''", 'O'),
#   ('who', 'B-NP'),
#   ('felt', 'B-VP'),
#   ('#UNK#', 'I-NP'),
#   ('by', 'B-PP'),
#   ('West', 'I-NP'),
#   ('Germany', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('enormous', 'I-ADJP'),
#   ('postwar', 'I-NP'),
#   ('prosperity', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('the', 'B-NP'),
#   ('Bonn', 'B-NP'),
#   ('government', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('to', 'B-PP'),
#   ('recognize', 'I-VP'),
#   ('the', 'B-NP'),
#   ('legitimacy', 'B-NP'),
#   ('of', 'I-PP'),
#   ('his', 'B-NP'),
#   ('state', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Senate', 'I-NP'),
#   ('estimates', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('its', 'B-NP'),
#   ('version', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('provision', 'I-NP'),
#   ('would', 'B-VP'),
#   ('yield', 'I-VP'),
#   ('$', 'B-NP'),
#   ('17', 'I-NP'),
#   ('million', 'I-NP'),
#   ('the', 'B-NP'),
#   ('first', 'B-ADVP'),
#   ('year', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('a', 'B-LST'),
#   ('total', 'I-NP'),
#   ('of', 'I-PP'),
#   ('$', 'B-NP'),
#   ('409', 'I-NP'),
#   ('million', 'I-NP'),
#   ('over', 'B-PRT'),
# ...
#   ('such', 'B-PP'),
#   ('a', 'B-LST'),
#   ('dividend', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('trust', 'I-NP'),
#   ('added', 'B-VP'),
#   (',', 'O'),
#   ('before', 'I-SBAR'),
#   ('results', 'I-NP'),
#   ('are', 'B-VP'),
#   ('available', 'B-ADJP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('first', 'B-ADVP'),
#   ('quarter', 'I-NP'),
#   ('of', 'I-PP'),
#   ('1990', 'B-NP'),
#   ('.', 'O')],
#  [('Sales', 'B-NP'),
#   ('rose', 'B-VP'),
#   ('5.2', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('2.04', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('the', 'B-NP'),
#   ('previous', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Data', 'I-NP'),
#   ('for', 'B-PP'),
#   ('1987', 'B-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('Systems', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('the', 'B-NP'),
#   ('Japan', 'B-NP'),
#   ('Human', 'B-NP'),
#   ('Relations', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('also', 'I-CONJP'),
#   ('indicate', 'I-VP'),
#   ('that', 'B-SBAR'),
#   ('Japanese', 'B-NP'),
#   ('employers', 'I-NP'),
#   ('adopt', 'I-VP'),
#   ('four', 'B-NP'),
#   ('of', 'I-PP'),
#   ('five', 'B-NP'),
#   ('suggestions', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('their', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('counterparts', 'I-NP'),
#   ('accept', 'I-VP'),
#   ('just', 'I-CONJP'),
#   ('one', 'B-NP'),
#   ('in', 'B-PP'),
#   ('four', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('returns', 'I-NP'),
#   ('landed', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('hands', 'I-NP'),
#   ('of', 'I-PP'),
#   ('an', 'B-NP'),
#   ('Internal', 'I-NP'),
#   ('Revenue', 'B-NP'),
#   ('Service', 'I-NP'),
#   ('criminal', 'B-ADJP'),
#   ('investigator', 'I-NP'),
#   (',', 'O'),
#   ('Samuel', 'B-NP'),
#   ('James', 'B-NP'),
#   ('Baker', 'I-NP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Kelly', 'I-NP'),
#   ('built', 'I-VP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('high-yield', 'B-NP'),
#   ('bond', 'I-NP'),
#   ('group', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('a', 'B-LST'),
#   ('minor', 'I-ADJP'),
#   ('player', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('junk-bond', 'I-NP'),
#   ('arena', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('result', 'I-VP'),
#   ('is', 'I-INTJ'),
#   ('that', 'B-SBAR'),
#   ('some', 'B-NP'),
#   ('franchisees', 'I-NP'),
#   ('are', 'B-VP'),
#   ('running', 'I-VP'),
#   ('hard', 'I-ADJP'),
#   ('just', 'I-CONJP'),
#   ('to', 'B-PP'),
#   ('stay', 'I-VP'),
#   ('even', 'B-ADVP'),
#   (',', 'O'),
#   ('laying', 'I-VP'),
#   ('off', 'B-PRT'),
#   ('middle', 'I-NP'),
#   ('managers', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('working', 'I-VP'),
#   ('harder', 'B-ADJP'),
#   ('to', 'B-PP'),
#   ('make', 'I-VP'),
#   ('less', 'B-ADJP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('&', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('small', 'I-ADJP'),
#   ('New', 'B-NP'),
#   ('York', 'I-NP'),
#   ('shop', 'I-NP'),
#   (',', 'O'),
#   ('is', 'I-INTJ'),
#   ('asking', 'I-VP'),
#   ('magazine', 'I-NP'),
#   ('ad', 'I-NP'),
#   ('representatives', 'I-NP'),
#   ('to', 'B-PP'),
#   ('tell', 'I-VP'),
#   ('it', 'B-NP'),
#   ('when', 'B-ADVP'),
#   ('major', 'I-NP'),
#   ('advertising', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('will', 'B-VP'),
#   ('run', 'I-VP'),
#   ('in', 'B-PP'),
#   ('their', 'B-NP'),
#   ('publications', 'I-NP'),
#   ('.', 'O')],
#  [('In', 'B-PP'),
#   ('addition', 'B-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('scheduled', 'I-VP'),
#   ('to', 'B-PP'),
#   ('unveil', 'I-VP'),
#   ('plans', 'B-VP'),
#   ('for', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('Philippine', 'B-NP'),
#   ('Airlines', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('national', 'B-ADJP'),
#   ('carrier', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('effort', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('lawyer', 'I-NP'),
#   ('and', 'I-UCP'),
#   ('business', 'I-NP'),
#   ('columnist', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('calls', 'B-VP'),
#   ('``', 'O'),
#   ('the', 'B-NP'),
#   ('bellwether', 'O'),
#   ('of', 'I-PP'),
#   ('privatization', 'I-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('An', 'B-NP'),
#   ('experimental', 'I-NP'),
#   ('vaccine', 'I-NP'),
#   ('can', 'B-VP'),
#   ('alter', 'I-VP'),
#   ('the', 'B-NP'),
#   ('immune', 'I-ADJP'),
#   ('response', 'I-NP'),
#   ('of', 'I-PP'),
#   ('people', 'B-NP'),
#   ('infected', 'I-VP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('AIDS', 'B-NP'),
#   ('virus', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-LST'),
#   ('prominent', 'I-ADJP'),
#   ('U.S.', 'I-NP'),
#   ('scientist', 'I-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('In', 'B-PP'),
#   ('addition', 'B-NP'),
#   (',', 'O'),
#   ('long-term', 'I-ADJP'),
#   ('debt', 'I-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('trimmed', 'I-VP'),
#   ('to', 'B-PP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('72', 'B-NP'),
#   ('million', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('96', 'I-NP'),
#   ('million', 'I-NP'),
#   ('since', 'B-SBAR'),
#   ('Jan.', 'B-NP'),
#   ('1', 'B-LST'),
#   ('.', 'O')],
#  [('New', 'B-NP'),
#   ('York', 'I-NP'),
#   ('real', 'B-ADJP'),
#   ('estate', 'I-NP'),
#   ('brokerage', 'I-NP'),
#   ('Edward', 'B-NP'),
#   ('S.', 'I-NP'),
#   ('Gordon', 'B-NP'),
#   ('Co.', 'I-NP'),
#   ('will', 'B-VP'),
#   ('have', 'I-VP'),
#   ('the', 'B-NP'),
#   ('difficult', 'I-ADJP'),
#   ('task', 'I-NP'),
#   ('of', 'I-PP'),
#   ('finding', 'I-VP'),
#   ('new', 'I-NP'),
#   ('tenants', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'),
#   ('revenue', 'I-NP'),
#   ('was', 'B-VP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-PRT'),
#   ('12', 'I-NP'),
#   ('%', 'I-ADJP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   ('last', 'I-ADVP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('As', 'B-SBAR'),
#   ('former', 'I-NP'),
#   ('Ambassador', 'I-NP'),
#   ('to', 'B-PP'),
#   ('Costa', 'B-NP'),
#   ('Rica', 'I-NP'),
#   ('Francis', 'B-NP'),
#   ('J.', 'I-NP'),
#   ('McNeil', 'I-NP'),
#   ('testified', 'B-VP'),
#   ('before', 'I-SBAR'),
#   ('the', 'B-NP'),
#   ('subcommittee', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('Reagan', 'I-NP'),
#   ('administration', 'I-NP'),
#   ('knew', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('Gen.', 'B-NP'),
#   ('Noriega', 'I-NP'),
#   ('was', 'B-VP'),
#   ('involved', 'I-ADJP'),
#   ('with', 'B-PP'),
#   ('narcotics', 'B-NP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('made', 'I-VP'),
#   ('a', 'B-LST'),
#   ('decision', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('summer', 'I-NP'),
#   ('of', 'I-PP'),
#   ('1986', 'B-NP'),
#   ('``', 'O'),
#   ('to', 'B-PP'),
#   ('put', 'I-VP'),
#   ('Gen.', 'B-NP'),
#   ('Noriega', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('the', 'B-NP'),
#   ('shelf', 'B-NP'),
#   ('until', 'B-SBAR'),
#   ('Nicaragua', 'B-NP'),
#   ('was', 'B-VP'),
#   ('settled', 'B-VP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('Retired', 'B-NP'),
#   ('army', 'I-NP'),
#   ('Chief', 'I-NP'),
#   ('of', 'I-PP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('an', 'B-NP'),
#   ('interview', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('he', 'B-NP'),
#   ('suggested', 'B-VP'),
#   ('in', 'B-PP'),
#   ('May', 'B-NP'),
#   ('1987', 'B-NP'),
#   ('that', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('cancel', 'I-VP'),
#   ('the', 'B-NP'),
#   ('Bofors', 'I-NP'),
#   ('contract', 'I-NP'),
#   ('.', 'O')],
#  [('Sales', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('quarter', 'I-NP'),
#   ('rose', 'B-VP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.11', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.03', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'I-NP'), ('#UNK#', 'I-NP'), (':', 'O')],
#  [('He', 'B-NP'),
#   ('knew', 'B-VP'),
#   ('which', 'B-NP'),
#   ('local', 'B-ADJP'),
#   ('luminaries', 'I-NP'),
#   ('had', 'B-VP'),
#   ('been', 'I-VP'),
#   ('caught', 'I-VP'),
#   ('driving', 'I-VP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('had', 'B-VP'),
#   ('been', 'I-VP'),
#   ('found', 'B-VP'),
#   ('with', 'B-PP'),
#   ('their', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('I', 'B-NP'),
#   ('suggest', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('The', 'B-NP'),
#   ('Wall', 'B-NP'),
#   ('Street', 'I-NP'),
#   ('Journal', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('as', 'B-CONJP'),
#   ('well', 'I-CONJP'),
#   ('as', 'B-CONJP'),
#   ('other', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('news', 'I-NP'),
#   ('publications', 'I-NP'),
#   ('of', 'I-PP'),
#   ('like', 'B-PP'),
#   ('mind', 'B-VP'),
#   ('-RRB-', 'O'),
#   ('should', 'B-VP'),
#   ('put', 'I-VP'),
#   ('its', 'B-NP'),
#   ('money', 'I-NP'),
#   ('where', 'B-ADVP'),
#   ('its', 'B-NP'),
#   ('mouth', 'I-ADJP'),
#   ('is', 'I-INTJ'),
#   (':', 'O'),
#   ('#UNK#', 'I-NP'),
#   ('computer', 'I-NP'),
#   ('equipment', 'I-NP'),
#   ('to', 'B-PP'),
#   ('replace', 'I-VP'),
#   ('that', 'B-SBAR'),
#   ('damaged', 'I-ADJP'),
#   ('at', 'B-PP'),
#   ('El', 'B-NP'),
#   ('Espectador', 'I-NP'),
#   (',', 'O'),
#   ('buy', 'I-VP'),
#   ('ad', 'I-NP'),
#   ('space', 'I-NP'),
#   (',', 'O'),
#   ('publish', 'I-VP'),
#   ('stories', 'I-NP'),
#   ('under', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'I-PP'),
#   ('El', 'B-NP'),
#   ('Espectador', 'I-NP'),
#   ('journalists', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('amount', 'I-NP'),
#   ('would', 'B-VP'),
#   ('help', 'I-VP'),
#   ('Los', 'B-NP'),
#   ('Angeles', 'I-NP'),
#   ('cope', 'I-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('first', 'B-ADVP'),
#   ('few', 'I-NP'),
#   ('weeks', 'I-NP'),
#   ('after', 'B-SBAR'),
#   ('its', 'B-NP'),
#   ('own', 'I-NP'),
#   ('anticipated', 'I-VP'),
#   ('quake', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('waiting', 'I-VP'),
#   ('for', 'B-PP'),
#   ('federal', 'I-NP'),
#   ('assistance', 'I-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('Your', 'B-NP'),
#   ('Oct.', 'B-NP'),
#   ('12', 'I-NP'),
#   ('editorial', 'I-NP'),
#   ('``', 'O'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('?', 'O'),
#   ("''", 'O'),
#   ('correctly', 'B-VP'),
#   ('states', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('I', 'B-NP'),
#   ('was', 'B-VP'),
#   ('critical', 'I-ADJP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('Bush', 'I-NP'),
#   ('administration', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('failure', 'I-NP'),
#   ('to', 'B-PP'),
#   ('have', 'I-VP'),
#   ('any', 'B-NP'),
#   ('plan', 'I-NP'),
#   ('in', 'B-PP'),
#   ('place', 'I-VP'),
#   ('to', 'B-PP'),
#   ('respond', 'I-VP'),
#   ('in', 'B-PP'),
#   ('a', 'B-LST'),
#   ('#UNK#', 'I-NP'),
#   ('fashion', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('opportunities', 'I-NP'),
#   ('to', 'B-PP'),
#   ('oust', 'I-VP'),
#   ('Manuel', 'I-NP'),
#   ('Noriega', 'I-NP'),
#   ('presented', 'B-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('attempted', 'B-VP'),
#   ('military', 'B-ADJP'),
#   ('coup', 'I-NP'),
#   ('on', 'B-PRT'),
#   ('Oct.', 'B-NP'),
#   ('3', 'B-LST'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Bakes', 'I-NP'),
#   ('declined', 'B-VP'),
#   ('to', 'B-PP'),
#   ('give', 'I-VP'),
#   ('out', 'B-PRT'),
#   ('Eastern', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('daily', 'B-ADVP'),
#   ('losses', 'I-NP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('said', 'B-VP'),
#   ('he', 'B-NP'),
#   ('did', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('expect', 'B-VP'),
#   ('Eastern', 'B-NP'),
#   ('would', 'B-VP'),
#   ('have', 'I-VP'),
#   ('to', 'B-PP'),
#   ('dip', 'I-VP'),
#   ('into', 'B-PP'),
#   ('the', 'B-NP'),
#   ('cash', 'B-NP'),
#   ('from', 'B-PP'),
#   ('asset', 'I-NP'),
#   ('sales', 'I-NP'),
#   ('currently', 'B-ADVP'),
#   ('held', 'I-VP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('What', 'B-NP'),
#   ('happens', 'B-VP'),
#   ('if', 'I-SBAR'),
#   ('the', 'B-NP'),
#   ('sponsors', 'I-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('have', 'I-VP'),
#   ('the', 'B-NP'),
#   ('cash', 'B-NP'),
#   ('to', 'B-PP'),
#   ('pay', 'I-VP'),
#   ('the', 'B-NP'),
#   ('tuitions', 'I-NP'),
#   ('?', 'O')],
#  [('He', 'B-NP'),
#   ('said', 'B-VP'),
#   ('he', 'B-NP'),
#   ('monitors', 'I-NP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('figures', 'I-NP'),
#   (',', 'O'),
#   ('but', 'B-CONJP'),
#   ('does', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('give', 'I-VP'),
#   ('them', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('importance', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-CONJP'),
#   ('some', 'B-NP'),
#   ('private', 'B-ADJP'),
#   ('and', 'I-UCP'),
#   ('government', 'I-NP'),
#   ('economists', 'I-NP'),
#   ('have', 'I-VP'),
#   ('suggested', 'B-VP'),
#   ('.', 'O')],
#  [('Dr.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('city', 'I-NP'),
#   ('health', 'I-NP'),
#   ('director', 'I-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('his', 'B-NP'),
#   ('staff', 'I-NP'),
#   ('suspects', 'B-VP'),
#   ('the', 'B-NP'),
#   ('hepatitis', 'B-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('can', 'B-VP'),
#   ('be', 'I-VP'),
#   ('highly', 'I-ADJP'),
#   ('contagious', 'I-NP'),
#   (',', 'O'),
#   ('was', 'B-VP'),
#   ('spread', 'I-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('cafeteria', 'I-NP'),
#   ('worker', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('virus', 'I-NP'),
#   ('.', 'O')],
#  [('Hewlett-Packard', 'B-NP'),
#   ('Co.', 'I-NP'),
#   ('also', 'I-CONJP'),
#   ('has', 'B-VP'),
#   ('begun', 'I-VP'),
#   ('to', 'B-PP'),
#   ('gain', 'I-NP'),
#   ('share', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('whole', 'B-ADJP'),
#   ('computer-integrated-manufacturing', 'I-NP'),
#   ('arena', 'I-NP'),
#   ('.', 'O')],
#  [('Georgia', 'B-NP'),
#   ('Pacific', 'I-NP'),
#   ('Corp.', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-PRT'),
#   ('$', 'B-NP'),
#   ('1.25', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('58', 'B-NP'),
#   (',', 'O'),
#   ('and', 'I-UCP'),
#   ('#UNK#', 'I-NP'),
#   ('Inc.', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-PRT'),
#   ('$', 'B-NP'),
#   ('3', 'B-LST'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('both', 'B-NP'),
#   ('reported', 'B-VP'),
#   ('strong', 'I-ADJP'),
#   ('profits', 'I-NP'),
#   ('.', 'O')],
#  [('Japanese', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('maker', 'I-NP'),
#   ('Daikin', 'I-NP'),
#   ('Industries', 'I-NP'),
#   ('Ltd.', 'I-NP'),
#   ('was', 'B-VP'),
#   ('fined', 'B-VP'),
#   ('two', 'B-NP'),
#   ('million', 'I-NP'),
#   ('yen', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('14,000', 'I-NP'),
#   ('-RRB-', 'O'),
#   ('for', 'B-PP'),
#   ('exporting', 'I-VP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Soviet', 'I-NP'),
#   ('Union', 'I-NP'),
#   ('a', 'B-LST'),
#   ('chemical', 'I-NP'),
#   ('solution', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('could', 'B-VP'),
#   ('be', 'I-VP'),
#   ('used', 'I-VP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'I-NP'),
#   ('systems', 'I-NP'),
#   ('.', 'O')],
#  [('October', 'B-NP'),
#   ('is', 'I-INTJ'),
#   ('a', 'B-LST'),
#   ('critical', 'I-ADJP'),
#   ('month', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('privatization', 'I-NP'),
#   ('program', 'I-NP'),
#   ('.', 'O')],
#  [('Since', 'B-SBAR'),
#   ('40', 'B-NP'),
#   ('%', 'I-ADJP'),
#   ('of', 'I-PP'),
#   ('skiers', 'I-NP'),
#   ('are', 'B-VP'),
#   ('parents', 'B-NP'),
#   (',', 'O'),
#   ('many', 'B-NP'),
#   ('slopes', 'I-NP'),
#   ('are', 'B-VP'),
#   ('building', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('expanding', 'B-VP'),
#   ('ski', 'I-NP'),
#   ('schools', 'B-NP'),
#   ('and', 'I-UCP'),
#   ('adding', 'B-VP'),
#   ('entertainment', 'I-NP'),
#   ('for', 'B-PP'),
#   ('kids', 'B-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('merger', 'I-NP'),
#   ('is', 'I-INTJ'),
#   ('proceeding', 'I-VP'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('plan', 'I-NP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('as', 'B-CONJP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('withdrawal', 'I-NP'),
#   ('of', 'I-PP'),
#   ('the', 'B-NP'),
#   ('Deloitte', 'B-NP'),
#   ('U.K.', 'I-NP'),
#   ('firm', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('he', 'B-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('Elected', 'B-VP'),
#   ('to', 'B-PP'),
#   ('Congress', 'B-NP'),
#   ('as', 'B-CONJP'),
#   ('a', 'B-LST'),
#   ('``', 'O'),
#   ('#UNK#', 'I-NP'),
#   ('baby', 'I-NP'),
#   ("''", 'O'),
#   ('in', 'B-PP'),
#   ('1974', 'B-NP'),
#   (',', 'O'),
#   ('he', 'B-NP'),
#   ('ran', 'B-VP'),
#   ('for', 'B-PP'),
#   ('governor', 'B-NP'),
#   ('three', 'B-NP'),
#   ('years', 'I-NP'),
#   ('later', 'B-ADVP'),
#   ('.', 'O')],
#  [('Only', 'B-ADVP'),
#   ('a', 'B-LST'),
#   ('few', 'I-NP'),
#   ('books', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('reading', 'B-VP'),
#   ('room', 'I-NP'),
#   ('.', 'O')],
#  ...]

# %%
# Evaluation of ES


# !python3 EvalScript/evalResult.py EN/dev.out EN/dev_try.out
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Manage App Execution Aliases.

# %% [markdown]
# # Part 2

# %%
for i,k in enumerate(tag_count):
    print(i,k)
# Out:
# 0 B-NP
# 1 I-NP
# 2 B-VP
# 3 B-ADVP
# 4 B-ADJP
# 5 I-ADJP
# 6 B-PP
# 7 O
# 8 B-SBAR
# 9 I-VP
# 10 I-ADVP
# 11 B-PRT
# 12 I-PP
# 13 B-CONJP
# 14 I-CONJP
# 15 B-INTJ
# 16 I-INTJ
# 17 I-SBAR
# 18 B-UCP
# 19 I-UCP
# 20 B-LST

# %% [markdown]
# #### 2a, 10 points

# %%
def get_vocab(filepath):
#     import collections #used for counting
    vocab = set()
    with open(filepath, 'r', encoding='utf-8') as file:
        # reading file line-by-line
        for line in file:
            stripped_line = line.strip() #removes the /n and then splits it to separete the word and its label
            if stripped_line:  # check if there even is a word or tag in the line
                word, tag = stripped_line.split()  # Split line into word and tag
                vocab.add(word) #doesnt add duplicates

    return vocab

# %%
def gettt(filepath):
    vocab = set()
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
#             else:
            word = line.split()
            vocab.update(word)
    return vocab

# %%
vocabu = get_vocab('EN/train')

# %%
print("24" not in vocabu)
# Out:
# False

# %%
vv = gettt('EN/dev.in')

# %%
print(vv)
# Out:
# {'Crutcher', 'summer', 'day', 'mortality', 'Stephanie', 'Turner', 'races', 'an', 'Cable', 'Du', 'euphoria', 'cuts', 'Budweiser', 'Board', 'inundated', 'parliament', 'happens', 'eye', 'Disk', 'June', 'reasonable', 'leaving', 'reserves', 'River', 'redeemed', 'equities', 'interview', 'U.S.', 'jobs', 'first-ever', 'ages', 'might', 'commission', 'rapid', 'individual', 'environmental', 'explain', 'assault', 'banning', 'communists', 'nevertheless', 'He', 'curbs', '43', 'payment', 'rein', 'sporadic', 'overall', 'pleased', 'while', '6.94', 'declining', 'Public', 'steel', 'Roberts', 'audit', 'operating', 'chances', 'COPPER', 'representatives', 'Paramount-MCA', 'treatment', 'forward', '450,000', 'represent', 'Nausea', 'luminaries', 'arrive', 'Net', 'tumble', 'assurances', 'utilities', 'would', 'principal', 'committed', 'generates', 'had', 'turning', 'likewise', 'Railroad', 'Herrera', 'undo', 'successors', 'hot-dipped', 'live', 'Baden-Wuerttemberg', 'emergency-medical', 'gone', 'repeated', 'scalp', 'being', 'consumers', 'War', 'Now', 'researchers', 'Helpless', 'import', 'case', '110', 'paramount', '10,000', 'convertible', 'Lake', 'overheated', 'disloyalty', '60', 'competing', 'gap', 'ends', 'prices', 'denied', 'smuggling', 'moment', 'Traders', 'Rican', 'roll', 'Little', 'moves', 'acrimonious', '7.937', '32', '1.55', 'offenders', 'Physics', 'benchmark', 'prompting', '50,000', 'song', 'substitute', 'forget', 'luxury', 'Demand', '20.75', 'various', 'full', 'essential', 'General', 'additional', 'DEPARTMENT', 'evaporated', '44', 'contend', 'nose', 'laid', 'yesterday', 'Fiat', 'rose', 'broad', 'several', 'hatched', 'Cela', '198', 'enormous', 'planes', 'Lot', 'drowned', 'citizens', 'disk', 'household', 'local', 'achievement', 'upon', '2009', 'further', 'inspection', 'McDonald', 'private', 'CALLS', 'Southfield', 'prime', 'wake', 'basically', 'places', 'railroad', 'concerned', 'bit', 'Berlin', '190.125', 'ending', '365-day', 'Such', 'straight', 'Schaefer', 'comic', 'transfer', 'recruit', 'Honecker', 'authority', '10.958', 'number', '2001', 'part-time', 'sidewalks', 'spoke', 'XR4Ti', 'Poppenberg', 'leveraged', 'professor', 'PATOIS', 'Comvik', 'transmissions', 'unusual', 'Conn.', 'simple', 'Mehta', 'ourselves', 'Palma', 'Galveston-Houston', 'Piccolino', 'happy', 'fail', 'Weekly', 'Juliano', 'turbulence', 'Far', 'AT&T', 'Wyss', 'marks', 'gasolines', 'toward', 'Daylight', 'matching', '46', 'floor', 'report', '3\\/8', 'Axe', 'voices', 'roster', 'soft', 'surprised', 'views', 'Resources', '1,500', 'replies', 'put', 'Cross', 'amendment', 'Chancellor', 'snagged', 'likes', 'These', 'unimportant', 'stick', 'tip', 'how', 'County', '85', '80,000', 'argued', '19,395', 'Warner', '5.5', 'Morgenzon', 'Professional', 'Republicans', 'franchise', 'member', 'affiliated', 'T.', 'last', 'Review', 'fit', 'damage', 'abortions', 'museum', 'broken', 'employee', 'remained', 'Penn', 'destroy', 'corporate-earnings', 'Cambodian', 'Twelve', 'Merry', 'Underwriters', 'Sidorenko', 'sails', 'senior', 'chairman', 'hours', 'Angeles-based', 'Cigna', 'dress', 'pleasure', 'funding', 'Regalia', 'Quick', 'Spooked', 'centers', '16-story', 'contain', 'prominent', 'reiterating', 'comments', 'designated', 'sovereignty', 'cans', 'response', 'non-communists', 'post-1987', 'excess', 'shielded', 'clear', 'confident', 'Belli', 'industrials', 'weeks', 'flooded', 'publish', 'wells', 'supervised', 'phonebook', 'landed', 'Alfred', 'less-developed', 'unsurpassed', 'Works', 'Generation', 'tenants', 'travel', 'news-oriented', 'regulators', 'Contel', '691.09', 'Finance', 'eager', 'closer', 'paper', 'currently', 'types', 'scrutiny', 'trying', 'battling', '300-day', 'just', 'sound', 'Coke', 'only', 'Genetics', 'feeling', 'do', 'eased', 'III', 'returns', 'US$', 'Frank', 'begin', 'badly', 'reaffirming', 'brushed', 'mistakenly', 'program-trading', 'superb', 'currency', 'split', '2.75', 'votes', 'lawsuit', 'scrambling', 'Prudential', 'mysterious', 'thank', 'coup', 'collateral', 'themselves', 'fresh', 'inquiries' ...

# %%
def check_new_words(training_set, test_set):
    # Use set difference to find words in the test set that aren't in the training set
    new_words = test_set - training_set
    
    # Return True if there are new words, otherwise False
    return len(new_words) > 0, new_words

x,z = check_new_words(vocabu, vv)
print(len(z))
print(len(vv))
print(len(vocabu))
# Out:
# 1284
# 6003
# 18212

# %%
def process_file_for_transitions(filepath):
    # we make use of the default library "collections" to make processing the tags and word-tag pairs easier
    import collections
    transition_count = collections.defaultdict(int) #y_u to y_v, including start and stop

    tag_count = collections.defaultdict(int)  # counting for tags
    start_counter = 0
    stop_counter = 0
    
    START = "START"
    STOP = "STOP"
    previous_tag = START

    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            stripped_line = line.strip()
            if stripped_line:
                word, tag = stripped_line.split()
                transition_count[(previous_tag, tag)] += 1
                if previous_tag == "START":
                    start_counter += 1
                tag_count[tag] += 1
                previous_tag = tag
            else:  # when the sentence has ended
                transition_count[(previous_tag, STOP)] += 1
                stop_counter += 1
                previous_tag = START  # reset for the next sentence
    tag_count["START"] = start_counter
    tag_count["STOP"] = stop_counter

    return transition_count, tag_count

# %%
transition_count, tag_count = process_file_for_transitions('EN/train')

# %%
transition_count
# Out:
# defaultdict(int,
#             {('START', 'B-NP'): 4966,
#              ('B-NP', 'I-NP'): 32390,
#              ('I-NP', 'B-VP'): 7365,
#              ('B-VP', 'B-ADVP'): 570,
#              ('B-ADVP', 'B-ADJP'): 59,
#              ('B-ADJP', 'I-ADJP'): 490,
#              ('I-ADJP', 'I-ADJP'): 84,
#              ('I-ADJP', 'B-PP'): 164,
#              ('B-PP', 'B-NP'): 17064,
#              ('I-NP', 'B-PP'): 8544,
#              ('I-NP', 'O'): 12410,
#              ('O', 'O'): 2710,
#              ('O', 'B-ADJP'): 209,
#              ('B-NP', 'B-VP'): 6164,
#              ('B-VP', 'B-PP'): 1803,
#              ('I-NP', 'I-NP'): 22201,
#              ('O', 'STOP'): 7598,
#              ('B-VP', 'B-SBAR'): 467,
#              ('B-SBAR', 'B-NP'): 1657,
#              ('B-VP', 'B-NP'): 6304,
#              ('B-VP', 'O'): 1231,
#              ('O', 'B-NP'): 8288,
#              ('I-NP', 'B-NP'): 2601,
#              ('B-ADVP', 'B-PP'): 608,
#              ('B-VP', 'I-VP'): 6828,
#              ('I-VP', 'B-NP'): 3610,
#              ('O', 'B-VP'): 2746,
#              ('I-VP', 'I-VP'): 3331,
#              ('B-NP', 'O'): 3830,
#              ('B-NP', 'B-PP'): 2744,
#              ('I-VP', 'B-PP'): 1507,
#              ('B-PP', 'B-PP'): 340,
#              ('B-NP', 'B-NP'): 1367,
#              ('I-NP', 'B-SBAR'): 348,
#              ('B-SBAR', 'B-VP'): 73,
#              ('B-NP', 'B-ADVP'): 464,
#              ('B-ADVP', 'B-NP'): 750,
#              ('B-ADVP', 'I-ADVP'): 310,
#              ('I-ADVP', 'B-NP'): 68,
#              ('START', 'B-PP'): 833,
#              ('I-VP', 'B-SBAR'): 134,
#              ('I-VP', 'B-ADVP'): 382,
#              ('B-ADVP', 'O'): 946,
#              ('I-NP', 'B-ADVP'): 837,
#              ('I-ADVP', 'B-ADVP'): 11,
#              ('O', 'B-PP'): 1197,
#              ('START', 'O'): 1087,
#              ('I-VP', 'O'): 576,
#              ('B-VP', 'B-PRT'): 204,
#              ('B-PRT', 'B-NP'): 237,
#              ('B-ADVP', 'B-VP'): 770,
#              ('O', 'B-ADVP'): 697,
#              ('B-PP', 'B-VP'): 489,
#              ('B-NP', 'B-ADJP'): 152,
#              ('B-ADJP', 'B-PP'): 428,
#              ('I-ADVP', 'O'): 119,
#              ('B-VP', 'B-VP'): 132,
#              ('O', 'B-SBAR'): 385,
#              ('I-ADJP', 'B-NP'): 51,
#              ('B-NP', 'B-SBAR'): 161,
#              ('B-VP', 'B-ADJP'): 716,
#              ('B-ADJP', 'B-VP'): 194,
#              ('I-NP', 'B-ADJP'): 224,
#              ('B-ADJP', 'O'): 450,
#              ('B-ADJP', 'B-NP'): 91,
#              ('START', 'B-ADVP'): 416,
#              ('B-PP', 'O'): 156,
#              ('B-ADVP', 'B-SBAR'): 58,
#              ('I-VP', 'B-VP'): 84,
#              ('I-ADJP', 'O'): 184,
#              ('START', 'B-ADJP'): 25,
#              ('B-PP', 'I-PP'): 207,
#              ('I-PP', 'B-NP'): 175,
#              ('B-ADVP', 'B-ADVP'): 58,
#              ('START', 'B-SBAR'): 173,
#              ('I-PP', 'B-VP'): 7,
#              ('I-ADJP', 'B-SBAR'): 35,
#              ('B-ADJP', 'B-ADVP'): 28,
#              ('B-PP', 'B-ADJP'): 48,
#              ('B-PRT', 'B-PP'): 113,
#              ('I-ADVP', 'B-PP'): 56,
#              ('I-VP', 'B-ADJP'): 295,
#              ('I-ADVP', 'I-ADVP'): 53,
#              ('I-VP', 'B-PRT'): 237,
#              ('B-ADJP', 'B-SBAR'): 66,
#              ('START', 'B-CONJP'): 2,
#              ('B-CONJP', 'I-CONJP'): 46,
#              ('I-CONJP', 'B-NP'): 28,
#              ('START', 'B-VP'): 143,
#              ('B-SBAR', 'B-PP'): 27,
#              ('B-NP', 'B-PRT'): 17,
#              ('I-ADVP', 'B-SBAR'): 29,
#              ('B-PRT', 'B-ADVP'): 14,
#              ('I-NP', 'STOP'): 43,
#              ('B-PRT', 'O'): 74,
#              ('O', 'B-INTJ'): 14,
#              ('B-INTJ', 'I-INTJ'): 5,
#              ('I-INTJ', 'O'): 5,
#              ('I-PP', 'B-ADJP'): 1,
#              ('B-INTJ', 'O'): 16,
#              ('B-SBAR', 'B-SBAR'): 16,
#              ('I-PP', 'B-PP'): 14,
#              ('I-ADVP', 'B-VP'): 21,
#              ('B-PP', 'B-ADVP'): 61,
#              ('B-SBAR', 'O'): 54,
#              ('B-SBAR', 'B-ADVP'): 17,
#              ('B-INTJ', 'B-VP'): 2,
#              ('I-PP', 'O'): 9,
#              ('I-ADJP', 'B-VP'): 40,
#              ('START', 'B-INTJ'): 10,
#              ('B-SBAR', 'I-SBAR'): 48,
#              ('I-SBAR', 'B-NP'): 46,
#              ('B-PP', 'B-SBAR'): 18,
#              ('I-NP', 'B-PRT'): 7,
#              ('O', 'B-CONJP'): 25,
#              ('I-CONJP', 'I-CONJP'): 18,
#              ('I-CONJP', 'B-PP'): 7,
#              ('I-ADJP', 'B-ADVP'): 8,
#              ('B-PRT', 'B-VP'): 20,
#              ('B-PRT', 'B-SBAR'): 9,
#              ('I-PP', 'I-PP'): 16,
#              ('B-VP', 'B-CONJP'): 3,
#              ('I-CONJP', 'B-VP'): 10,
#              ('B-PP', 'STOP'): 4,
#              ('B-SBAR', 'B-ADJP'): 6,
#              ('I-SBAR', 'B-PP'): 1,
#              ('B-PRT', 'B-ADJP'): 1,
#              ('I-ADJP', 'B-ADJP'): 7,
#              ('I-NP', 'B-CONJP'): 11,
#              ('I-ADVP', 'B-ADJP'): 6,
#              ('B-NP', 'STOP'): 11,
#              ('B-NP', 'B-UCP'): 1,
#              ('B-UCP', 'I-UCP'): 1,
#              ('I-UCP', 'I-UCP'): 3,
#              ('I-UCP', 'B-NP'): 1,
#              ('O', 'B-PRT'): 1,
#              ('B-ADJP', 'B-PRT'): 1,
#              ('START', 'B-LST'): 8,
#              ('B-LST', 'O'): 11,
#              ('B-ADJP', 'B-ADJP'): 2,
#              ('B-ADVP', 'B-CONJP'): 2,
#              ('B-CONJP', 'O'): 3,
#              ('B-NP', 'B-CONJP'): 4,
#              ('B-ADVP', 'STOP'): 3,
#              ('I-SBAR', 'B-VP'): 1,
#              ('I-CONJP', 'O'): 1,
#              ('I-ADJP', 'STOP'): 1,
#              ('I-PP', 'B-ADVP'): 1,
#              ('I-VP', 'B-CONJP'): 2,
#              ('I-VP', 'STOP'): 1,
#              ('I-INTJ', 'I-INTJ'): 2,
#              ('B-ADJP', 'STOP'): 1,
#              ('B-SBAR', 'B-LST'): 1,
#              ('O', 'B-LST'): 2,
#              ('B-INTJ', 'B-NP'): 1,
#              ('B-VP', 'B-INTJ'): 2,
#              ('B-INTJ', 'B-ADVP'): 1,
#              ('B-ADVP', 'B-PRT'): 1,
#              ('B-VP', 'STOP'): 1,
#              ('B-INTJ', 'B-PP'): 1})

# %%
def estimate_one_transmission_probability(y_u, y_v, transition_count, tag_count):
        # get the total times y->x occurs
    tag_transition_freq = transition_count.get((y_u, y_v), 0)
    # total times y appears
    tag_total_freq = tag_count.get(y, 1)
    
    return tag_transition_freq / tag_total_freq

# %%
def estimate_all_transmission_probability(transition_count, tag_count):
  
    transmission_probabilities = {}
    # iterate through all the transition tag pairs to get all the transition probabilities
    # store the results in the dictionary transition_probabilities
    for (y_u, y_v), count in transition_count.items():
        transmission_probabilities[(y_u, y_v)] = count / tag_count[y_u]
        
    return transmission_probabilities

# %%
transmission_probabilities = estimate_all_transmission_probability(transition_count, tag_count)

# %%
transmission_probabilities
# Out:
# {('START', 'B-NP'): 0.6480490669450607,
#  ('B-NP', 'I-NP'): 0.6847056336539478,
#  ('I-NP', 'B-VP'): 0.13491234818926195,
#  ('B-VP', 'B-ADVP'): 0.031214062756694597,
#  ('B-ADVP', 'B-ADJP'): 0.016549789621318374,
#  ('B-ADJP', 'I-ADJP'): 0.27984009137635635,
#  ('I-ADJP', 'I-ADJP'): 0.14634146341463414,
#  ('I-ADJP', 'B-PP'): 0.2857142857142857,
#  ('B-PP', 'B-NP'): 0.9280469897209985,
#  ('I-NP', 'B-PP'): 0.15650931472220694,
#  ('I-NP', 'O'): 0.2273268487479621,
#  ('O', 'O'): 0.11352211796246649,
#  ('O', 'B-ADJP'): 0.008755026809651475,
#  ('B-NP', 'B-VP'): 0.13030335059718845,
#  ('B-VP', 'B-PP'): 0.09873500903564975,
#  ('I-NP', 'I-NP'): 0.4066787565715961,
#  ('O', 'STOP'): 0.3182808310991957,
#  ('B-VP', 'B-SBAR'): 0.025573626855046272,
#  ('B-SBAR', 'B-NP'): 0.8725645076355977,
#  ('B-VP', 'B-NP'): 0.3452165817863206,
#  ('B-VP', 'O'): 0.06741142325173868,
#  ('O', 'B-NP'): 0.34718498659517427,
#  ('I-NP', 'B-NP'): 0.0476452162444359,
#  ('B-ADVP', 'B-PP'): 0.17054698457223003,
#  ('B-VP', 'I-VP'): 0.3739116149170363,
#  ('I-VP', 'B-NP'): 0.35534993601732456,
#  ('O', 'B-VP'): 0.11503016085790885,
#  ('I-VP', 'I-VP'): 0.3278866030121075,
#  ('B-NP', 'O'): 0.08096395729838284,
#  ('B-NP', 'B-PP'): 0.05800655321847585,
#  ('I-VP', 'B-PP'): 0.1483413721823014,
#  ('B-PP', 'B-PP'): 0.018491325392940666,
#  ('B-NP', 'B-NP'): 0.028897579537046823,
#  ('I-NP', 'B-SBAR'): 0.006374677144584272,
#  ('B-SBAR', 'B-VP'): 0.038441284886782515,
#  ('B-NP', 'B-ADVP'): 0.009808688299334109,
#  ('B-ADVP', 'B-NP'): 0.21037868162692847,
#  ('B-ADVP', 'I-ADVP'): 0.08695652173913043,
#  ('I-ADVP', 'B-NP'): 0.18732782369146006,
#  ('START', 'B-PP'): 0.1087041628604985,
#  ('I-VP', 'B-SBAR'): 0.013190274633330052,
#  ('I-VP', 'B-ADVP'): 0.03760212619352298,
#  ('B-ADVP', 'O'): 0.2653576437587658,
#  ('I-NP', 'B-ADVP'): 0.015332197614991482,
#  ('I-ADVP', 'B-ADVP'): 0.030303030303030304,
#  ('O', 'B-PP'): 0.05014242627345845,
#  ('START', 'O'): 0.14185045021532036,
#  ('I-VP', 'O'): 0.05669849394625455,
#  ('B-VP', 'B-PRT'): 0.011171348776080172,
#  ('B-PRT', 'B-NP'): 0.5064102564102564,
#  ('B-ADVP', 'B-VP'): 0.21598877980364656,
#  ('O', 'B-ADVP'): 0.029197386058981232,
#  ('B-PP', 'B-VP'): 0.02659487681514113,
#  ('B-NP', 'B-ADJP'): 0.0032131909946094494,
#  ('B-ADJP', 'B-PP'): 0.24443175328383782,
#  ('I-ADVP', 'O'): 0.3278236914600551,
#  ('B-VP', 'B-VP'): 0.007228519796287169,
#  ('O', 'B-SBAR'): 0.016127680965147453,
#  ('I-ADJP', 'B-NP'): 0.08885017421602788,
#  ('B-NP', 'B-SBAR'): 0.00340344572455343,
#  ('B-VP', 'B-ADJP'): 0.03920924374349707,
#  ('B-ADJP', 'B-VP'): 0.11079383209594518,
#  ('I-NP', 'B-ADJP'): 0.00410324046088183,
#  ('B-ADJP', 'O'): 0.2569960022844089,
#  ('B-ADJP', 'B-NP'): 0.051970302684180465,
#  ('START', 'B-ADVP'): 0.05428683283309409,
#  ('B-PP', 'O'): 0.008484255180290423,
#  ('B-ADVP', 'B-SBAR'): 0.016269284712482467,
#  ('I-VP', 'B-VP'): 0.008268530367162122,
#  ('I-ADJP', 'O'): 0.3205574912891986,
#  ('START', 'B-ADJP'): 0.003262429857758058,
#  ('B-PP', 'I-PP'): 0.011257953989231522,
#  ('I-PP', 'B-NP'): 0.7847533632286996,
#  ('B-ADVP', 'B-ADVP'): 0.016269284712482467,
#  ('START', 'B-SBAR'): 0.02257601461568576,
#  ('I-PP', 'B-VP'): 0.03139013452914798,
#  ('I-ADJP', 'B-SBAR'): 0.06097560975609756,
#  ('B-ADJP', 'B-ADVP'): 0.01599086236436322,
#  ('B-PP', 'B-ADJP'): 0.0026105400554739763,
#  ('B-PRT', 'B-PP'): 0.24145299145299146,
#  ('I-ADVP', 'B-PP'): 0.15426997245179064,
#  ('I-VP', 'B-ADJP'): 0.029038291170390786,
#  ('I-ADVP', 'I-ADVP'): 0.14600550964187328,
#  ('I-VP', 'B-PRT'): 0.023329067821635987,
#  ('B-ADJP', 'B-SBAR'): 0.03769274700171331,
#  ('START', 'B-CONJP'): 0.00026099438862064463,
#  ('B-CONJP', 'I-CONJP'): 0.9387755102040817,
#  ('I-CONJP', 'B-NP'): 0.4375,
#  ('START', 'B-VP'): 0.018661098786376094,
#  ('B-SBAR', 'B-PP'): 0.014218009478672985,
#  ('B-NP', 'B-PRT'): 0.00035937004544974105,
#  ('I-ADVP', 'B-SBAR'): 0.07988980716253444,
#  ('B-PRT', 'B-ADVP'): 0.029914529914529916,
#  ('I-NP', 'STOP'): 0.000787675624187137,
#  ('B-PRT', 'O'): 0.1581196581196581,
#  ('O', 'B-INTJ'): 0.0005864611260053619,
#  ('B-INTJ', 'I-INTJ'): 0.19230769230769232,
#  ('I-INTJ', 'O'): 0.7142857142857143,
#  ('I-PP', 'B-ADJP'): 0.004484304932735426,
#  ('B-INTJ', 'O'): 0.6153846153846154,
#  ('B-SBAR', 'B-SBAR'): 0.00842548709847288,
#  ('I-PP', 'B-PP'): 0.06278026905829596,
#  ('I-ADVP', 'B-VP'): 0.05785123966942149,
#  ('B-PP', 'B-ADVP'): 0.003317561320498178,
#  ('B-SBAR', 'O'): 0.02843601895734597,
#  ('B-SBAR', 'B-ADVP'): 0.008952080042127435,
#  ('B-INTJ', 'B-VP'): 0.07692307692307693,
#  ('I-PP', 'O'): 0.04035874439461883,
#  ('I-ADJP', 'B-VP'): 0.06968641114982578,
#  ('START', 'B-INTJ'): 0.0013049719431032234,
#  ('B-SBAR', 'I-SBAR'): 0.02527646129541864,
#  ('I-SBAR', 'B-NP'): 0.9583333333333334,
#  ('B-PP', 'B-SBAR'): 0.0009789525208027412,
#  ('I-NP', 'B-PRT'): 0.0001282262644025572,
#  ('O', 'B-CONJP'): 0.0010472520107238606,
#  ('I-CONJP', 'I-CONJP'): 0.28125,
#  ('I-CONJP', 'B-PP'): 0.109375,
#  ('I-ADJP', 'B-ADVP'): 0.013937282229965157,
#  ('B-PRT', 'B-VP'): 0.042735042735042736,
#  ('B-PRT', 'B-SBAR'): 0.019230769230769232,
#  ('I-PP', 'I-PP'): 0.07174887892376682,
#  ('B-VP', 'B-CONJP'): 0.0001642845408247084,
#  ('I-CONJP', 'B-VP'): 0.15625,
#  ('B-PP', 'STOP'): 0.00021754500462283134,
#  ('B-SBAR', 'B-ADJP'): 0.00315955766192733,
#  ('I-SBAR', 'B-PP'): 0.020833333333333332,
#  ('B-PRT', 'B-ADJP'): 0.002136752136752137,
#  ('I-ADJP', 'B-ADJP'): 0.012195121951219513,
#  ('I-NP', 'B-CONJP'): 0.00020149841548973275,
#  ('I-ADVP', 'B-ADJP'): 0.01652892561983471,
#  ('B-NP', 'STOP'): 0.00023253355882042067,
#  ('B-NP', 'B-UCP'): 2.1139414438220062e-05,
#  ('B-UCP', 'I-UCP'): 1.0,
#  ('I-UCP', 'I-UCP'): 0.75,
#  ('I-UCP', 'B-NP'): 0.25,
#  ('O', 'B-PRT'): 4.1890080428954424e-05,
#  ('B-ADJP', 'B-PRT'): 0.0005711022272986865,
#  ('START', 'B-LST'): 0.0010439775544825785,
#  ('B-LST', 'O'): 1.0,
#  ('B-ADJP', 'B-ADJP'): 0.001142204454597373,
#  ('B-ADVP', 'B-CONJP'): 0.0005610098176718093,
#  ('B-CONJP', 'O'): 0.061224489795918366,
#  ('B-NP', 'B-CONJP'): 8.455765775288025e-05,
#  ('B-ADVP', 'STOP'): 0.0008415147265077139,
#  ('I-SBAR', 'B-VP'): 0.020833333333333332,
#  ('I-CONJP', 'O'): 0.015625,
#  ('I-ADJP', 'STOP'): 0.0017421602787456446,
#  ('I-PP', 'B-ADVP'): 0.004484304932735426,
#  ('I-VP', 'B-CONJP'): 0.0001968697706467172,
#  ('I-VP', 'STOP'): 9.84348853233586e-05,
#  ('I-INTJ', 'I-INTJ'): 0.2857142857142857,
#  ('B-ADJP', 'STOP'): 0.0005711022272986865,
#  ('B-SBAR', 'B-LST'): 0.000526592943654555,
#  ('O', 'B-LST'): 8.378016085790885e-05,
#  ('B-INTJ', 'B-NP'): 0.038461538461538464,
#  ('B-VP', 'B-INTJ'): 0.00010952302721647227,
#  ('B-INTJ', 'B-ADVP'): 0.038461538461538464,
#  ('B-ADVP', 'B-PRT'): 0.00028050490883590464,
#  ('B-VP', 'STOP'): 5.4761513608236134e-05,
#  ('B-INTJ', 'B-PP'): 0.038461538461538464}

# %% [markdown]
# #### 2b, 15 points (viterbii)

# %%
tag_count
# Out:
# defaultdict(int,
#             {'B-NP': 47305,
#              'I-NP': 54591,
#              'B-VP': 18261,
#              'B-ADVP': 3565,
#              'B-ADJP': 1751,
#              'I-ADJP': 574,
#              'B-PP': 18387,
#              'O': 23872,
#              'B-SBAR': 1899,
#              'I-VP': 10159,
#              'I-ADVP': 363,
#              'B-PRT': 468,
#              'I-PP': 223,
#              'B-CONJP': 49,
#              'I-CONJP': 64,
#              'B-INTJ': 26,
#              'I-INTJ': 7,
#              'I-SBAR': 48,
#              'B-UCP': 1,
#              'I-UCP': 4,
#              'B-LST': 11,
#              'START': 7663,
#              'STOP': 7663})

# %%
tags = [tag for tag in tag_count if tag not in ['START', 'STOP']]
print(tags)
# Out:
# ['B-NP', 'I-NP', 'B-VP', 'B-ADVP', 'B-ADJP', 'I-ADJP', 'B-PP', 'O', 'B-SBAR', 'I-VP', 'I-ADVP', 'B-PRT', 'I-PP', 'B-CONJP', 'I-CONJP', 'B-INTJ', 'I-INTJ', 'I-SBAR', 'B-UCP', 'I-UCP', 'B-LST']

# %%
# transmission_probabilities
# print(emission_probabilities)
for word, tag in emission_probabilities:
    if word == '#UNK#':
        print(word,tag)
# Out:
# #UNK# B-NP
# #UNK# I-NP
# #UNK# B-VP
# #UNK# B-ADVP
# #UNK# B-ADJP
# #UNK# I-ADJP
# #UNK# B-PP
# #UNK# O
# #UNK# B-SBAR
# #UNK# I-VP
# #UNK# I-ADVP
# #UNK# B-PRT
# #UNK# I-PP
# #UNK# B-CONJP
# #UNK# I-CONJP
# #UNK# B-INTJ
# #UNK# I-INTJ
# #UNK# I-SBAR
# #UNK# B-UCP
# #UNK# I-UCP
# #UNK# B-LST

# %%
def viterbi_algorithm(sentence, tag_count, transmission_probabilities, emission_probabilities, vocabulary, unk = 0.1):
    # make sure that "sentence" is a sequence of x observations
    tags = [tag for tag in tag_count if tag not in ['START', 'STOP']] # makes a dictionary of tags that doesnt include start and stop, so we dont iterate through them unncessarily
#     tags.pop('START')
#     tags.pop('STOP')
    
    n = len(sentence)  # number of words in the sentence (k)
    m = len(tags)      # number of tags (u / v)
    for i in range(0,n):
        if sentence[i] not in vocabulary:
            sentence[i] = '#UNK#'
    # create a matrix to store all the pi values
    pi = [[float('-inf')] * m for _ in range(n+1)] #+1 tp account for the stop state, but we dont actually store anything theer
    backpointer = [[0] * m for _ in range(n)] # to store y*

    # base case!!!, here, we actually just initialise the first column to be pi(0,v) where u is "START". 
    # we skip the step of assigning pi(0,v) = 1 if v is start and 0 otherwise
    for i, tag in enumerate(tags): # i is the index of the tag
        t_count = tag_count[tag]
        pi[0][i] = transmission_probabilities.get(('START', tag), 0) * emission_probabilities.get((sentence[0], tag),0)

            
    #bottom up dynamic programming        
    for i in range(1, n): 
        for j, tag in enumerate(tags):
            max_prob = float('-inf')
            max_state = None
            for kk, prev_tag in enumerate(tags):
                # for now, if there's an unknown word, default to 0, but we should change this to the k/count + k thing
#                 t_count
                prob = pi[i-1][kk] * transmission_probabilities.get((prev_tag, tag), 0) * emission_probabilities.get((sentence[i], tag), 0)
                
                if prob > max_prob:
                    max_prob = prob
                    max_state = kk
            pi[i][j] = max_prob
            backpointer[i][j] = max_state # to store y*

    # termination step 
    max_prob = float('-inf')
    max_state = None
    for i, tag in enumerate(tags):
        prob = pi[n-1][i] * transmission_probabilities.get((tag, 'STOP'), 0)
        if prob > max_prob:
            max_prob = prob
            max_state = i
            
    #initialise an array for the best sequence of states         
    best_path = [tags[max_state]]
    
    #go backwards along the backpointer, iteratively finding the best state
    for i in range(n-1, 0, -1):
        max_state = backpointer[i][max_state]
        best_path.append(tags[max_state])
        
    # reverse the array to get it in the right order
    best_path.reverse()
    
    return best_path

# %%
def get_sentences(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        content = file.read().strip()
    # split on double newlines which denote separated sentences
    return [sentence.split() for sentence in content.split('\n\n')]

# %%
def get_prediction(filepath, tag_count, transmission_probabilities, emission_probabilities, vocabulary):
    sentences = get_sentences(filepath)
#     print(sentences)
    predictions = []
    for sentence in sentences:
        best_path_prediction = viterbi_algorithm(sentence, tag_count, transmission_probabilities, emission_probabilities, vocabulary)
        predictions.append(list(zip(sentence, best_path_prediction))) #puts them in the predictions array pairwise
    return predictions

# %%
def write_tag_predictions_to_file(predictions, output_filepath):
    # open the output file for writing
    with open(output_filepath, 'w', encoding='utf-8') as file:
        for sentence in predictions:
            for word, tag in sentence:
                # write each word and its predicted tag to the file, with a spacing to separate.
                file.write(f"{word} {tag}\n")
            file.write("\n")

# %%
predictions = get_prediction('EN/dev.in', tag_count, transmission_probabilities, emission_probabilities, vocabulary)

# %%
predictions
# Out:
# [[('HBO', 'B-NP'),
#   ('has', 'B-VP'),
#   ('close', 'I-VP'),
#   ('to', 'B-PP'),
#   ('24', 'B-NP'),
#   ('million', 'I-NP'),
#   ('subscribers', 'I-NP'),
#   ('to', 'B-PP'),
#   ('its', 'B-NP'),
#   ('HBO', 'I-NP'),
#   ('and', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('networks', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('Showtime', 'B-NP'),
#   ('and', 'O'),
#   ('its', 'B-NP'),
#   ('sister', 'I-NP'),
#   ('service', 'I-NP'),
#   (',', 'O'),
#   ('The', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Channel', 'I-NP'),
#   (',', 'O'),
#   ('have', 'B-VP'),
#   ('only', 'I-VP'),
#   ('about', 'B-PP'),
#   ('10', 'B-NP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Paul', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Associates', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('Calif.', 'B-NP'),
#   (',', 'O'),
#   ('research', 'B-NP'),
#   ('firm', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('after', 'B-PP'),
#   ('the', 'B-NP'),
#   ('stock', 'I-NP'),
#   ('market', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('roller-coaster', 'I-NP'),
#   ('ride', 'I-NP'),
#   ('.', 'O')],
#  [('This', 'B-NP'),
#   ('may', 'B-VP'),
#   ('seem', 'I-VP'),
#   ('to', 'I-VP'),
#   ('be', 'I-VP'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('and', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('futile', 'I-NP'),
#   ('effort', 'I-NP'),
#   ('in', 'I-NP'),
#   ('Africa', 'I-NP'),
#   ('.', 'O')],
#  [('American', 'B-NP'),
#   ('Express', 'I-NP'),
#   ('Bank', 'I-NP'),
#   ('earnings', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('50', 'B-NP'),
#   ('%', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('21.3', 'I-NP'),
#   ('million', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('42.5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('despite', 'B-PP'),
#   ('a', 'B-NP'),
#   ('29', 'I-NP'),
#   ('%', 'I-NP'),
#   ('revenue', 'I-NP'),
#   ('gain', 'I-NP'),
#   ('.', 'O')],
#  [('Californians', 'B-NP'),
#   (',', 'O'),
#   ('meanwhile', 'B-ADVP'),
#   (',', 'O'),
#   ('tried', 'B-VP'),
#   ('to', 'I-VP'),
#   ('cope', 'I-VP'),
#   ('with', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('services', 'I-NP'),
#   (',', 'B-NP'),
#   ('blocked', 'B-NP'),
#   ('roadways', 'B-NP'),
#   ('and', 'B-NP'),
#   ('water', 'B-NP'),
#   ('shortages', 'B-NP'),
#   ('in', 'B-NP'),
#   ('the', 'B-NP'),
#   ('aftermath', 'B-NP'),
#   ('of', 'B-NP'),
#   ('the', 'B-NP'),
#   ('tremor', 'B-NP'),
#   ('that', 'B-NP'),
#   ('left', 'B-NP'),
#   ('scores', 'B-NP'),
#   ('dead', 'B-NP'),
#   ('and', 'B-NP'),
#   ('injured', 'B-NP'),
#   ('.', 'B-NP')],
#  [('This', 'B-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('number', 'I-NP'),
#   ('of', 'B-PP'),
#   ('retail', 'B-NP'),
#   ('leveraged', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('have', 'B-VP'),
#   ('failed', 'I-VP'),
#   (',', 'O'),
#   ('causing', 'B-VP'),
#   ('jitters', 'B-NP'),
#   ('among', 'B-NP'),
#   ('suppliers', 'B-NP'),
#   (',', 'B-NP'),
#   ('and', 'B-NP'),
#   ('Mr.', 'B-NP'),
#   ('Merksamer', 'B-NP'),
#   ('apparently', 'B-NP'),
#   ('wanted', 'B-NP'),
#   ('assurances', 'B-NP'),
#   ('that', 'B-NP'),
#   ('he', 'B-NP'),
#   ('wo', 'B-NP'),
#   ("n't", 'B-NP'),
#   ('have', 'B-NP'),
#   ('delivery', 'B-NP'),
#   ('problems', 'B-NP'),
#   ('.', 'B-NP')],
#  [('Mr.', 'B-NP'),
#   ('Juliano', 'I-NP'),
#   ('thinks', 'B-VP'),
#   ('so', 'B-ADJP'),
#   ('.', 'O')],
#  [('Assistant', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('Attorney', 'I-NP'),
#   ('Terry', 'I-NP'),
#   ('Hart', 'I-NP'),
#   ('of', 'B-PP'),
#   ('Dallas', 'B-NP'),
#   ('says', 'B-VP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('will', 'B-VP'),
#   ('oppose', 'B-VP'),
#   ('any', 'B-NP'),
#   ('efforts', 'I-NP'),
#   ('to', 'B-VP'),
#   ('bring', 'I-VP'),
#   ('in', 'B-PP'),
#   ('a', 'B-NP'),
#   ('new', 'I-NP'),
#   ('defense', 'I-NP'),
#   ('team', 'I-NP'),
#   ('because', 'B-PP'),
#   ('it', 'B-NP'),
#   ('would', 'B-VP'),
#   ('delay', 'I-VP'),
#   ('a', 'B-NP'),
#   ('retrial', 'B-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('Co.', 'I-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('will', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('all', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('shares', 'I-NP'),
#   ('of', 'B-PP'),
#   ('its', 'B-NP'),
#   ('privately', 'B-ADVP'),
#   ('held', 'B-VP'),
#   ('6.5', 'B-NP'),
#   ('%', 'I-NP'),
#   ('convertible', 'I-NP'),
#   ('Series', 'I-NP'),
#   ('C', 'I-NP'),
#   ('preferred', 'I-NP'),
#   ('stock', 'I-NP'),
#   ('Nov.', 'B-NP'),
#   ('8', 'I-NP'),
#   ('.', 'O')],
#  [('On', 'B-PP'),
#   ('a', 'B-NP'),
#   ('$', 'I-NP'),
#   ('10,000', 'I-NP'),
#   ('investment', 'I-NP'),
#   (',', 'O'),
#   ('that', 'B-SBAR'),
#   ("'s", 'B-NP'),
#   ('a', 'B-NP'),
#   ('difference', 'I-NP'),
#   ('of', 'B-PP'),
#   ('only', 'B-NP'),
#   ('$', 'I-NP'),
#   ('50', 'I-NP'),
#   ('a', 'B-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Neither', 'O'),
#   ('the', 'B-NP'),
#   ('Amoco', 'B-NP'),
#   ('agreement', 'I-NP'),
#   ('nor', 'O'),
#   ('the', 'B-NP'),
#   ('wells', 'I-NP'),
#   ('existed', 'B-VP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('suit', 'I-NP'),
#   ('alleged', 'I-NP'),
#   ('.', 'O')],
#  [('But', 'O'),
#   ('for', 'B-PP'),
#   ('individuals', 'B-NP'),
#   ('who', 'B-NP'),
#   ('buy', 'B-VP'),
#   ('much', 'I-VP'),
#   ('smaller', 'B-NP'),
#   ('amounts', 'I-NP'),
#   ('and', 'I-NP'),
#   ('care', 'I-NP'),
#   ('less', 'B-PP'),
#   ('about', 'B-NP'),
#   ('relative', 'I-NP'),
#   ('performance', 'I-NP'),
#   ('than', 'I-NP'),
#   ('in', 'B-PP'),
#   ('preserving', 'B-VP'),
#   ('what', 'B-NP'),
#   ('they', 'B-NP'),
#   ('have', 'B-VP'),
#   (',', 'O'),
#   ('that', 'B-NP'),
#   ('margin', 'I-NP'),
#   ('is', 'B-VP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('authorities', 'I-NP'),
#   ('have', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('foreign', 'B-NP'),
#   ('reporters', 'I-NP'),
#   ('to', 'B-PP'),
#   ('her', 'B-NP'),
#   ('office', 'I-NP'),
#   ('to', 'B-VP'),
#   ('see', 'I-VP'),
#   ('an', 'B-NP'),
#   ('example', 'I-NP'),
#   ('of', 'B-PP'),
#   ('``', 'O'),
#   ('the', 'B-NP'),
#   ('new', 'I-NP'),
#   ('way', 'I-NP'),
#   ('of', 'B-PP'),
#   ('thinking', 'B-VP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('That', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('because', 'B-SBAR'),
#   ('computers', 'B-NP'),
#   ('do', 'B-VP'),
#   ('most', 'B-ADJP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('work', 'I-NP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('low', 'B-NP'),
#   ('trading', 'I-NP'),
#   ('activity', 'I-NP'),
#   ('keeps', 'B-VP'),
#   ('a', 'B-NP'),
#   ('lid', 'I-NP'),
#   ('on', 'I-NP'),
#   ('commission', 'I-NP'),
#   ('costs', 'I-NP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Pinola', 'I-NP'),
#   ('is', 'B-VP'),
#   ('president', 'B-NP'),
#   ('and', 'O'),
#   ('chief', 'B-NP'),
#   ('operating', 'I-NP'),
#   ('officer', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('Mutual', 'I-NP'),
#   ('Life', 'I-NP'),
#   ('Insurance', 'I-NP'),
#   ('Co', 'I-NP'),
#   ('.', 'O')],
#  [('John', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('analyst', 'I-NP'),
#   ('with', 'B-PP'),
#   ('Raymond', 'B-NP'),
#   ('James', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Associates', 'I-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('results', 'I-NP'),
#   ('were', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('surprising', 'B-ADJP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('attributed', 'B-VP'),
#   ('the', 'B-NP'),
#   ('buy-back', 'I-NP'),
#   ('to', 'B-PP'),
#   ('management', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('confidence', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Mirage', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('ability', 'I-NP'),
#   ('to', 'B-VP'),
#   ('generate', 'I-VP'),
#   ('strong', 'B-NP'),
#   ('cash', 'I-NP'),
#   ('flow', 'I-NP'),
#   ('in', 'B-PP'),
#   ('1990', 'B-NP'),
#   ('.', 'O')],
#  [('Raymond', 'B-NP'),
#   ('James', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Associates', 'I-NP'),
#   ('in', 'B-PP'),
#   ('St.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('Fla.', 'B-NP'),
#   (',', 'O'),
#   ('lowered', 'B-VP'),
#   ('its', 'B-NP'),
#   ('third-quarter', 'I-NP'),
#   ('earnings', 'I-NP'),
#   ('estimate', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   (',', 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Dow', 'B-NP'),
#   ('Jones', 'I-NP'),
#   ('Professional', 'I-NP'),
#   ('Investor', 'I-NP'),
#   ('Report', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('also', 'B-ADVP'),
#   ('operates', 'B-VP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('entertainment', 'B-NP'),
#   ('properties', 'I-NP'),
#   ('and', 'O'),
#   ('small', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('systems', 'I-NP'),
#   ('.', 'O')],
#  [('Digital', 'B-NP'),
#   (',', 'O'),
#   ('based', 'B-VP'),
#   ('in', 'B-PP'),
#   ('Maynard', 'B-NP'),
#   (',', 'O'),
#   ('Mass.', 'B-NP'),
#   (',', 'O'),
#   ('hopes', 'B-NP'),
#   ('to', 'I-NP'),
#   ('stage', 'I-NP'),
#   ('a', 'B-NP'),
#   ('repeat', 'I-NP'),
#   ('performance', 'I-NP'),
#   ('in', 'B-PP'),
#   ('mainframes', 'B-NP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('it', 'B-NP'),
#   ('has', 'B-VP'),
#   ('spent', 'I-VP'),
#   ('almost', 'B-ADVP'),
#   ('$', 'B-NP'),
#   ('1', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('developing', 'B-VP'),
#   ('the', 'B-NP'),
#   ('new', 'I-NP'),
#   ('technology', 'I-NP'),
#   ('.', 'O')],
#  [('He', 'B-NP'),
#   ('also', 'B-ADVP'),
#   ('says', 'B-VP'),
#   ('CompuServe', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('continue', 'B-VP'),
#   ('to', 'I-VP'),
#   ('grow', 'I-VP'),
#   ('``', 'O'),
#   ('20', 'B-NP'),
#   ('%', 'I-NP'),
#   ('to', 'B-PP'),
#   ('30', 'B-NP'),
#   ('%', 'I-NP'),
#   ('a', 'B-NP'),
#   ('year', 'I-NP'),
#   ("''", 'O'),
#   ('in', 'B-PP'),
#   ('spite', 'B-NP'),
#   ('of', 'B-PP'),
#   ('tough', 'B-NP'),
#   ('competition', 'I-NP'),
#   ('from', 'B-NP'),
#   ('giants', 'I-NP'),
#   ('like', 'B-PP'),
#   ('Sears', 'B-NP'),
#   ('and', 'O'),
#   ('IBM', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Treasury', 'I-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'I-VP'),
#   ('raise', 'I-VP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('new', 'B-NP'),
#   ('cash', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('sale', 'I-NP'),
#   ('Monday', 'I-NP'),
#   ('of', 'B-PP'),
#   ('about', 'B-NP'),
#   ('$', 'I-NP'),
#   ('15.6', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('short-term', 'B-NP'),
#   ('bills', 'I-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('$', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('bills', 'I-NP'),
#   ('.', 'O')],
#  [('Stocks', 'B-NP'),
#   ('retreated', 'B-NP'),
#   ('to', 'B-NP'),
#   ('session', 'B-NP'),
#   ('lows', 'B-NP'),
#   ('just', 'B-NP'),
#   ('after', 'B-NP'),
#   ('the', 'B-NP'),
#   ('opening', 'B-NP'),
#   ('amid', 'B-NP'),
#   ('worries', 'B-NP'),
#   ('about', 'B-NP'),
#   ('the', 'B-NP'),
#   ('market', 'B-NP'),
#   ('impact', 'B-NP'),
#   ('of', 'B-NP'),
#   ('the', 'B-NP'),
#   ('quake', 'B-NP'),
#   (',', 'B-NP'),
#   ('but', 'B-NP'),
#   ('quickly', 'B-NP'),
#   ('snapped', 'B-NP'),
#   ('back', 'B-NP'),
#   ('to', 'B-NP'),
#   ('higher', 'B-NP'),
#   ('levels', 'B-NP'),
#   ('with', 'B-NP'),
#   ('the', 'B-NP'),
#   ('help', 'B-NP'),
#   ('of', 'B-NP'),
#   ('futures-related', 'B-NP'),
#   ('program', 'B-NP'),
#   ('buying', 'B-NP'),
#   ('.', 'B-NP')],
#  [('There', 'B-NP'),
#   ('is', 'B-VP'),
#   ('no', 'B-NP'),
#   ('small', 'I-NP'),
#   ('irony', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('fact', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('some', 'B-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('advertising', 'I-NP'),
#   ('comes', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('of', 'B-PP'),
#   ('--', 'O'),
#   ('you', 'B-NP'),
#   ('#UNK#', 'B-PP'),
#   ('it', 'B-NP'),
#   ('--', 'O'),
#   ('outsiders', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Federal', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Commission', 'I-NP'),
#   ('clears', 'B-VP'),
#   ('corporate', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'I-VP'),
#   ('#UNK#', 'I-VP'),
#   ('to', 'B-PP'),
#   ('an', 'B-NP'),
#   ('employee', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('chosen', 'I-NP'),
#   ('charity', 'I-NP'),
#   ('in', 'B-PP'),
#   ('exchange', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('worker', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('gift', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ('political', 'I-NP'),
#   ('action', 'I-NP'),
#   ('committee', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('method', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('the', 'B-NP'),
#   ('20', 'I-NP'),
#   ('%', 'I-NP'),
#   ('tax', 'I-NP'),
#   (',', 'O'),
#   ('paid', 'B-VP'),
#   ('if', 'B-SBAR'),
#   ('it', 'B-NP'),
#   ('exceeds', 'B-VP'),
#   ('tax', 'B-NP'),
#   ('figured', 'B-VP'),
#   ('the', 'B-NP'),
#   ('regular', 'I-NP'),
#   ('way', 'I-NP'),
#   (',', 'O'),
#   ('is', 'B-VP'),
#   ('due', 'B-ADJP'),
#   ('for', 'B-PP'),
#   ('a', 'B-NP'),
#   ('change', 'I-NP'),
#   ('in', 'B-PP'),
#   ('1990', 'B-NP'),
#   (',', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('to', 'B-PP'),
#   ('1986', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('tax', 'I-NP'),
#   ('act', 'I-NP'),
#   ('.', 'O')],
#  [('I', 'B-NP'),
#   ('expected', 'B-VP'),
#   ('him', 'B-NP'),
#   ('to', 'B-VP'),
#   ('say', 'I-VP'),
#   (',', 'O'),
#   ('``', 'O'),
#   ('I', 'B-NP'),
#   ('told', 'B-VP'),
#   ('you', 'B-NP'),
#   ('so', 'B-ADVP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('but', 'O'),
#   ('he', 'B-NP'),
#   ('already', 'B-ADVP'),
#   ('was', 'B-VP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('Although', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('East', 'I-NP'),
#   ('German', 'I-NP'),
#   ('news', 'I-NP'),
#   ('agency', 'I-NP'),
#   ('ADN', 'I-NP'),
#   ('claimed', 'B-VP'),
#   ('Mr.', 'B-NP'),
#   ('Honecker', 'I-NP'),
#   ('had', 'B-VP'),
#   ('asked', 'I-VP'),
#   ('to', 'I-VP'),
#   ('be', 'I-VP'),
#   ('relieved', 'I-VP'),
#   ('of', 'B-PP'),
#   ('his', 'B-NP'),
#   ('duties', 'I-NP'),
#   ('for', 'B-PP'),
#   ('``', 'B-NP'),
#   ('health', 'I-NP'),
#   ('reasons', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('West', 'B-NP'),
#   ('German', 'I-NP'),
#   ('government', 'I-NP'),
#   ('sources', 'I-NP'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Politburo', 'I-NP'),
#   ('had', 'B-VP'),
#   ('asked', 'I-VP'),
#   ('for', 'B-PP'),
#   ('his', 'B-NP'),
#   ('resignation', 'I-NP'),
#   ('at', 'B-PP'),
#   ('a', 'B-NP'),
#   ('separate', 'I-NP'),
#   ('meeting', 'I-NP'),
#   ('late', 'B-NP'),
#   ('Tuesday', 'I-NP'),
#   ('.', 'O')],
#  [('During', 'B-PP'),
#   ('the', 'B-NP'),
#   ('quarter', 'I-NP'),
#   (',', 'O'),
#   ('Pfizer', 'B-NP'),
#   ('received', 'B-VP'),
#   ('federal', 'B-NP'),
#   ('approval', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('calcium', 'I-NP'),
#   ('channel', 'I-NP'),
#   ('blocker', 'I-NP'),
#   ('approved', 'B-VP'),
#   ('for', 'B-PP'),
#   ('both', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('and', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('used', 'B-VP'),
#   ('to', 'I-VP'),
#   ('open', 'I-VP'),
#   ('obstructed', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   ('arteries', 'I-NP'),
#   ('.', 'O')],
#  [('We', 'B-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('want', 'I-VP'),
#   ('to', 'I-VP'),
#   ('be', 'I-VP'),
#   ('party', 'B-NP'),
#   ('to', 'B-PP'),
#   ('a', 'B-NP'),
#   ('second', 'I-NP'),
#   ('rejection', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('he', 'B-NP'),
#   ('said', 'B-VP'),
#   (',', 'O'),
#   ('adding', 'B-VP'),
#   ('that', 'B-NP'),
#   ('coming', 'B-VP'),
#   ('up', 'B-PRT'),
#   ('with', 'B-PP'),
#   ('a', 'B-NP'),
#   ('revised', 'I-NP'),
#   ('offer', 'I-NP'),
#   ('could', 'B-VP'),
#   ('easily', 'I-VP'),
#   ('take', 'I-VP'),
#   ('several', 'B-NP'),
#   ('weeks', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('authorities', 'I-NP'),
#   ('say', 'B-VP'),
#   ('that', 'B-NP'),
#   ('at', 'B-PP'),
#   ('any', 'B-NP'),
#   ('given', 'I-NP'),
#   ('time', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('host', 'I-NP'),
#   ('of', 'B-PP'),
#   ('fraudulent', 'B-NP'),
#   ('telemarketing', 'I-NP'),
#   ('operations', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('many', 'I-NP'),
#   ('legitimate', 'I-NP'),
#   ('businesses', 'I-NP'),
#   ('here', 'B-ADVP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('percentage', 'I-NP'),
#   ('rates', 'I-NP'),
#   ('are', 'B-VP'),
#   ('calculated', 'B-VP'),
#   ('on', 'B-PP'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('yield', 'I-NP'),
#   ('is', 'B-VP'),
#   ('based', 'I-VP'),
#   ('on', 'B-PP'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Neither', 'B-NP'),
#   ('was', 'B-VP'),
#   ('among', 'B-PP'),
#   ('the', 'B-NP'),
#   ('46', 'I-NP'),
#   ('traders', 'I-NP'),
#   ('indicted', 'B-VP'),
#   ('last', 'B-NP'),
#   ('August', 'I-NP'),
#   ('in', 'B-PP'),
#   ('a', 'B-NP'),
#   ('federal', 'I-NP'),
#   ('investigation', 'I-NP'),
#   ('of', 'B-PP'),
#   ('traders', 'B-NP'),
#   ('at', 'B-PP'),
#   ('both', 'B-NP'),
#   ('the', 'B-NP'),
#   ('Merc', 'I-NP'),
#   ('and', 'O'),
#   ('the', 'B-NP'),
#   ('Chicago', 'I-NP'),
#   ('Board', 'I-NP'),
#   ('of', 'B-PP'),
#   ('Trade', 'B-NP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('spokesman', 'I-NP'),
#   ('for', 'B-PP'),
#   ('Dean', 'B-NP'),
#   ('Witter', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('unit', 'I-NP'),
#   ('of', 'B-PP'),
#   ('Sears', 'B-NP'),
#   (',', 'I-NP'),
#   ('Roebuck', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Co.', 'I-NP'),
#   (',', 'O'),
#   ('declined', 'B-VP'),
#   ('to', 'I-VP'),
#   ('comment', 'I-VP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('By', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('a', 'B-NP'),
#   ('place', 'I-NP'),
#   ('now', 'B-ADVP'),
#   (',', 'O'),
#   ('we', 'B-NP'),
#   ('make', 'B-VP'),
#   ('ourselves', 'B-NP'),
#   ('a', 'B-NP'),
#   ('power', 'I-NP'),
#   ('any', 'B-NP'),
#   ('new', 'I-NP'),
#   ('government', 'I-NP'),
#   ('will', 'B-VP'),
#   ('have', 'I-VP'),
#   ('to', 'I-VP'),
#   ('take', 'I-VP'),
#   ('into', 'B-PP'),
#   ('account', 'B-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('Also', 'B-ADVP'),
#   (',', 'O'),
#   ('profit', 'B-NP'),
#   ('rose', 'B-VP'),
#   ('19', 'B-NP'),
#   ('%', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('third', 'I-NP'),
#   ('quarter', 'I-NP'),
#   ('.', 'O')],
#  [('Two', 'B-NP'),
#   ('election', 'I-NP'),
#   ('commission', 'I-NP'),
#   ('members', 'I-NP'),
#   ('opposed', 'B-VP'),
#   ('the', 'B-NP'),
#   ('matching', 'I-NP'),
#   ('plans', 'I-NP'),
#   ('.', 'O')],
#  [('An', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('move', 'I-NP'),
#   ('by', 'B-PP'),
#   ('personal', 'B-NP'),
#   ('computer', 'I-NP'),
#   ('manufacturers', 'I-NP'),
#   ("'", 'O'),
#   ('to', 'B-VP'),
#   ('include', 'I-VP'),
#   ('advanced', 'I-VP'),
#   ('graphics', 'B-NP'),
#   ('capabilities', 'I-NP'),
#   ('as', 'B-PP'),
#   ('standard', 'B-NP'),
#   ('equipment', 'I-NP'),
#   ('further', 'I-NP'),
#   ('#UNK#', 'B-PP'),
#   ('reseller', 'B-NP'),
#   ('purchases', 'I-NP'),
#   ('of', 'B-PP'),
#   ('Western', 'B-NP'),
#   ('Digital', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('equipment', 'I-NP'),
#   ('.', 'O')],
#  [('When', 'B-ADVP'),
#   ('the', 'B-NP'),
#   ('IAFP', 'I-NP'),
#   ('recently', 'B-ADVP'),
#   ('assembled', 'B-VP'),
#   ('other', 'B-NP'),
#   ('industry', 'I-NP'),
#   ('groups', 'I-NP'),
#   ('to', 'B-VP'),
#   ('discuss', 'I-VP'),
#   ('common', 'B-NP'),
#   ('standards', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('might', 'B-VP'),
#   ('be', 'I-VP'),
#   ('applied', 'I-VP'),
#   ('to', 'B-PP'),
#   ('planners', 'B-NP'),
#   (',', 'O'),
#   ('Mr.', 'B-NP'),
#   ('Gargan', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('group', 'I-NP'),
#   ('was', 'B-VP'),
#   ('excluded', 'I-VP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('is', 'B-VP'),
#   ('chairman', 'B-NP'),
#   ('of', 'B-PP'),
#   ('his', 'B-NP'),
#   ('own', 'I-NP'),
#   ('consulting', 'I-NP'),
#   ('company', 'I-NP'),
#   ('in', 'B-PP'),
#   ('Englewood', 'B-NP'),
#   (',', 'O'),
#   ('N.J', 'B-NP'),
#   ('.', 'O')],
#  [('CALL', 'B-NP'),
#   ('MONEY', 'I-NP'),
#   (':', 'O'),
#   ('9', 'B-NP'),
#   ('3\\/4', 'I-NP'),
#   ('%', 'I-NP'),
#   ('to', 'B-PP'),
#   ('10', 'B-NP'),
#   ('%', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('forces', 'I-NP'),
#   ('at', 'B-PP'),
#   ('work', 'B-NP'),
#   ('included', 'B-VP'),
#   ('computer-guided', 'B-NP'),
#   ('trading', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-CONJP'),
#   ('well', 'I-CONJP'),
#   ('as', 'I-CONJP'),
#   ('#UNK#', 'B-NP'),
#   ('market', 'I-NP'),
#   ('makers', 'I-NP'),
#   ('and', 'O'),
#   ('institutional', 'B-NP'),
#   ('investors', 'I-NP'),
#   ('who', 'B-NP'),
#   ('had', 'B-VP'),
#   ('bought', 'I-VP'),
#   ('stock', 'B-NP'),
#   ('on', 'B-PP'),
#   ('the', 'B-NP'),
#   ('cheap', 'I-NP'),
#   ('during', 'B-PP'),
#   ('the', 'B-NP'),
#   ('recent', 'I-NP'),
#   ('correction', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('thing', 'I-NP'),
#   ('is', 'B-VP'),
#   ('so', 'B-ADJP'),
#   ('#UNK#', 'O'),
#   ('right', 'B-ADVP'),
#   ('now', 'I-ADVP'),
#   ('that', 'B-SBAR'),
#   ('there', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('really', 'I-VP'),
#   ('no', 'B-NP'),
#   ('way', 'I-NP'),
#   ('to', 'B-VP'),
#   ('say', 'I-VP'),
#   ('what', 'B-NP'),
#   ('will', 'B-VP'),
#   ('happen', 'I-VP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Justice', 'B-NP'),
#   ('Department', 'I-NP'),
#   ('attorney', 'I-NP'),
#   ('#UNK#', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('III', 'I-NP'),
#   (',', 'O'),
#   ('who', 'B-NP'),
#   ('represents', 'B-VP'),
#   ('the', 'B-NP'),
#   ('IRS', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('case', 'I-NP'),
#   ('.', 'O')],
#  [('That', 'B-NP'),
#   ('rose', 'B-VP'),
#   ('to', 'I-VP'),
#   ('nearly', 'B-NP'),
#   ('18', 'I-NP'),
#   ('%', 'I-NP'),
#   ('during', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('has', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('changed', 'I-VP'),
#   ('much', 'B-ADJP'),
#   ('since', 'B-SBAR'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Maynard', 'I-NP'),
#   ('initially', 'B-ADVP'),
#   ('won', 'B-VP'),
#   ('approval', 'B-NP'),
#   ('for', 'B-PP'),
#   ('his', 'B-NP'),
#   ('machine', 'I-NP'),
#   ('to', 'B-VP'),
#   ('be', 'I-VP'),
#   ('used', 'I-VP'),
#   ('at', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('facilities', 'B-NP'),
#   ('regulated', 'B-NP'),
#   ('by', 'B-NP'),
#   ('the', 'B-NP'),
#   ('USDA', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('Food', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('Service', 'B-NP'),
#   ('.', 'B-NP')],
#  [('#UNK#', 'B-NP'),
#   ('gained', 'B-VP'),
#   ('100', 'B-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('trade', 'I-NP'),
#   ('figures', 'I-NP'),
#   ('range', 'I-NP'),
#   ('widely', 'I-NP'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('few', 'B-NP'),
#   ('economists', 'I-NP'),
#   ('expect', 'B-VP'),
#   ('the', 'B-NP'),
#   ('data', 'I-NP'),
#   ('to', 'B-VP'),
#   ('show', 'I-VP'),
#   ('a', 'B-NP'),
#   ('very', 'I-NP'),
#   ('marked', 'B-VP'),
#   ('improvement', 'B-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#', 'I-NP'),
#   ('2', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('billion', 'B-NP'),
#   ('-RRB-', 'B-NP'),
#   ('deficit', 'B-NP'),
#   ('in', 'B-NP'),
#   ('the', 'B-NP'),
#   ('current', 'B-NP'),
#   ('account', 'B-NP'),
#   ('reported', 'B-NP'),
#   ('for', 'B-NP'),
#   ('August', 'B-NP'),
#   ('.', 'B-NP')],
#  [('Fox', 'B-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'I-VP'),
#   ('offer', 'I-VP'),
#   ('its', 'B-NP'),
#   ('stations', 'I-NP'),
#   ('movies', 'I-NP'),
#   (',', 'O'),
#   ('theatrical', 'B-NP'),
#   ('and', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('ventures', 'I-NP'),
#   (',', 'O'),
#   ('probably', 'B-ADVP'),
#   ('on', 'B-PP'),
#   ('Wednesdays', 'B-NP'),
#   (',', 'O'),
#   ('sometime', 'B-NP'),
#   ('next', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('sentiment', 'I-NP'),
#   ('among', 'B-PP'),
#   ('bankers', 'B-NP'),
#   ('comes', 'B-VP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Independent', 'I-NP'),
#   ('Bankers', 'B-NP'),
#   ('Association', 'I-NP'),
#   ('of', 'B-PP'),
#   ('Texas', 'B-NP'),
#   (',', 'O'),
#   ('although', 'B-SBAR'),
#   ('it', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('hard', 'B-ADJP'),
#   ('to', 'B-VP'),
#   ('tell', 'I-VP'),
#   ('from', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('$', 'I-NP'),
#   ('5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('``', 'O'),
#   ('The', 'B-NP'),
#   ('I', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('of', 'B-PP'),
#   ('Texas', 'B-NP'),
#   ("''", 'O'),
#   ('TV', 'B-NP'),
#   ('campaign', 'I-NP'),
#   ('.', 'O')],
#  [('So-called', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('provisions', 'I-NP'),
#   ('also', 'B-ADVP'),
#   ('merit', 'B-NP'),
#   ('a', 'B-NP'),
#   ('close', 'I-NP'),
#   ('inspection', 'I-NP'),
#   ('.', 'O')],
#  [('It', 'B-NP'),
#   ('would', 'B-VP'),
#   ('go', 'I-VP'),
#   ('along', 'B-ADVP'),
#   ('doing', 'B-VP'),
#   ('nothing', 'B-NP'),
#   ('but', 'O'),
#   ('#UNK#', 'B-PP'),
#   ('the', 'B-NP'),
#   ('heavy', 'I-NP'),
#   ('water', 'I-NP'),
#   ('and', 'O'),
#   ('then', 'B-ADVP'),
#   ('at', 'B-PP'),
#   ('totally', 'B-ADJP'),
#   ('unpredictable', 'B-NP'),
#   ('times', 'I-NP'),
#   (',', 'O'),
#   ('it', 'B-NP'),
#   ('would', 'B-VP'),
#   ('begin', 'I-VP'),
#   ('producing', 'I-VP'),
#   ('excess', 'B-NP'),
#   ('heat', 'I-NP'),
#   ('for', 'B-PP'),
#   ('as', 'B-NP'),
#   ('long', 'I-NP'),
#   ('as', 'B-PP'),
#   ('10', 'B-NP'),
#   ('or', 'O'),
#   ('11', 'B-NP'),
#   ('hours', 'I-NP'),
#   ('before', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('down', 'B-ADVP'),
#   ('.', 'O')],
#  [('These', 'B-NP'),
#   ('and', 'O'),
#   ('other', 'B-NP'),
#   ('modern', 'I-NP'),
#   ('trading', 'I-NP'),
#   ('#UNK#', 'B-PP'),
#   ('``', 'B-NP'),
#   ('tend', 'B-NP'),
#   ('to', 'B-NP'),
#   ('promote', 'B-NP'),
#   ('dramatic', 'B-NP'),
#   ('shifts', 'B-NP'),
#   ('in', 'B-NP'),
#   ('assets', 'B-NP'),
#   (',', 'B-NP'),
#   ("''", 'B-NP'),
#   ('says', 'B-NP'),
#   ('George', 'B-NP'),
#   ('Douglas', 'B-NP'),
#   (',', 'B-NP'),
#   ('first', 'B-NP'),
#   ('vice', 'B-NP'),
#   ('president', 'B-NP'),
#   ('at', 'B-NP'),
#   ('Drexel', 'B-NP'),
#   ('Burnham', 'B-NP'),
#   ('Lambert', 'B-NP'),
#   ('Inc', 'B-NP'),
#   ('.', 'B-NP')],
#  [('Executives', 'B-NP'),
#   ('at', 'B-PP'),
#   ('Olivetti', 'B-NP'),
#   (',', 'O'),
#   ('whose', 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('have', 'B-VP'),
#   ('been', 'I-VP'),
#   ('steadily', 'B-ADVP'),
#   ('sliding', 'B-VP'),
#   ('over', 'B-PP'),
#   ('the', 'B-NP'),
#   ('past', 'I-NP'),
#   ('couple', 'I-NP'),
#   ('of', 'B-PP'),
#   ('years', 'B-NP'),
#   (',', 'O'),
#   ('have', 'B-VP'),
#   ('acknowledged', 'B-VP'),
#   ('that', 'B-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('past', 'I-NP'),
#   ('they', 'B-NP'),
#   ('have', 'B-VP'),
#   ('lagged', 'B-VP'),
#   ('at', 'B-PP'),
#   ('getting', 'B-VP'),
#   ('new', 'B-NP'),
#   ('technology', 'I-NP'),
#   ('to', 'B-PP'),
#   ('market', 'B-NP'),
#   ('.', 'O')],
#  [('Tom', 'B-NP'),
#   ('Schumacher', 'I-NP'),
#   (',', 'O'),
#   ('executive', 'B-NP'),
#   ('vice', 'I-NP'),
#   ('president', 'I-NP'),
#   ('and', 'O'),
#   ('general', 'B-NP'),
#   ('manager', 'I-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('California', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('his', 'B-NP'),
#   ('organization', 'I-NP'),
#   ('urged', 'B-VP'),
#   ('trucking', 'B-NP'),
#   ('firms', 'I-NP'),
#   ('to', 'B-VP'),
#   ('halt', 'I-VP'),
#   ('all', 'B-NP'),
#   ('deliveries', 'I-NP'),
#   ('into', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Bay', 'I-NP'),
#   ('area', 'I-NP'),
#   ('yesterday', 'I-NP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('for', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('supplies', 'I-NP'),
#   ('.', 'O')],
#  [('Real-estate', 'B-NP'),
#   ('interests', 'I-NP'),
#   (',', 'O'),
#   ('for', 'B-PP'),
#   ('example', 'B-NP'),
#   (',', 'O'),
#   ('are', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('an', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('President', 'B-NP'),
#   ('Bush', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('capital-gains', 'I-NP'),
#   ('proposal', 'I-NP'),
#   (':', 'O'),
#   ('It', 'B-NP'),
#   ('does', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('include', 'I-VP'),
#   ('real-estate', 'B-NP'),
#   ('gains', 'I-NP'),
#   ('.', 'O')],
#  [('We', 'B-NP'),
#   ('expect', 'B-VP'),
#   ('a', 'B-ADJP'),
#   ('choppy', 'I-ADJP'),
#   ('and', 'O'),
#   ('sloppy', 'B-ADJP'),
#   ('market', 'B-NP'),
#   ('for', 'B-PP'),
#   ('a', 'B-NP'),
#   ('short', 'I-NP'),
#   ('period', 'I-NP'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('we', 'B-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('think', 'I-VP'),
#   ('it', 'B-NP'),
#   ('will', 'B-VP'),
#   ('be', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('Sheldon', 'B-NP'),
#   ('B.', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'B-NP'),
#   ('chairman', 'B-NP'),
#   ('of', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('&', 'B-NP'),
#   ('Co.', 'B-NP'),
#   (',', 'B-NP'),
#   ('and', 'B-NP'),
#   ('John', 'B-NP'),
#   ('L.', 'B-NP'),
#   ('Murray', 'B-NP'),
#   (',', 'B-NP'),
#   ('chairman', 'B-NP'),
#   ('of', 'B-NP'),
#   ('Universal', 'B-NP'),
#   ('Foods', 'B-NP'),
#   ('Corp.', 'B-NP'),
#   (',', 'B-NP'),
#   ('were', 'B-NP'),
#   ('elected', 'B-NP'),
#   ('to', 'B-NP'),
#   ('the', 'B-NP'),
#   ('board', 'B-NP'),
#   ('of', 'B-NP'),
#   ('this', 'B-NP'),
#   ('engine', 'B-NP'),
#   ('maker', 'B-NP'),
#   ('.', 'B-NP')],
#  [('#UNK#', 'B-NP'), (':', 'O')],
#  [('And', 'O'),
#   ('the', 'B-NP'),
#   ('respondents', 'I-NP'),
#   ("'", 'B-NP'),
#   ('commitment', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('stock', 'I-NP'),
#   ('market', 'I-NP'),
#   ('remains', 'B-VP'),
#   ('somewhat', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   ('than', 'I-NP'),
#   ('usual', 'I-NP'),
#   ('.', 'O')],
#  [('Now', 'B-ADVP'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('new', 'I-NP'),
#   ('approach', 'I-NP'),
#   ('is', 'B-VP'),
#   ('available', 'B-ADJP'),
#   ('to', 'B-VP'),
#   ('building', 'I-VP'),
#   ('your', 'B-NP'),
#   ('financial', 'I-NP'),
#   ('portfolio', 'I-NP'),
#   ('without', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('risk', 'I-NP'),
#   (',', 'O'),
#   ('without', 'B-PP'),
#   ('extensive', 'B-NP'),
#   ('planning', 'I-NP'),
#   ('and', 'I-NP'),
#   ('without', 'B-PP'),
#   ('hurting', 'B-VP'),
#   ('your', 'B-NP'),
#   ('life', 'I-NP'),
#   ('style', 'I-NP'),
#   ('one', 'I-NP'),
#   ('bit', 'I-NP'),
#   ('!', 'O')],
#  [('``', 'O'),
#   ('Losses', 'B-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('earthquake', 'I-NP'),
#   ('are', 'B-VP'),
#   ('expected', 'I-VP'),
#   ('to', 'I-VP'),
#   ('be', 'I-VP'),
#   ('of', 'B-PP'),
#   ('similar', 'B-NP'),
#   ('magnitude', 'I-NP'),
#   ('to', 'B-PP'),
#   ('those', 'B-NP'),
#   ('of', 'B-PP'),
#   ('Hurricane', 'B-NP'),
#   ('Hugo', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('according', 'B-PP'),
#   ('to', 'B-PP'),
#   ('Moody', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('.', 'O')],
#  [('Frank', 'B-NP'),
#   ('Carlucci', 'I-NP'),
#   ('III', 'I-NP'),
#   ('was', 'B-VP'),
#   ('named', 'I-VP'),
#   ('to', 'B-PP'),
#   ('this', 'B-NP'),
#   ('telecommunications', 'I-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('board', 'I-NP'),
#   (',', 'O'),
#   ('filling', 'B-VP'),
#   ('the', 'B-NP'),
#   ('vacancy', 'I-NP'),
#   ('created', 'B-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('death', 'I-NP'),
#   ('of', 'B-PP'),
#   ('William', 'B-NP'),
#   ('#UNK#', 'B-PP'),
#   ('last', 'B-NP'),
#   ('May', 'I-NP'),
#   ('.', 'O')],
#  [('Most', 'B-NP'),
#   ('banking', 'I-NP'),
#   ('issues', 'I-NP'),
#   ('retreated', 'B-VP'),
#   ('after', 'B-PP'),
#   ('a', 'B-NP'),
#   ('sector', 'B-NP'),
#   ('downgrade', 'B-NP'),
#   ('by', 'B-NP'),
#   ('Warburg', 'B-NP'),
#   ('Securities', 'B-NP'),
#   (',', 'B-NP'),
#   ('although', 'B-NP'),
#   ('National', 'B-NP'),
#   ('Westminister', 'B-NP'),
#   ('showed', 'B-NP'),
#   ('strength', 'B-NP'),
#   ('on', 'B-NP'),
#   ('positive', 'B-NP'),
#   ('comments', 'B-NP'),
#   ('from', 'B-NP'),
#   ('brokerage', 'B-NP'),
#   ('firms', 'B-NP'),
#   ('about', 'B-NP'),
#   ('its', 'B-NP'),
#   ('long-term', 'B-NP'),
#   ('prospects', 'B-NP'),
#   ('.', 'B-NP')],
#  [('#UNK#', 'B-NP'),
#   ('approvals', 'I-NP'),
#   (':', 'O'),
#   ('Bell', 'B-NP'),
#   ('Atlantic', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('New', 'B-NP'),
#   ('Jersey', 'I-NP'),
#   ('Bell', 'I-NP'),
#   ('and', 'O'),
#   ('General', 'B-NP'),
#   ('Dynamics', 'I-NP'),
#   ('.', 'O')],
#  [('How', 'B-ADVP'),
#   ('should', 'B-VP'),
#   ('a', 'B-NP'),
#   ('reasonable', 'I-NP'),
#   ('member', 'I-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Federal', 'I-NP'),
#   ('Reserve', 'I-NP'),
#   ('Board', 'I-NP'),
#   ('interpret', 'B-VP'),
#   ('a', 'B-NP'),
#   ('congressional', 'I-NP'),
#   ('decision', 'I-NP'),
#   ('to', 'B-VP'),
#   ('put', 'I-VP'),
#   ('the', 'B-NP'),
#   ('secretary', 'I-NP'),
#   ('on', 'B-PP'),
#   ('the', 'B-NP'),
#   ('board', 'I-NP'),
#   ('?', 'O')],
#  [('Assistant', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('Attorney', 'I-NP'),
#   ('Randy', 'I-NP'),
#   ('Mastro', 'I-NP'),
#   (',', 'O'),
#   ('who', 'B-NP'),
#   ('headed', 'B-VP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('case', 'I-NP'),
#   ('against', 'B-PP'),
#   ('the', 'B-NP'),
#   ('International', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'O'),
#   ('will', 'B-VP'),
#   ('join', 'I-VP'),
#   ('Gibson', 'B-NP'),
#   (',', 'I-NP'),
#   ('Dunn', 'I-NP'),
#   ('&', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('its', 'B-NP'),
#   ('New', 'I-NP'),
#   ('York', 'I-NP'),
#   ('office', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('Sell', 'B-NP'),
#   ('stocks', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('are', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('doing', 'I-VP'),
#   ('well', 'B-ADVP'),
#   ('now', 'I-ADVP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('that', 'B-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('have', 'I-VP'),
#   ('good', 'B-NP'),
#   ('earnings', 'I-NP'),
#   ('prospects', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Alfred', 'B-NP'),
#   ('Goldman', 'I-NP'),
#   (',', 'O'),
#   ('technical', 'B-NP'),
#   ('analyst', 'I-NP'),
#   ('at', 'B-PP'),
#   ('St.', 'B-NP'),
#   ('Louis-based', 'I-NP'),
#   ('A.G.', 'B-NP'),
#   ('Edwards', 'I-NP'),
#   ('&', 'I-NP'),
#   ('Sons', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('attorney', 'I-NP'),
#   ('in', 'B-PP'),
#   ('Washington', 'B-NP'),
#   ('for', 'B-PP'),
#   ('Mr.', 'B-NP'),
#   ('Keating', 'I-NP'),
#   (',', 'O'),
#   ('declined', 'B-VP'),
#   ('to', 'I-VP'),
#   ('comment', 'I-VP'),
#   ('on', 'B-PP'),
#   ('the', 'B-NP'),
#   ('hearings', 'I-NP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('to', 'B-VP'),
#   ('say', 'I-VP'),
#   (',', 'O'),
#   ('``', 'O'),
#   ('We', 'B-NP'),
#   ('will', 'B-VP'),
#   ('be', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('several', 'B-NP'),
#   ('forums', 'I-NP'),
#   ('to', 'B-PP'),
#   ('each', 'B-NP'),
#   ('of', 'B-PP'),
#   ('these', 'B-NP'),
#   ('allegations', 'I-NP'),
#   ('at', 'B-PP'),
#   ('the', 'B-NP'),
#   ('appropriate', 'B-NP'),
#   ('time', 'I-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('The', 'B-NP'),
#   ('directors', 'I-NP'),
#   ("'", 'B-NP'),
#   ('action', 'I-NP'),
#   (',', 'O'),
#   ('taken', 'B-VP'),
#   ('Oct.', 'B-NP'),
#   ('10', 'I-NP'),
#   ('but', 'O'),
#   ('announced', 'B-VP'),
#   ('Friday', 'B-NP'),
#   (',', 'O'),
#   ('had', 'B-VP'),
#   ('little', 'B-ADJP'),
#   ('or', 'O'),
#   ('no', 'B-NP'),
#   ('effect', 'I-NP'),
#   ('on', 'B-PP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('stock', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('at', 'B-PP'),
#   ('$', 'B-NP'),
#   ('4.75', 'I-NP'),
#   ('in', 'B-PP'),
#   ('light', 'B-NP'),
#   ('over-the-counter', 'I-NP'),
#   ('trading', 'I-NP'),
#   ('.', 'O')],
#  [('Few', 'B-NP'),
#   ('specialists', 'I-NP'),
#   ('said', 'B-VP'),
#   ('they', 'B-NP'),
#   ('expect', 'B-VP'),
#   ('the', 'B-NP'),
#   ('quake', 'I-NP'),
#   ('to', 'B-VP'),
#   ('have', 'I-VP'),
#   ('much', 'B-ADJP'),
#   ('of', 'B-PP'),
#   ('an', 'B-NP'),
#   ('effect', 'I-NP'),
#   ('on', 'B-PP'),
#   ('most', 'B-NP'),
#   ('California', 'I-NP'),
#   ('property', 'I-NP'),
#   ('values', 'I-NP'),
#   ('.', 'O')],
#  [('Food', 'B-NP'),
#   ('prices', 'I-NP'),
#   ('rose', 'B-VP'),
#   ('0.2', 'B-NP'),
#   ('%', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('second', 'I-NP'),
#   ('month', 'I-NP'),
#   ('in', 'B-PP'),
#   ('a', 'B-NP'),
#   ('row', 'I-NP'),
#   (',', 'O'),
#   ('far', 'B-ADJP'),
#   ('slower', 'I-ADJP'),
#   ('than', 'B-PP'),
#   ('the', 'B-NP'),
#   ('monthly', 'I-NP'),
#   ('rises', 'B-VP'),
#   ('earlier', 'B-ADVP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('There', 'B-NP'),
#   ('was', 'B-VP'),
#   ('no', 'B-NP'),
#   ('cost', 'I-NP'),
#   ('estimate', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('second', 'I-NP'),
#   ('phase', 'I-NP'),
#   ('.', 'O')],
#  [('Some', 'B-NP'),
#   ('couples', 'B-VP'),
#   ('continue', 'I-VP'),
#   ('to', 'I-VP'),
#   ('try', 'I-VP'),
#   ('.', 'O')],
#  [('Stocks', 'B-NP'),
#   ('of', 'B-PP'),
#   ('major', 'B-NP'),
#   ('toy', 'I-NP'),
#   ('makers', 'I-NP'),
#   ('rallied', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('wake', 'I-NP'),
#   ('of', 'B-PP'),
#   ('strong', 'B-NP'),
#   ('third-quarter', 'I-NP'),
#   ('earnings', 'I-NP'),
#   ('reports', 'I-NP'),
#   ('.', 'O')],
#  [('Bay', 'B-NP'),
#   ('Financial', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('said', 'B-VP'),
#   ('it', 'B-NP'),
#   ('may', 'B-VP'),
#   ('be', 'I-VP'),
#   ('forced', 'I-VP'),
#   ('to', 'I-VP'),
#   ('file', 'I-VP'),
#   ('under', 'B-PP'),
#   ('Chapter', 'B-NP'),
#   ('11', 'I-NP'),
#   ('if', 'B-SBAR'),
#   ('it', 'B-NP'),
#   ('ca', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('reach', 'I-VP'),
#   ('an', 'B-NP'),
#   ('agreement', 'I-NP'),
#   ('with', 'B-PP'),
#   ('its', 'B-NP'),
#   ('lenders', 'I-NP'),
#   ('to', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('its', 'B-NP'),
#   ('debt', 'I-NP'),
#   ('burden', 'I-NP'),
#   (',', 'O'),
#   ('plunged', 'B-VP'),
#   ('1', 'B-NP'),
#   ('3\\/8', 'I-NP'),
#   ('to', 'B-PP'),
#   ('2', 'B-NP'),
#   ('1\\/8', 'I-NP'),
#   ('.', 'O')],
#  [('His', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('was', 'B-VP'),
#   ('rejected', 'I-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('programs', 'I-NP'),
#   ('have', 'B-VP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Rep.', 'B-NP'),
#   ('Henry', 'I-NP'),
#   ('Hyde', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('conservative', 'I-NP'),
#   ('Republican', 'I-NP'),
#   ('from', 'B-PP'),
#   ('Illinois', 'B-NP'),
#   ('.', 'O')],
#  [('You', 'B-NP'),
#   ("'ll", 'B-NP'),
#   ('see', 'B-NP'),
#   ('carriers', 'B-NP'),
#   ('try', 'B-NP'),
#   ('to', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('some', 'B-NP'),
#   ('of', 'B-NP'),
#   ('the', 'B-NP'),
#   ('price', 'B-NP'),
#   ('cutting', 'B-NP'),
#   ('that', 'B-NP'),
#   ('occurred', 'B-NP'),
#   ('previously', 'B-NP'),
#   ('.', 'B-NP'),
#   ("''", 'B-NP')],
#  [('And', 'O'),
#   ('they', 'B-NP'),
#   ('have', 'B-VP'),
#   ('bought', 'I-VP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('500', 'I-NP'),
#   ('million', 'I-NP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('plans', 'I-NP'),
#   (',', 'O'),
#   ('offered', 'B-VP'),
#   ('in', 'B-PP'),
#   ('Michigan', 'B-NP'),
#   (',', 'O'),
#   ('Florida', 'B-NP'),
#   ('and', 'I-NP'),
#   ('Wyoming', 'I-NP'),
#   ('.', 'O')],
#  [('Meanwhile', 'B-ADVP'),
#   (',', 'O'),
#   ('Eurocom', 'B-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('had', 'B-VP'),
#   ('held', 'I-VP'),
#   ('20', 'B-NP'),
#   ('%', 'I-NP'),
#   ('of', 'B-PP'),
#   ('WCRS', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('ad', 'I-NP'),
#   ('unit', 'I-NP'),
#   (',', 'O'),
#   ('will', 'B-VP'),
#   ('pay', 'I-VP'),
#   ('#', 'B-NP'),
#   ('43.5', 'I-NP'),
#   ('million', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   ('-RRB-', 'O'),
#   ('to', 'B-VP'),
#   ('raise', 'I-VP'),
#   ('its', 'B-NP'),
#   ('stake', 'I-NP'),
#   ('to', 'B-PP'),
#   ('60', 'B-NP'),
#   ('%', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Treasury', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('benchmark', 'I-NP'),
#   ('30-year', 'I-NP'),
#   ('bond', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('more', 'B-NP'),
#   ('than', 'I-NP'),
#   ('1\\/2', 'I-NP'),
#   ('point', 'I-NP'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('over', 'B-PP'),
#   ('$', 'B-NP'),
#   ('5', 'I-NP'),
#   ('for', 'B-PP'),
#   ('each', 'B-NP'),
#   ('$', 'I-NP'),
#   ('1,000', 'I-NP'),
#   ('face', 'I-NP'),
#   ('amount', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('yield', 'I-NP'),
#   ('moved', 'B-VP'),
#   ('above', 'B-PP'),
#   ('8', 'B-NP'),
#   ('%', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('first', 'I-NP'),
#   ('time', 'I-NP'),
#   ('since', 'B-PP'),
#   ('Thursday', 'B-NP'),
#   ('.', 'O')],
#  [('Yet', 'B-ADVP'),
#   ('her', 'B-NP'),
#   ('intensity', 'I-NP'),
#   ('stops', 'I-NP'),
#   ('and', 'I-NP'),
#   ('starts', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('music', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('results', 'B-VP'),
#   ('compare', 'I-VP'),
#   ('with', 'B-PP'),
#   ('a', 'B-NP'),
#   ('year-earlier', 'I-NP'),
#   ('net', 'I-NP'),
#   ('loss', 'I-NP'),
#   ('of', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.5', 'I-NP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('seven', 'B-NP'),
#   ('cents', 'I-NP'),
#   ('a', 'B-NP'),
#   ('share', 'I-NP'),
#   (',', 'O'),
#   ('based', 'B-VP'),
#   ('on', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('million', 'I-NP'),
#   ('common', 'I-NP'),
#   ('and', 'I-NP'),
#   ('dilutive', 'I-NP'),
#   ('equivalents', 'I-NP'),
#   ('outstanding', 'B-ADJP'),
#   ('.', 'O')],
#  [('Revenue', 'B-NP'),
#   ('dropped', 'B-VP'),
#   ('1.6', 'B-NP'),
#   ('%', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.21', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.23', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('.', 'O')],
#  [('Charleston', 'B-NP'),
#   ('is', 'B-NP'),
#   ('historic', 'B-NP'),
#   ('and', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'B-NP'),
#   ('as', 'B-NP'),
#   ('your', 'B-NP'),
#   ('reporter', 'B-NP'),
#   ('said', 'B-NP'),
#   (',', 'B-NP'),
#   ('but', 'B-NP'),
#   ('not', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'B-NP'),
#   ('as', 'B-NP'),
#   ('he', 'B-NP'),
#   ('suggested', 'B-NP'),
#   ('.', 'B-NP')],
#  [('This', 'B-NP'),
#   ('magazine', 'I-NP'),
#   ('and', 'I-NP'),
#   ('book', 'I-NP'),
#   ('publisher', 'I-NP'),
#   ('said', 'B-VP'),
#   ('three', 'B-NP'),
#   ('men', 'I-NP'),
#   ('were', 'B-VP'),
#   ('elected', 'I-VP'),
#   ('directors', 'B-NP'),
#   (',', 'O'),
#   ('increasing', 'B-VP'),
#   ('the', 'B-NP'),
#   ('board', 'I-NP'),
#   ('to', 'B-PP'),
#   ('10', 'B-NP'),
#   ('.', 'O')],
#  [('Among', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Guinness', 'I-NP'),
#   ('disk', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('wonders', 'B-NP'),
#   (':', 'O'),
#   ('the', 'B-NP'),
#   ('world', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('recorded', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('company', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('is', 'B-VP'),
#   ('retaining', 'B-NP'),
#   ('most', 'I-NP'),
#   ('of', 'B-PP'),
#   ('its', 'B-NP'),
#   ('wine', 'B-UCP'),
#   ('and', 'I-UCP'),
#   ('all', 'B-NP'),
#   ('of', 'B-PP'),
#   ('its', 'B-NP'),
#   ('soft-drink', 'I-NP'),
#   ('interests', 'I-NP'),
#   (',', 'O'),
#   ('did', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('break', 'I-VP'),
#   ('out', 'B-PRT'),
#   ('results', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('businesses', 'I-NP'),
#   ('it', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'I-VP'),
#   ('sell', 'I-VP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('press', 'I-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('doing', 'I-VP'),
#   ('an', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('job', 'I-NP'),
#   ('.', 'O')],
#  [('Two', 'B-NP'),
#   ('rules', 'I-NP'),
#   ('in', 'B-PP'),
#   ('pending', 'B-NP'),
#   ('congressional', 'I-NP'),
#   ('legislation', 'I-NP'),
#   ('threaten', 'B-VP'),
#   ('to', 'I-VP'),
#   ('hinder', 'I-VP'),
#   ('leveraged', 'B-NP'),
#   ('buy-outs', 'I-NP'),
#   ('by', 'B-PP'),
#   ('raising', 'B-VP'),
#   ('the', 'B-NP'),
#   ('price', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'B-PP'),
#   ('such', 'B-NP'),
#   ('deals', 'I-NP'),
#   ('by', 'B-PP'),
#   ('as', 'I-PP'),
#   ('much', 'B-NP'),
#   ('as', 'B-PP'),
#   ('10', 'B-NP'),
#   ('%', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('We', 'B-NP'),
#   ('hope', 'I-NP'),
#   ('to', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('employers', 'I-NP'),
#   ("''", 'O'),
#   ('to', 'B-VP'),
#   ('recognize', 'I-VP'),
#   ('the', 'B-NP'),
#   ('problems', 'I-NP'),
#   ('so', 'O'),
#   ('they', 'B-NP'),
#   ('can', 'B-VP'),
#   ('do', 'I-VP'),
#   ('something', 'B-NP'),
#   ('about', 'B-PP'),
#   ('them', 'B-NP'),
#   (',', 'O'),
#   ('Dr.', 'B-NP'),
#   ('Warshaw', 'I-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('year', 'I-NP'),
#   ('earlier', 'B-ADVP'),
#   ('sales', 'B-NP'),
#   ('totaled', 'B-VP'),
#   ('#UNK#', 'B-NP'),
#   ('billion', 'I-NP'),
#   ('francs', 'I-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('We', 'B-NP'),
#   ("'re", 'B-VP'),
#   ('encouraging', 'B-VP'),
#   ('a', 'B-NP'),
#   ('graceful', 'I-NP'),
#   ('transition', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('says', 'B-VP'),
#   ('Mary', 'B-NP'),
#   ('Kay', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('organization', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('president', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Taxpayers', 'I-NP'),
#   ('Union', 'I-NP'),
#   ('would', 'B-VP'),
#   ('like', 'B-PP'),
#   ('Congress', 'B-NP'),
#   ('to', 'B-NP'),
#   ('add', 'B-NP'),
#   ('800,000', 'B-NP'),
#   ('acres', 'B-NP'),
#   ('to', 'B-NP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('of', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('in', 'B-NP'),
#   ('the', 'B-NP'),
#   ('system', 'B-NP'),
#   ('by', 'B-NP'),
#   ('enacting', 'B-NP'),
#   ('``', 'B-NP'),
#   ('The', 'B-NP'),
#   ('Coastal', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('Act', 'B-NP'),
#   ('of', 'B-NP'),
#   ('1989', 'B-NP'),
#   ('.', 'B-NP'),
#   ("''", 'B-NP')],
#  [('Digital', 'B-NP'),
#   ("'s", 'B-NP'),
#   ('failure', 'I-NP'),
#   ('to', 'B-VP'),
#   ('deliver', 'I-VP'),
#   ('a', 'B-NP'),
#   ('true', 'I-NP'),
#   ('mainframe-class', 'I-NP'),
#   ('machine', 'I-NP'),
#   ('before', 'B-PP'),
#   ('now', 'B-ADVP'),
#   ('may', 'B-VP'),
#   ('have', 'I-VP'),
#   ('cost', 'I-VP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ('as', 'B-ADVP'),
#   ('much', 'I-ADVP'),
#   ('as', 'B-SBAR'),
#   ('$', 'B-NP'),
#   ('1', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('in', 'B-PP'),
#   ('revenue', 'B-NP'),
#   ('in', 'B-PP'),
#   ('fiscal', 'B-NP'),
#   ('1989', 'I-NP'),
#   (',', 'O'),
#   ('Mr.', 'B-NP'),
#   ('Willman', 'I-NP'),
#   ('says', 'B-VP'),
#   ('.', 'O')],
#  [('It', 'B-NP'), ('is', 'B-VP'), ("n't", 'I-VP'), ('.', 'O')],
#  [('Detroit', 'B-NP'),
#   ('Edison', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('plan', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('generated', 'B-VP'),
#   ('$', 'B-NP'),
#   ('54,000', 'B-NP'),
#   ('in', 'B-PP'),
#   ('matching', 'B-VP'),
#   ('funds', 'B-NP'),
#   ('this', 'I-NP'),
#   ('year', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-ADVP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('1988', 'B-NP'),
#   ('.', 'O')],
#  [('Along', 'B-PP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('car', 'I-NP'),
#   (',', 'O'),
#   ('Wacoal', 'B-NP'),
#   ('plans', 'B-VP'),
#   ('to', 'I-VP'),
#   ('launch', 'I-VP'),
#   ('a', 'B-NP'),
#   ('series', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('men', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('underwear', 'I-NP'),
#   ('.', 'O')],
#  [('A', 'B-NP'),
#   ('columnist', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Atlanta', 'I-NP'),
#   ('Journal', 'I-NP'),
#   ('and', 'I-NP'),
#   ('Constitution', 'I-NP'),
#   ('wrote', 'B-VP'),
#   (':', 'O'),
#   ('``', 'O'),
#   ('Who', 'B-NP'),
#   ('did', 'B-VP'),
#   ('the', 'B-NP'),
#   ('research', 'I-NP'),
#   ('for', 'B-PP'),
#   ('this', 'B-NP'),
#   ('report', 'I-NP'),
#   ('?', 'O')],
#  [('Computer', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('Corp.', 'I-NP'),
#   (',', 'O'),
#   ('El', 'B-NP'),
#   ('Segundo', 'I-NP'),
#   (',', 'O'),
#   ('Calif.', 'B-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('the', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Aeronautics', 'I-NP'),
#   ('and', 'I-NP'),
#   ('Space', 'I-NP'),
#   ('Administration', 'I-NP'),
#   ('will', 'B-VP'),
#   ('negotiate', 'I-VP'),
#   ('details', 'B-NP'),
#   ('of', 'B-PP'),
#   ('a', 'B-NP'),
#   ('contract', 'I-NP'),
#   ('valued', 'B-VP'),
#   ('at', 'B-PP'),
#   ('about', 'B-NP'),
#   ('$', 'I-NP'),
#   ('170', 'I-NP'),
#   ('million', 'I-NP'),
#   ('to', 'B-VP'),
#   ('provide', 'I-VP'),
#   ('software', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Ames', 'I-NP'),
#   ('Research', 'I-NP'),
#   ('Center', 'I-NP'),
#   ('.', 'O')],
#  [('He', 'B-NP'),
#   ('was', 'B-VP'),
#   ('a', 'B-NP'),
#   ('``', 'O'),
#   ('socialist', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ("''", 'O'),
#   ('who', 'B-NP'),
#   ('felt', 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('by', 'B-PP'),
#   ('West', 'B-NP'),
#   ('Germany', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('enormous', 'B-NP'),
#   ('postwar', 'I-NP'),
#   ('prosperity', 'I-NP'),
#   ('and', 'O'),
#   ('the', 'B-NP'),
#   ('Bonn', 'I-NP'),
#   ('government', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('#UNK#', 'I-VP'),
#   ('#UNK#', 'I-VP'),
#   ('to', 'I-VP'),
#   ('recognize', 'I-VP'),
#   ('the', 'B-NP'),
#   ('legitimacy', 'I-NP'),
#   ('of', 'B-PP'),
#   ('his', 'B-NP'),
#   ('state', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('Senate', 'I-NP'),
#   ('estimates', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('its', 'B-NP'),
#   ('version', 'I-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('provision', 'I-NP'),
#   ('would', 'B-VP'),
#   ('yield', 'I-VP'),
#   ('$', 'B-NP'),
#   ('17', 'I-NP'),
#   ('million', 'I-NP'),
#   ('the', 'B-NP'),
#   ('first', 'I-NP'),
#   ('year', 'I-NP'),
#   ('and', 'O'),
#   ('a', 'B-NP'),
#   ('total', 'I-NP'),
#   ('of', 'B-PP'),
#   ('$', 'B-NP'),
#   ('409', 'I-NP'),
#   ('million', 'I-NP'),
#   ('over', 'B-PP'),
#   ('five', 'B-NP'),
#   ('years', 'I-NP'),
#   ('.', 'O')],
#  [('Trinova', 'B-NP'),
#   ('third-quarter', 'I-NP'),
#   ('loss', 'I-NP'),
#   ('after', 'B-PP'),
#   ('a', 'B-NP'),
#   ('charge', 'I-NP'),
#   ('for', 'B-PP'),
#   ('a', 'B-NP'),
#   ('planned', 'I-NP'),
#   ('restructuring', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('will', 'B-VP'),
#   ('include', 'I-VP'),
#   ('the', 'B-NP'),
#   ('closing', 'I-NP'),
#   ('or', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('of', 'B-PP'),
# ...
#   ('division', 'I-NP'),
#   ('.', 'O')],
#  [('And', 'O'),
#   ('they', 'B-NP'),
#   ('wo', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('consider', 'I-VP'),
#   ('such', 'B-PP'),
#   ('a', 'B-NP'),
#   ('dividend', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('trust', 'I-NP'),
#   ('added', 'B-VP'),
#   (',', 'O'),
#   ('before', 'B-PP'),
#   ('results', 'B-NP'),
#   ('are', 'B-VP'),
#   ('available', 'B-ADJP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('first', 'I-NP'),
#   ('quarter', 'I-NP'),
#   ('of', 'B-PP'),
#   ('1990', 'B-NP'),
#   ('.', 'O')],
#  [('Sales', 'B-NP'),
#   ('rose', 'B-VP'),
#   ('5.2', 'B-NP'),
#   ('%', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('2.04', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('the', 'B-NP'),
#   ('previous', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('Data', 'B-NP'),
#   ('for', 'B-PP'),
#   ('1987', 'B-NP'),
#   ('from', 'B-PP'),
#   ('the', 'B-NP'),
#   ('National', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('Systems', 'I-NP'),
#   ('and', 'O'),
#   ('the', 'B-NP'),
#   ('Japan', 'B-NP'),
#   ('Human', 'I-NP'),
#   ('Relations', 'I-NP'),
#   ('Association', 'I-NP'),
#   ('also', 'B-ADVP'),
#   ('indicate', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('Japanese', 'B-NP'),
#   ('employers', 'I-NP'),
#   ('adopt', 'B-VP'),
#   ('four', 'B-NP'),
#   ('of', 'B-PP'),
#   ('five', 'B-NP'),
#   ('suggestions', 'I-NP'),
#   (',', 'O'),
#   ('while', 'B-SBAR'),
#   ('their', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('counterparts', 'I-NP'),
#   ('accept', 'B-VP'),
#   ('just', 'B-NP'),
#   ('one', 'I-NP'),
#   ('in', 'B-PP'),
#   ('four', 'B-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('returns', 'I-NP'),
#   ('landed', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('hands', 'I-NP'),
#   ('of', 'B-PP'),
#   ('an', 'B-NP'),
#   ('Internal', 'I-NP'),
#   ('Revenue', 'B-NP'),
#   ('Service', 'I-NP'),
#   ('criminal', 'I-NP'),
#   ('investigator', 'I-NP'),
#   (',', 'O'),
#   ('Samuel', 'B-NP'),
#   ('James', 'I-NP'),
#   ('Baker', 'I-NP'),
#   ('.', 'O')],
#  [('Mr.', 'B-NP'),
#   ('Kelly', 'I-NP'),
#   ('built', 'B-VP'),
#   ('the', 'B-NP'),
#   ('company', 'I-NP'),
#   ("'s", 'B-VP'),
#   ('high-yield', 'B-NP'),
#   ('bond', 'I-NP'),
#   ('group', 'I-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('a', 'B-NP'),
#   ('minor', 'I-NP'),
#   ('player', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('junk-bond', 'I-NP'),
#   ('arena', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('result', 'I-NP'),
#   ('is', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('some', 'B-NP'),
#   ('franchisees', 'I-NP'),
#   ('are', 'B-VP'),
#   ('running', 'I-VP'),
#   ('hard', 'B-ADJP'),
#   ('just', 'I-ADJP'),
#   ('to', 'B-VP'),
#   ('stay', 'I-VP'),
#   ('even', 'I-VP'),
#   (',', 'I-VP'),
#   ('laying', 'I-VP'),
#   ('off', 'B-PRT'),
#   ('middle', 'B-NP'),
#   ('managers', 'I-NP'),
#   ('and', 'O'),
#   ('working', 'B-VP'),
#   ('harder', 'B-ADVP'),
#   ('to', 'B-VP'),
#   ('make', 'I-VP'),
#   ('less', 'B-ADJP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('&', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('small', 'I-NP'),
#   ('New', 'I-NP'),
#   ('York', 'I-NP'),
#   ('shop', 'B-VP'),
#   (',', 'B-NP'),
#   ('is', 'B-NP'),
#   ('asking', 'B-NP'),
#   ('magazine', 'B-NP'),
#   ('ad', 'B-NP'),
#   ('representatives', 'B-NP'),
#   ('to', 'B-NP'),
#   ('tell', 'B-NP'),
#   ('it', 'B-NP'),
#   ('when', 'B-NP'),
#   ('major', 'B-NP'),
#   ('advertising', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('will', 'B-NP'),
#   ('run', 'B-NP'),
#   ('in', 'B-NP'),
#   ('their', 'B-NP'),
#   ('publications', 'B-NP'),
#   ('.', 'B-NP')],
#  [('In', 'B-PP'),
#   ('addition', 'B-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('is', 'B-VP'),
#   ('scheduled', 'I-VP'),
#   ('to', 'I-VP'),
#   ('unveil', 'I-VP'),
#   ('plans', 'B-NP'),
#   ('for', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('Philippine', 'I-NP'),
#   ('Airlines', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('national', 'I-NP'),
#   ('carrier', 'I-NP'),
#   (',', 'O'),
#   ('an', 'B-NP'),
#   ('effort', 'I-NP'),
#   ('that', 'B-NP'),
#   ('lawyer', 'I-NP'),
#   ('and', 'O'),
#   ('business', 'B-NP'),
#   ('columnist', 'I-NP'),
#   ('#UNK#', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('calls', 'I-NP'),
#   ('``', 'O'),
#   ('the', 'B-NP'),
#   ('bellwether', 'I-NP'),
#   ('of', 'B-PP'),
#   ('privatization', 'B-NP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('An', 'B-NP'),
#   ('experimental', 'I-NP'),
#   ('vaccine', 'I-NP'),
#   ('can', 'B-VP'),
#   ('alter', 'I-VP'),
#   ('the', 'B-NP'),
#   ('immune', 'I-NP'),
#   ('response', 'I-NP'),
#   ('of', 'B-PP'),
#   ('people', 'B-NP'),
#   ('infected', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('AIDS', 'I-NP'),
#   ('virus', 'I-NP'),
#   (',', 'O'),
#   ('a', 'B-NP'),
#   ('prominent', 'I-NP'),
#   ('U.S.', 'I-NP'),
#   ('scientist', 'I-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('In', 'B-PP'),
#   ('addition', 'B-NP'),
#   (',', 'O'),
#   ('long-term', 'B-NP'),
#   ('debt', 'I-NP'),
#   ('has', 'B-VP'),
#   ('been', 'I-VP'),
#   ('trimmed', 'I-VP'),
#   ('to', 'I-VP'),
#   ('about', 'B-PP'),
#   ('$', 'B-NP'),
#   ('72', 'B-NP'),
#   ('million', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('96', 'I-NP'),
#   ('million', 'I-NP'),
#   ('since', 'B-PP'),
#   ('Jan.', 'B-NP'),
#   ('1', 'I-NP'),
#   ('.', 'O')],
#  [('New', 'B-NP'),
#   ('York', 'I-NP'),
#   ('real', 'I-NP'),
#   ('estate', 'I-NP'),
#   ('brokerage', 'I-NP'),
#   ('Edward', 'I-NP'),
#   ('S.', 'I-NP'),
#   ('Gordon', 'B-NP'),
#   ('Co.', 'I-NP'),
#   ('will', 'B-VP'),
#   ('have', 'I-VP'),
#   ('the', 'B-NP'),
#   ('difficult', 'I-NP'),
#   ('task', 'I-NP'),
#   ('of', 'B-PP'),
#   ('finding', 'B-VP'),
#   ('new', 'B-NP'),
#   ('tenants', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'),
#   ('revenue', 'I-NP'),
#   ('was', 'B-VP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-ADVP'),
#   ('12', 'B-NP'),
#   ('%', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('million', 'I-NP'),
#   ('last', 'I-NP'),
#   ('year', 'I-NP'),
#   ('.', 'O')],
#  [('As', 'B-SBAR'),
#   ('former', 'B-NP'),
#   ('Ambassador', 'I-NP'),
#   ('to', 'B-PP'),
#   ('Costa', 'B-NP'),
#   ('Rica', 'I-NP'),
#   ('Francis', 'I-NP'),
#   ('J.', 'I-NP'),
#   ('McNeil', 'I-NP'),
#   ('testified', 'B-VP'),
#   ('before', 'B-PP'),
#   ('the', 'B-NP'),
#   ('subcommittee', 'I-NP'),
#   (',', 'O'),
#   ('the', 'B-NP'),
#   ('Reagan', 'I-NP'),
#   ('administration', 'I-NP'),
#   ('knew', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('Gen.', 'B-NP'),
#   ('Noriega', 'I-NP'),
#   ('was', 'B-VP'),
#   ('involved', 'I-VP'),
#   ('with', 'B-PP'),
#   ('narcotics', 'B-NP'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('made', 'B-VP'),
#   ('a', 'B-NP'),
#   ('decision', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('summer', 'I-NP'),
#   ('of', 'B-PP'),
#   ('1986', 'B-NP'),
#   ('``', 'O'),
#   ('to', 'B-VP'),
#   ('put', 'I-VP'),
#   ('Gen.', 'B-NP'),
#   ('Noriega', 'I-NP'),
#   ('on', 'B-PP'),
#   ('the', 'B-NP'),
#   ('shelf', 'B-NP'),
#   ('until', 'B-PP'),
#   ('Nicaragua', 'B-NP'),
#   ('was', 'B-VP'),
#   ('settled', 'I-VP'),
#   ('.', 'O'),
#   ("''", 'O')],
#  [('Retired', 'B-NP'),
#   ('army', 'I-NP'),
#   ('Chief', 'I-NP'),
#   ('of', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   ('in', 'B-PP'),
#   ('an', 'B-NP'),
#   ('interview', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('he', 'B-NP'),
#   ('suggested', 'B-VP'),
#   ('in', 'B-PP'),
#   ('May', 'B-NP'),
#   ('1987', 'I-NP'),
#   ('that', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('government', 'I-NP'),
#   ('cancel', 'B-VP'),
#   ('the', 'B-NP'),
#   ('Bofors', 'I-NP'),
#   ('contract', 'I-NP'),
#   ('.', 'O')],
#  [('Sales', 'B-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('quarter', 'I-NP'),
#   ('rose', 'B-VP'),
#   ('to', 'I-VP'),
#   ('$', 'B-NP'),
#   ('1.11', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('from', 'B-PP'),
#   ('$', 'B-NP'),
#   ('1.03', 'I-NP'),
#   ('billion', 'I-NP'),
#   ('.', 'O')],
#  [('#UNK#', 'B-NP'), ('#UNK#', 'I-NP'), (':', 'O')],
#  [('He', 'B-NP'),
#   ('knew', 'B-VP'),
#   ('which', 'B-NP'),
#   ('local', 'I-NP'),
#   ('luminaries', 'I-NP'),
#   ('had', 'B-VP'),
#   ('been', 'I-VP'),
#   ('caught', 'I-VP'),
#   ('driving', 'I-VP'),
#   ('#UNK#', 'B-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('had', 'B-VP'),
#   ('been', 'I-VP'),
#   ('found', 'I-VP'),
#   ('with', 'B-PP'),
#   ('their', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('.', 'O')],
#  [('I', 'B-NP'),
#   ('suggest', 'B-VP'),
#   ('that', 'B-SBAR'),
#   ('The', 'B-NP'),
#   ('Wall', 'I-NP'),
#   ('Street', 'I-NP'),
#   ('Journal', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('as', 'B-CONJP'),
#   ('well', 'I-CONJP'),
#   ('as', 'I-CONJP'),
#   ('other', 'B-NP'),
#   ('U.S.', 'I-NP'),
#   ('news', 'I-NP'),
#   ('publications', 'I-NP'),
#   ('of', 'B-PP'),
#   ('like', 'B-PP'),
#   ('mind', 'B-NP'),
#   ('-RRB-', 'O'),
#   ('should', 'B-VP'),
#   ('put', 'I-VP'),
#   ('its', 'B-NP'),
#   ('money', 'I-NP'),
#   ('where', 'B-ADVP'),
#   ('its', 'B-NP'),
#   ('mouth', 'I-NP'),
#   ('is', 'B-VP'),
#   (':', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('computer', 'I-NP'),
#   ('equipment', 'I-NP'),
#   ('to', 'B-VP'),
#   ('replace', 'I-VP'),
#   ('that', 'B-SBAR'),
#   ('damaged', 'B-NP'),
#   ('at', 'B-PP'),
#   ('El', 'B-NP'),
#   ('Espectador', 'I-NP'),
#   (',', 'O'),
#   ('buy', 'B-NP'),
#   ('ad', 'I-NP'),
#   ('space', 'I-NP'),
#   (',', 'B-VP'),
#   ('publish', 'I-VP'),
#   ('stories', 'B-NP'),
#   ('under', 'B-PP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('of', 'B-PP'),
#   ('El', 'B-NP'),
#   ('Espectador', 'I-NP'),
#   ('journalists', 'I-NP'),
#   ('.', 'O')],
#  [('The', 'B-NP'),
#   ('amount', 'I-NP'),
#   ('would', 'B-VP'),
#   ('help', 'I-VP'),
#   ('Los', 'B-NP'),
#   ('Angeles', 'B-NP'),
#   ('cope', 'B-NP'),
#   ('in', 'B-NP'),
#   ('the', 'B-NP'),
#   ('first', 'B-NP'),
#   ('few', 'B-NP'),
#   ('weeks', 'B-NP'),
#   ('after', 'B-NP'),
#   ('its', 'B-NP'),
#   ('own', 'B-NP'),
#   ('anticipated', 'B-NP'),
#   ('quake', 'B-NP'),
#   (',', 'B-NP'),
#   ('while', 'B-NP'),
#   ('waiting', 'B-NP'),
#   ('for', 'B-NP'),
#   ('federal', 'B-NP'),
#   ('assistance', 'B-NP'),
#   ('to', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'B-NP')],
#  [('Your', 'B-NP'),
#   ('Oct.', 'I-NP'),
#   ('12', 'I-NP'),
#   ('editorial', 'I-NP'),
#   ('``', 'O'),
#   ('#UNK#', 'B-NP'),
#   (',', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('?', 'O'),
#   ("''", 'O'),
#   ('correctly', 'B-VP'),
#   ('states', 'B-NP'),
#   ('that', 'B-SBAR'),
#   ('I', 'B-NP'),
#   ('was', 'B-VP'),
#   ('critical', 'B-ADJP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Bush', 'I-NP'),
#   ('administration', 'I-NP'),
#   ("'s", 'B-NP'),
#   ('failure', 'I-NP'),
#   ('to', 'B-VP'),
#   ('have', 'I-VP'),
#   ('any', 'B-NP'),
#   ('plan', 'I-NP'),
#   ('in', 'B-PP'),
#   ('place', 'B-NP'),
#   ('to', 'B-VP'),
#   ('respond', 'I-VP'),
#   ('in', 'B-PP'),
#   ('a', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('fashion', 'I-NP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('opportunities', 'B-NP'),
#   ('to', 'B-NP'),
#   ('oust', 'B-NP'),
#   ('Manuel', 'B-NP'),
#   ('Noriega', 'B-NP'),
#   ('presented', 'B-NP'),
#   ('by', 'B-NP'),
#   ('the', 'B-NP'),
#   ('attempted', 'B-NP'),
#   ('military', 'B-NP'),
#   ('coup', 'B-NP'),
#   ('on', 'B-NP'),
#   ('Oct.', 'B-NP'),
#   ('3', 'B-NP'),
#   ('.', 'B-NP')],
#  [('Mr.', 'B-NP'),
#   ('Bakes', 'I-NP'),
#   ('declined', 'B-VP'),
#   ('to', 'I-VP'),
#   ('give', 'I-VP'),
#   ('out', 'B-PRT'),
#   ('Eastern', 'B-NP'),
#   ("'s", 'B-VP'),
#   ('daily', 'B-NP'),
#   ('losses', 'I-NP'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('said', 'B-VP'),
#   ('he', 'B-NP'),
#   ('did', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('expect', 'I-VP'),
#   ('Eastern', 'B-NP'),
#   ('would', 'B-VP'),
#   ('have', 'I-VP'),
#   ('to', 'I-VP'),
#   ('dip', 'I-VP'),
#   ('into', 'B-PP'),
#   ('the', 'B-NP'),
#   ('cash', 'I-NP'),
#   ('from', 'B-PP'),
#   ('asset', 'B-NP'),
#   ('sales', 'I-NP'),
#   ('currently', 'B-VP'),
#   ('held', 'I-VP'),
#   ('in', 'B-PP'),
#   ('#UNK#', 'B-NP'),
#   ('.', 'O')],
#  [('What', 'B-NP'),
#   ('happens', 'B-VP'),
#   ('if', 'B-SBAR'),
#   ('the', 'B-NP'),
#   ('sponsors', 'I-NP'),
#   ('do', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('have', 'I-VP'),
#   ('the', 'B-NP'),
#   ('cash', 'I-NP'),
#   ('to', 'B-VP'),
#   ('pay', 'I-VP'),
#   ('the', 'B-NP'),
#   ('tuitions', 'I-NP'),
#   ('?', 'O')],
#  [('He', 'B-NP'),
#   ('said', 'B-VP'),
#   ('he', 'B-NP'),
#   ('monitors', 'I-NP'),
#   ('the', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('figures', 'I-NP'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('does', 'B-VP'),
#   ("n't", 'I-VP'),
#   ('give', 'I-VP'),
#   ('them', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('importance', 'I-NP'),
#   (',', 'O'),
#   ('as', 'B-SBAR'),
#   ('some', 'B-NP'),
#   ('private', 'I-NP'),
#   ('and', 'I-NP'),
#   ('government', 'I-NP'),
#   ('economists', 'I-NP'),
#   ('have', 'B-VP'),
#   ('suggested', 'I-VP'),
#   ('.', 'O')],
#  [('Dr.', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('city', 'B-NP'),
#   ('health', 'I-NP'),
#   ('director', 'I-NP'),
#   (',', 'O'),
#   ('said', 'B-VP'),
#   ('his', 'B-NP'),
#   ('staff', 'I-NP'),
#   ('suspects', 'B-VP'),
#   ('the', 'B-NP'),
#   ('hepatitis', 'B-NP'),
#   (',', 'O'),
#   ('which', 'B-NP'),
#   ('can', 'B-VP'),
#   ('be', 'I-VP'),
#   ('highly', 'B-NP'),
#   ('contagious', 'I-NP'),
#   (',', 'O'),
#   ('was', 'B-VP'),
#   ('spread', 'I-VP'),
#   ('by', 'B-PP'),
#   ('the', 'B-NP'),
#   ('cafeteria', 'I-NP'),
#   ('worker', 'I-NP'),
#   ('with', 'B-PP'),
#   ('the', 'B-NP'),
#   ('virus', 'I-NP'),
#   ('.', 'O')],
#  [('Hewlett-Packard', 'B-NP'),
#   ('Co.', 'I-NP'),
#   ('also', 'B-ADVP'),
#   ('has', 'B-VP'),
#   ('begun', 'I-VP'),
#   ('to', 'B-PP'),
#   ('gain', 'B-NP'),
#   ('share', 'I-NP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('whole', 'I-NP'),
#   ('computer-integrated-manufacturing', 'I-NP'),
#   ('arena', 'I-NP'),
#   ('.', 'O')],
#  [('Georgia', 'B-NP'),
#   ('Pacific', 'I-NP'),
#   ('Corp.', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-ADVP'),
#   ('$', 'B-NP'),
#   ('1.25', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('58', 'I-NP'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('Inc.', 'I-NP'),
#   (',', 'O'),
#   ('up', 'B-ADVP'),
#   ('$', 'B-NP'),
#   ('3', 'I-NP'),
#   ('to', 'B-PP'),
#   ('$', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('both', 'B-NP'),
#   ('reported', 'B-VP'),
#   ('strong', 'B-NP'),
#   ('profits', 'I-NP'),
#   ('.', 'O')],
#  [('Japanese', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   ('maker', 'I-NP'),
#   ('Daikin', 'I-NP'),
#   ('Industries', 'I-NP'),
#   ('Ltd.', 'I-NP'),
#   ('was', 'B-VP'),
#   ('fined', 'B-VP'),
#   ('two', 'B-NP'),
#   ('million', 'I-NP'),
#   ('yen', 'I-NP'),
#   ('-LRB-', 'O'),
#   ('$', 'B-NP'),
#   ('14,000', 'I-NP'),
#   ('-RRB-', 'O'),
#   ('for', 'B-NP'),
#   ('exporting', 'B-NP'),
#   ('to', 'B-NP'),
#   ('the', 'B-NP'),
#   ('Soviet', 'B-NP'),
#   ('Union', 'B-NP'),
#   ('a', 'B-NP'),
#   ('chemical', 'B-NP'),
#   ('solution', 'B-NP'),
#   ('that', 'B-NP'),
#   ('could', 'B-NP'),
#   ('be', 'B-NP'),
#   ('used', 'B-NP'),
#   ('in', 'B-NP'),
#   ('#UNK#', 'B-NP'),
#   ('systems', 'B-NP'),
#   ('.', 'B-NP')],
#  [('October', 'B-NP'),
#   ('is', 'B-VP'),
#   ('a', 'B-NP'),
#   ('critical', 'I-NP'),
#   ('month', 'I-NP'),
#   ('for', 'B-PP'),
#   ('the', 'B-NP'),
#   ('privatization', 'I-NP'),
#   ('program', 'I-NP'),
#   ('.', 'O')],
#  [('Since', 'B-SBAR'),
#   ('40', 'B-NP'),
#   ('%', 'I-NP'),
#   ('of', 'B-PP'),
#   ('skiers', 'B-NP'),
#   ('are', 'B-VP'),
#   ('parents', 'B-NP'),
#   (',', 'O'),
#   ('many', 'B-NP'),
#   ('slopes', 'I-NP'),
#   ('are', 'B-VP'),
#   ('building', 'B-NP'),
#   ('#UNK#', 'I-NP'),
#   (',', 'O'),
#   ('expanding', 'B-VP'),
#   ('ski', 'B-NP'),
#   ('schools', 'I-NP'),
#   ('and', 'O'),
#   ('adding', 'B-VP'),
#   ('entertainment', 'B-NP'),
#   ('for', 'B-PP'),
#   ('kids', 'B-NP'),
#   ('.', 'O')],
#  [('``', 'O'),
#   ('The', 'B-NP'),
#   ('merger', 'I-NP'),
#   ('is', 'B-VP'),
#   ('proceeding', 'I-VP'),
#   ('according', 'B-PP'),
#   ('to', 'B-VP'),
#   ('plan', 'I-VP'),
#   (',', 'O'),
#   ('except', 'B-PP'),
#   ('as', 'I-PP'),
#   ('to', 'B-PP'),
#   ('the', 'B-NP'),
#   ('withdrawal', 'I-NP'),
#   ('of', 'B-PP'),
#   ('the', 'B-NP'),
#   ('Deloitte', 'I-NP'),
#   ('U.K.', 'I-NP'),
#   ('firm', 'I-NP'),
#   (',', 'O'),
#   ("''", 'O'),
#   ('he', 'B-NP'),
#   ('said', 'B-VP'),
#   ('.', 'O')],
#  [('Elected', 'B-VP'),
#   ('to', 'I-VP'),
#   ('Congress', 'B-NP'),
#   ('as', 'B-PP'),
#   ('a', 'B-NP'),
#   ('``', 'O'),
#   ('#UNK#', 'B-NP'),
#   ('baby', 'I-NP'),
#   ("''", 'O'),
#   ('in', 'B-PP'),
#   ('1974', 'B-NP'),
#   (',', 'O'),
#   ('he', 'B-NP'),
#   ('ran', 'B-VP'),
#   ('for', 'B-PP'),
#   ('governor', 'B-NP'),
#   ('three', 'I-NP'),
#   ('years', 'I-NP'),
#   ('later', 'B-ADVP'),
#   ('.', 'O')],
#  [('Only', 'B-ADVP'),
#   ('a', 'B-NP'),
#   ('few', 'I-NP'),
#   ('books', 'I-NP'),
#   ('fell', 'B-VP'),
#   ('in', 'B-PP'),
#   ('the', 'B-NP'),
#   ('reading', 'I-NP'),
#   ('room', 'I-NP'),
#   ('.', 'O')],
#  ...]

# %%
write_tag_predictions_to_file(predictions, 'EN/dev.p2.out')

# %%
# !python EvalScript/evalResult.py EN/dev.out EN/dev.p2.out
# Out:
# #Entity in gold data: 13179
# #Entity in prediction: 14279
#
# #Correct Entity : 10858
# Entity  precision: 0.7604
# Entity  recall: 0.8239
# Entity  F: 0.7909
#
# #Correct Sentiment : 10056
# Sentiment  precision: 0.7043
# Sentiment  recall: 0.7630
# Sentiment  F: 0.7325

# %% [markdown]
# ### Part 3

# %%
# lets try just storing the best 2 paths at each point, then at the final stop state,

# %%
#Just copy pastad this here for easy reference first.
def viterbi_algorithm2(sentence, tag_count, transmission_probabilities, emission_probabilities, unk = 0.1):

    # make sure that "sentence" is a sequence of x observations
    tags = [tag for tag in tag_count if tag not in ['START', 'STOP']] # makes a dictionary of tags that doesnt include start and stop, so we dont iterate through them unncessarily
    tag_count.pop('START')
    tag_count.pop('STOP')
    
    n = len(sentence)  # number of words in the sentence (k)
    m = len(tags)      # number of tags (u / v)

    # create a matrix to store all the pi values
    pi = [[float('-inf'), float('-inf')] * m for _ in range(n+1)] #+1 tp account for the stop state, but we dont actually store anything theer
    backpointer = [[0] * m for _ in range(n)] # to store y*

    pi_2 = [[float('-inf'), float('-inf')] * m for _ in range(n+1)]
    backpointer_2 = [[0] * m for _ in range(n)] # to store y*

    # base case!!!, here, we actually just initialise the first column to be pi(0,v) where u is "START". 
    # we skip the step of assigning pi(0,v) = 1 if v is start and 0 otherwise
    for i, tag in enumerate(tags): # i is the index of the tag
        t_count = tag_count[tag]
        pi[0][i] = transmission_probabilities.get(('START', tag), 0) * emission_probabilities.get((sentence[0], tag), 0)
#         if tag == "START":
#             pi[0,i] = 1
#         elif tag == "STOP": # we only do this because tag_count includes both start and stop states
#             continue
#         else:
#             pi[0,i] = 0
            
    #bottom up dynamic programming        
    for i in range(1, n): 
        for j, tag in enumerate(tags):
            max_prob = float('-inf')
            second_max = float('-inf')
            max_state = None
            second_max_state = None
            for kk, prev_tag in enumerate(tags):
                # for now, if there's an unknown word, default to 0, but we should change this to the k/count + k thing
                t_count
                prob = pi[i-1][kk] * transmission_probabilities.get((prev_tag, tag), 0) * emission_probabilities.get((sentence[i], tag), 0)
                prob_2 = pi_2[i-1][kk] * transmission_probabilities.get((prev_tag, tag), 0) * emission_probabilities.get((sentence[i], tag), 0)

                #changes made here to store the 2nd max
                if prob > max_prob:
                    max_prob = prob
                    max_state = kk
                elif prob_2 > second_max and prob_2 != max_prob:
                    second_max = prob_2
                    second_max_state = kk


            pi[i][j] = max_prob
            backpointer[i][j] = max_state # to store y*

            pi_2[i][j] = second_max
            backpointer_2[i][j] = second_max_state

    # termination step 
    max_prob = float('-inf')
    max_state = None
    for i, tag in enumerate(tags):
        prob = pi[n-1][i] * transmission_probabilities.get((tag, 'STOP'), 0)
        prob_2 = pi_2[n-1][i] * transmission_probabilities.get((tag, 'STOP'), 0)

        if prob > max_prob:
            max_prob = prob
            max_state = i

        elif prob_2 > second_max and prob_2 != max_prob:
            second_max = prob_2
            second_max_state = i
            
    #initialise an array for the best sequence of states         
    best_path = [tags[max_state]]
    second_best_path = [tags[second_max_state]]
    
    #go backwards along the backpointer, iteratively finding the best state
    for i in range(n-1, 0, -1):
        max_state = backpointer[i][max_state]
        second_max_state = backpointer_2[i][second_max_state]

        best_path.append(tags[max_state])
        second_best_path.append(tags[second_max_state])

        
    # reverse the array to get it in the right order
    best_path.reverse()
    second_best_path.reverse()
    
    return best_path,second_best_path

# %%
filepath = 'EN/dev.in'
sentences = get_sentences(filepath)
for sentence in sentences:
    print(best_path_prediction = viterbi_algorithm2(sentence, tag_count, transmission_probabilities, emission_probabilities, vocabulary))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       2 sentences = get_sentences(filepath)
#       3 for sentence in sentences:
# ----> 4     print(best_path_prediction = viterbi_algorithm2(sentence, tag_count, transmission_probabilities, emission_probabilities, vocabulary))
#
# Cell In[65], line 76, in viterbi_algorithm2(sentence, tag_count, transmission_probabilities, emission_probabilities, unk)
#      74 #initialise an array for the best sequence of states
#      75 best_path = [tags[max_state]]
# ---> 76 second_best_path = [tags[second_max_state]]
#      78 #go backwards along the backpointer, iteratively finding the best state
#      79 for i in range(n-1, 0, -1):
#
# TypeError: list indices must be integers or slices, not NoneType

# %% [markdown]
# ### Old stuff

# %%
def processfile(filepath):
#     counter = 0
    with open(filepath,'r',encoding='utf-8') as f:
        ys = {}
        words = []
        lines = f.readlines()
        for line in lines:
            clean_text = line.strip().split(" ") #removes the /n and then splits it to separete the word and its label
#             print(counter)
#             counter += 1
            if len(clean_text) > 1: #sometimes clean_text = [] whenever there is an empty line between paragraphs
                word = clean_text[0]
                label = clean_text[1]
                if word not in words:
                    words.append(word)
                if label not in ys:
                    ys[label] = 1
                else:
                    ys[label] += 1
        return ys, words, lines

# %%
ytrain, wordstrain, linestrain = processfile("EN/train")
